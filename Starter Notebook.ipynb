# %% [markdown]
# # Two Birds, One Neural Network Challenge - Starter Notebook
#
#
# ## Background
# The original concept for this challenge comes from the difficulties of understanding the Earth using only a limited number of data sources that could be interpreted in a multitude of ways.    McAliley and Li (2021) took an interesting approach to this problem by using generative algorithms to create diverse output models consistent with a series of measurements.   The algorithm produced many potential output solutions that scientists could use to make better predictions or plan future data gathering.
#
# This challenge expands upon the work of McAliley and Li (2021) by asking you to develop a generative neural network that maximizes the diversity of generated outputs consistent with **two** complex conditions.   How many sets of inputs simultaneously satisfy both conditions? How diverse will these sets of solutions be? These are the core questions of the Two Birds, One Neural Network challenge.
#
# ## The Statement of the Problem
#
# In this challenge, we have two given conditions, or models, Y0, Y1 captured by these equations:
#
# $$
# y_1 = \cos(49 \cdot x_0 + 42 \cdot x_1)
# $$
#
# $$
# y_2 = \cos(56 \cdot x_0 + 63 \cdot x_1)
# $$
#
# As you can see, the equations are a function of the vectors X0 (decreasing straight line) and X1 (increasing straight line). Can we generate a complete solution space of combination (X0, X1) simultaneously satisfying functions Y0 and Y1? Can we develop a neural network that can generate the most diverse set of solutions satisfying both conditions?
#
# This Challenge asks you to develop a neural network of arbitrary nature at the participant's choice. This could be any variation of an autoencoder (e.g., CVAE), a generative adversarial network (GAN), or any other network that allows you to generate the desired variety of solutions.
#
# Our example is built on a network type, such as a conditional variational autoencoder (CVAE), in which given functions are used as conditionals.
#
# If you prefer to use the proposed CVAE, then **any changes, including hyperparameters, configuration of layers, loss function, optimizer, etc., are welcomed**.
#
# Again, the Challenge aims **to develop a neural network and find the optimal values for hyperparameters and other constraints** to achieve **a complete space of reconstructed X0/X1**. Remember that X0/X1 should preserve the nature of the provided data, including the sign of the slope, closeness to a straight line, and producing the Y0/Y1 almost match to the given Y1/Y2.
#
# ## Description of provided data
#
# For training and evaluation of NN we are providing:
#  - **train_dataset.pt** (100,000 elements) - to build your solution.
#  - **validation_dataset.pt** (3,000 elements) - to validate your soltuion.
#
# Both dataset have the same structure:
# Each element is tensor structured as a pair of X0/X1 straight lines from 50 points (X0 is descending, X1 is ascending) along as associated tensor of conditional values Y1/Y2 for each pair X0/X1.
#
# For evaluation the **scoring_dataset.pt**  has the same structure but only 50 elements.  This dataset must be used to generate scores on the Predictive Leaderboard as described below.
#
# ## Evaluation process
#
# ### Predictive Scoring Evaluation
#
# Participants must use the provided scoring dataset and all other materials to generate results. Specifically, all 50 elements from the scoring dataset must be utilized to generate 30 samples for each element. The shape of the resulting dataset will be a threshold scoring criteria, ensuring the presence of all 50 elements.
#
# During the Predictive Scoring calculation, the '"nature of data" will be investigated, which includes the following criteria:
#  - X0 should exhibit a descending pattern, and X1 should show an ascending pattern.
#  - X0 and X1 should closely resemble straight lines (i.e., Pearson Coefficient) with a goodness of fit greater than 0.8.
#  - Reconstructed Y1/Y2, computed as functions on reconstructed X0/X1, should closely match the provided Y1/Y2 values.  The RMSE should be less than 0.1.
#
# All the abovementioned requirements are mandatory and will be assessed for the entire result. The score will be set to 0 if these criteria are not met. In all other cases, the score will be calculated as a coverage score within the [0,1] interval.
#
#
# ### Final Scoring Evaluation
#
# The best submissions on the Predictive Leaderboard will be invited to the Final Evaluation process.   Please ensure that your code is runnable, easy to follow, and reproducible. We offer the following recommendations:
#
#  -  Create a notebook with a clear and easily followable pipeline.
#  -  Include a reasonable amount of comments and descriptions to help us fully understand the brilliance of your solution.
#  - Explicitly set seeds for the training process (code example for this can be found below) to ensure the Judges can reproduce your results; otherwise, your solution may be disqualified.
#
# For the Final Evaluation, 100 X0/X1 samples will be generated on a larger scoring dataset containing 1000 elements. **Please note that the final_scoring_dataset is fixed and will be the same for all provided submissions**.
#
# The Final Assessment will be calculated using the following formula:
#
#
# $$
# \text{FinalAssessment} = 0.3 \cdot \text{LiveScoring} + 0.65 \cdot \text{FinalScoring} + 0.05 \cdot \text{Interpretability}
# $$
#
#
# The interpretability criterion will focus on the extent of documentation, including docstrings and markdown, clear variable naming, and adherence to standard Python style guidelines.
#
# ## Provided functionality
#
# Below, a quick start for this challenge is provided using CVAE. The architecture of the CVAE is provided in a separate file, **CVAE_example.py**, along with a configuration file, **config_model.yaml**. Functions for training, testing, plotting, and sample generation are also provided separately in the **CVAE_function.py** module.
# ## 0. Environment & settings

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, TensorDataset  

import torch.utils.data as data_utils


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import yaml


# Module with CVAE antares architecture
import CVAE_example as CVAE 

#Module w/ith all related CVAE functions: train, test, etc.
import CVAE_functions as CVAE_fn


# setup device cuda vs. cpu
cuda = torch.cuda.is_available()

# device = torch.device("mps")
device = torch.device("cuda")

def f_y_0(x0, x1):
    return np.sin(5 * x0 + 3 * x1)


def f_y_1(x0, x1):
    return np.cos(4 * x0 + 8 * x1)

functions = [f_y_0, f_y_1]

# %%
device
# Out:
# device(type='cuda')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Nov__3_17:51:05_Pacific_Daylight_Time_2023
# Cuda compilation tools, release 12.3, V12.3.103
# Build cuda_12.3.r12.3/compiler.33492891_0

# %% [markdown]
# ## 1. Prepare Dataset
# ### 1.1. Load Dataset
#
# Download datasets: **test_dataset.pt** and **validation_dataset.pt** and put them into the **'/data'** folder. Otherwise, edit the following hardcoded path to your own.

# %%
data_root = 'D:/aiml projects/BH 24-2y/bh2y_final resources/bh2y_final resources/data_1/'  #edit it for you own path to datasets
filename = "_dataset" 

filename_dataset = f'{data_root}train{filename}.pt'
filename_validation_dataset = f'{data_root}validation{filename}.pt'

dataset = CVAE_fn.SignalDataset(torch.load(filename_dataset))
dataset_validation = CVAE_fn.SignalDataset(torch.load(filename_validation_dataset))

print(f"Train dataset is loaded successfully and has length: {len(dataset)}")
print(f"Validation dataset is loaded successfully and has length: {len(dataset_validation)}")

# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = 100, shuffle=True)

# create a PyTorch DataLoader from the dataset_test
validation_loader = DataLoader(dataset_validation, batch_size=100, shuffle=True)
# Out:
# Train dataset is loaded successfully and has length: 100000
# Validation dataset is loaded successfully and has length: 3000

# %% [markdown]
# ### 1.2. Plot Random Samples

# %%
x,y = next(iter(dataloader))        
num_samples = 30

CVAE_fn.plot_samples(x, y, num_samples = num_samples)

# %% [markdown]
# ## 2. Model setup and train
# ### 2.1. Define the model and optimizer
#
# Here, we invite you to create your own neural network instead of the provided example or upgrade the suggested CVAE with any other possible changes, including (but not limited to) the loss function, optimizer, and hyperparameters.

# %%
number_of_functions = len(functions)

# Customize your Model’s Architecture Based on next dictionary 
model_parameters = {
    "number_of_points": 50,
    "number_of_inputs": 2,
    "number_of_functions": number_of_functions, 
    "bias": True,
    "in_channels1": 1,
    "out_channels1": 16 ,
    "kernel_size1": [6, 2],
    "out_channels2": 64,
    "kernel_size2": [4, 1],
    "out_channels3": 64,
    "kernel_size3": [4, 1]
}

with open('config_model.yaml', 'w') as f:
    yaml.dump(model_parameters, f)
    
    
# Define the input dimensions
number_of_points = 50
number_of_inputs = model_parameters['number_of_inputs']
number_of_functions = model_parameters['number_of_functions']
input_shape = (1, number_of_points, number_of_inputs)
cond_shape = (number_of_points, number_of_functions)


# Define initial state of hyperparameters
hyperparameters = {
    'latent_dim': 8,
    'lr': 0.004699203904034449,
    'beta': 13.254604785840401,
    'wx': 0.2797739476512935,
    'wy': 0.1487447727368247,
    'batch_size': 232,
    "epoch":50
    }



latent_dim, lr, beta,  wx, wy,batch_size, num_epochs = hyperparameters.values()

cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

print("Current CVAE configuration: ")
model
# Out:
# c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Current CVAE configuration:
# CVAE(
#   (encoder): Encoder(
#     (conv1): Conv2d(1, 16, kernel_size=(6, 2), stride=(1, 1))
#     (conv2): Conv2d(16, 64, kernel_size=(4, 1), stride=(1, 1))
#     (conv3): Conv2d(64, 64, kernel_size=(4, 1), stride=(1, 1))
#     (fc1_mean): Linear(in_features=2688, out_features=8, bias=True)
#     (fc1_logvar): Linear(in_features=2688, out_features=8, bias=True)
#   )
#   (sampling): Sampling()
#   (decoder): Decoder(
#     (fc1): LazyLinear(in_features=0, out_features=2688, bias=True)
#     (conv_transpose1): ConvTranspose2d(64, 64, kernel_size=(4, 1), stride=(1, 1))
#     (conv_transpose2): ConvTranspose2d(64, 16, kernel_size=(4, 1), stride=(1, 1))
#     (conv_transpose3): ConvTranspose2d(16, 1, kernel_size=(6, 2), stride=(1, 1))
#     (relu): ReLU()
#   )
# )

# %% [markdown]
# ### 2.2. Generate samples from the untrained model

# %%
# update PyTorch DataLoader with current value of batch_size
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
num_samples = 30

x_batch, y_batch = next(iter(dataloader))
y_idx = np.random.randint(batch_size)
given_x = x_batch[y_idx].unsqueeze(0).to(device) 
given_y = y_batch[y_idx].unsqueeze(0).to(device) 

given_y = torch.reshape(given_y, (len(given_y), number_of_points* number_of_functions))

x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points, number_of_functions))

CVAE_fn.plot_samples_stacked(given_x, x_output.cpu(), y_output.cpu(),fun_list = functions)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 12
#       8 given_y = y_batch[y_idx].unsqueeze(0).to(device)
#      10 given_y = torch.reshape(given_y, (len(given_y), number_of_points* number_of_functions))
# ---> 12 x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
#      13 y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points, number_of_functions))
#      15 CVAE_fn.plot_samples_stacked(given_x, x_output.cpu(), y_output.cpu(),fun_list = functions)
#
# File d:\aiml projects\BH 24-2y\CVAE_functions.py:174, in generate_samples(cvae, num_samples, given_y, input_shape, zmult)
#     172     z = cvae.sampling(*cvae.encoder(z_rand.unsqueeze(0), given_y))
#     173 else:
# --> 174     z = cvae.sampling(*cvae.encoder(z_rand.unsqueeze(0)))
#     175 # Another way to generate random latent vector
#     176 #z = torch.randn(1, latent_dim).cuda()
#     177
#     178 # Set conditional data as one of the given y
#     179 # Generate sample from decoder under given_y
#     180 sample = cvae.decoder(z, given_y)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\aiml projects\BH 24-2y\CVAE_example.py:54, in Encoder.forward(self, x)
#      50 x = F.relu(self.conv3(x))
#      52 x = x.view(x.size(0), -1)  # Flatten the feature map
# ---> 54 z_mean = self.fc1_mean(x)
#      55 z_logvar = self.fc1_logvar(x)
#      57 return z_mean, z_logvar
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x2496 and 2688x8)

# %% [markdown]
# ### 2.3. Train & validate model

# %%
# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

for epoch in range(1, num_epochs + 1):
    epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
    print(epoch_result)
    
    
CVAE_fn.test_cvae(model, validation_loader,beta, wx, wy, functions)
# Out:
# Train Epoch 1: Average Loss: 34.479184, KDL: 2.595570, x_loss: 0.113622, y_loss: 0.296728
# {'epoch': 1, 'average_loss': 34.47918372759078, 'KLD_loss': 2.5955704231229095, 'x_loss': 0.11362159895469193, 'y_loss': 0.29672755297549347}
# Train Epoch 2: Average Loss: 0.054074, KDL: 0.000176, x_loss: 0.078951, y_loss: 0.199363
# {'epoch': 2, 'average_loss': 0.054073751326305444, 'KLD_loss': 0.00017588385553271682, 'x_loss': 0.07895059361881404, 'y_loss': 0.1993627048752926}
# Train Epoch 3: Average Loss: 0.066010, KDL: 0.001404, x_loss: 0.072558, y_loss: 0.182222
# {'epoch': 3, 'average_loss': 0.06601004013619213, 'KLD_loss': 0.001403708493819943, 'x_loss': 0.07255826741284518, 'y_loss': 0.18222170366250254}
# Train Epoch 4: Average Loss: 0.045041, KDL: 0.000040, x_loss: 0.069096, y_loss: 0.169294
# {'epoch': 4, 'average_loss': 0.045041065775202935, 'KLD_loss': 3.984073797861735e-05, 'x_loss': 0.06909635537131517, 'y_loss': 0.1692942264834764}
# Train Epoch 5: Average Loss: 0.044377, KDL: 0.000040, x_loss: 0.067906, y_loss: 0.167022
# {'epoch': 5, 'average_loss': 0.044377411586335964, 'KLD_loss': 4.0400911260534214e-05, 'x_loss': 0.06790578591257886, 'y_loss': 0.16702195501851816}
# Train Epoch 6: Average Loss: 0.042454, KDL: 0.000040, x_loss: 0.065683, y_loss: 0.158288
# {'epoch': 6, 'average_loss': 0.042453905610643605, 'KLD_loss': 4.020885184959129e-05, 'x_loss': 0.06568320339580101, 'y_loss': 0.15828793620069823}
# Train Epoch 7: Average Loss: 0.042119, KDL: 0.000041, x_loss: 0.065053, y_loss: 0.157189
# {'epoch': 7, 'average_loss': 0.042118791965077874, 'KLD_loss': 4.055875319021719e-05, 'x_loss': 0.06505325188239415, 'y_loss': 0.1571886874045487}
# Train Epoch 8: Average Loss: 0.041279, KDL: 0.000038, x_loss: 0.063908, y_loss: 0.153888
# {'epoch': 8, 'average_loss': 0.04127940563140092, 'KLD_loss': 3.844665156470405e-05, 'x_loss': 0.06390779650839115, 'y_loss': 0.15388825158071187}
# Train Epoch 9: Average Loss: 0.040420, KDL: 0.000037, x_loss: 0.062814, y_loss: 0.150267
# {'epoch': 9, 'average_loss': 0.040419713076617986, 'KLD_loss': 3.7310851944817434e-05, 'x_loss': 0.06281410606095085, 'y_loss': 0.15026693641104633}
# Train Epoch 10: Average Loss: 0.040304, KDL: 0.000034, x_loss: 0.062741, y_loss: 0.149926
# {'epoch': 10, 'average_loss': 0.04030396887618634, 'KLD_loss': 3.394760467388012e-05, 'x_loss': 0.06274094217870799, 'y_loss': 0.14992610975686047}
# Train Epoch 11: Average Loss: 0.039138, KDL: 0.000029, x_loss: 0.061173, y_loss: 0.145497
# {'epoch': 11, 'average_loss': 0.03913802616470666, 'KLD_loss': 2.878021310876917e-05, 'x_loss': 0.061172960231218626, 'y_loss': 0.14549724514492685}
# Train Epoch 12: Average Loss: 0.039114, KDL: 0.000027, x_loss: 0.061173, y_loss: 0.145461
# {'epoch': 12, 'average_loss': 0.03911377310200974, 'KLD_loss': 2.737177742852105e-05, 'x_loss': 0.06117250717296782, 'y_loss': 0.1454605508285264}
# Train Epoch 13: Average Loss: 0.038309, KDL: 0.000021, x_loss: 0.060424, y_loss: 0.142025
# {'epoch': 13, 'average_loss': 0.03830948089145952, 'KLD_loss': 2.1049269923457393e-05, 'x_loss': 0.06042372190428001, 'y_loss': 0.14202514220098103}
# Train Epoch 14: Average Loss: 0.037968, KDL: 0.000017, x_loss: 0.059734, y_loss: 0.141356
# {'epoch': 14, 'average_loss': 0.0379678680371769, 'KLD_loss': 1.7332809942739982e-05, 'x_loss': 0.059734406458489875, 'y_loss': 0.141356209224021}
# Train Epoch 15: Average Loss: 0.037264, KDL: 0.000014, x_loss: 0.058955, y_loss: 0.138416
# {'epoch': 15, 'average_loss': 0.03726396701488368, 'KLD_loss': 1.3670435658207646e-05, 'x_loss': 0.05895521608181298, 'y_loss': 0.1384158670488331}
# Train Epoch 16: Average Loss: 0.037482, KDL: 0.000009, x_loss: 0.059245, y_loss: 0.139723
# {'epoch': 16, 'average_loss': 0.03748200141773042, 'KLD_loss': 9.333645855938946e-06, 'x_loss': 0.059244887040996994, 'y_loss': 0.13972330350359832}
# Train Epoch 17: Average Loss: 0.037825, KDL: 0.000007, x_loss: 0.059329, y_loss: 0.142048
# {'epoch': 17, 'average_loss': 0.0378245079708803, 'KLD_loss': 7.315366356461136e-06, 'x_loss': 0.059328735564593914, 'y_loss': 0.14204808704003138}
# Train Epoch 18: Average Loss: 0.036704, KDL: 0.000005, x_loss: 0.058400, y_loss: 0.136487
# {'epoch': 18, 'average_loss': 0.036704379254607136, 'KLD_loss': 4.81969780392117e-06, 'x_loss': 0.05839987014661784, 'y_loss': 0.13648703587413938}
# Train Epoch 19: Average Loss: 0.036775, KDL: 0.000003, x_loss: 0.058603, y_loss: 0.136702
# {'epoch': 19, 'average_loss': 0.036774890630988884, 'KLD_loss': 3.426163284866898e-06, 'x_loss': 0.05860349205667498, 'y_loss': 0.13670226434866586}
# Train Epoch 20: Average Loss: 0.036005, KDL: 0.000003, x_loss: 0.057606, y_loss: 0.133469
# {'epoch': 20, 'average_loss': 0.03600546990572992, 'KLD_loss': 2.72249733960187e-06, 'x_loss': 0.057605843309795964, 'y_loss': 0.13346868596488126}
# Train Epoch 21: Average Loss: 0.036504, KDL: 0.000004, x_loss: 0.058054, y_loss: 0.135899
# {'epoch': 21, 'average_loss': 0.036503644319492635, 'KLD_loss': 3.5829014248318144e-06, 'x_loss': 0.058053612114033766, 'y_loss': 0.13589899748977688}
# Train Epoch 22: Average Loss: 0.035924, KDL: 0.000003, x_loss: 0.057414, y_loss: 0.133278
# {'epoch': 22, 'average_loss': 0.035924166096029456, 'KLD_loss': 2.7859652483904803e-06, 'x_loss': 0.057413625039367214, 'y_loss': 0.13327797436741767}
# Train Epoch 23: Average Loss: 0.035672, KDL: 0.000003, x_loss: 0.057013, y_loss: 0.132289
# {'epoch': 23, 'average_loss': 0.035671683571611844, 'KLD_loss': 3.2810149369416414e-06, 'x_loss': 0.0570132946509316, 'y_loss': 0.13228942102028263}
# Train Epoch 24: Average Loss: 0.037491, KDL: 0.000004, x_loss: 0.058852, y_loss: 0.140968
# {'epoch': 24, 'average_loss': 0.037490939219154557, 'KLD_loss': 4.3395492765638564e-06, 'x_loss': 0.058851575146912145, 'y_loss': 0.14096819352427567}
# Train Epoch 25: Average Loss: 0.034882, KDL: 0.000012, x_loss: 0.056128, y_loss: 0.127846
# {'epoch': 25, 'average_loss': 0.03488175611494592, 'KLD_loss': 1.2244891237329554e-05, 'x_loss': 0.05612779322459742, 'y_loss': 0.12784556899633673}
# Train Epoch 26: Average Loss: 0.035504, KDL: 0.000026, x_loss: 0.056501, y_loss: 0.130104
# {'epoch': 26, 'average_loss': 0.03550395891674001, 'KLD_loss': 2.5961134168836805e-05, 'x_loss': 0.05650099725634963, 'y_loss': 0.13010438157383492}
# Train Epoch 27: Average Loss: 0.035523, KDL: 0.000026, x_loss: 0.056375, y_loss: 0.130476
# {'epoch': 27, 'average_loss': 0.03552256993673466, 'KLD_loss': 2.5848547617594402e-05, 'x_loss': 0.05637539280750961, 'y_loss': 0.1304757842725074}
# Train Epoch 28: Average Loss: 0.043299, KDL: 0.000028, x_loss: 0.067364, y_loss: 0.161925
# {'epoch': 28, 'average_loss': 0.04329946754862451, 'KLD_loss': 2.7721126874287922e-05, 'x_loss': 0.0673635758942476, 'y_loss': 0.16192475363129266}
# Train Epoch 29: Average Loss: 0.038997, KDL: 0.000029, x_loss: 0.060961, y_loss: 0.144882
# {'epoch': 29, 'average_loss': 0.03899690708904355, 'KLD_loss': 2.9499884004946108e-05, 'x_loss': 0.06096146509689451, 'y_loss': 0.14488218248718315}
# Train Epoch 30: Average Loss: 0.035322, KDL: 0.000031, x_loss: 0.056133, y_loss: 0.129108
# {'epoch': 30, 'average_loss': 0.03532197324265898, 'KLD_loss': 3.1175436796965424e-05, 'x_loss': 0.05613313884370857, 'y_loss': 0.12910816552876322}
# Train Epoch 31: Average Loss: 0.034857, KDL: 0.000027, x_loss: 0.055741, y_loss: 0.127104
# {'epoch': 31, 'average_loss': 0.03485722967026824, 'KLD_loss': 2.688886942686858e-05, 'x_loss': 0.05574071039100764, 'y_loss': 0.12710382199535766}
# Train Epoch 32: Average Loss: 0.035793, KDL: 0.000036, x_loss: 0.056377, y_loss: 0.131396
# {'epoch': 32, 'average_loss': 0.03579311584622634, 'KLD_loss': 3.589965679027416e-05, 'x_loss': 0.05637712043675559, 'y_loss': 0.13139574378038998}
# Train Epoch 33: Average Loss: 0.034692, KDL: 0.000027, x_loss: 0.055232, y_loss: 0.126943
# {'epoch': 33, 'average_loss': 0.034692105763867775, 'KLD_loss': 2.6984899132340042e-05, 'x_loss': 0.055231598680149076, 'y_loss': 0.12694273692452246}
# Train Epoch 34: Average Loss: 0.035157, KDL: 0.000035, x_loss: 0.055583, y_loss: 0.128654
# {'epoch': 34, 'average_loss': 0.03515722577166916, 'KLD_loss': 3.546697122079355e-05, 'x_loss': 0.05558264561652861, 'y_loss': 0.12865358542788913}
# Train Epoch 35: Average Loss: 0.034351, KDL: 0.000024, x_loss: 0.054893, y_loss: 0.125524
# {'epoch': 35, 'average_loss': 0.03435126737760449, 'KLD_loss': 2.4330836755258065e-05, 'x_loss': 0.054893340173832794, 'y_loss': 0.1255240390525648}
# Train Epoch 36: Average Loss: 0.037797, KDL: 0.000037, x_loss: 0.057629, y_loss: 0.142386
# {'epoch': 36, 'average_loss': 0.03779650159197411, 'KLD_loss': 3.72926394144694e-05, 'x_loss': 0.05762854753131116, 'y_loss': 0.1423864182671187}
# Train Epoch 37: Average Loss: 0.034347, KDL: 0.000028, x_loss: 0.054733, y_loss: 0.125456
# {'epoch': 37, 'average_loss': 0.03434717489182259, 'KLD_loss': 2.8169817394680446e-05, 'x_loss': 0.054733147767061986, 'y_loss': 0.12545574090822978}
# Train Epoch 38: Average Loss: 0.034270, KDL: 0.000029, x_loss: 0.054572, y_loss: 0.125192
# {'epoch': 38, 'average_loss': 0.03426974756143021, 'KLD_loss': 2.8697980774773492e-05, 'x_loss': 0.05457163292535201, 'y_loss': 0.1251919309574145}
# Train Epoch 39: Average Loss: 0.034387, KDL: 0.000025, x_loss: 0.054639, y_loss: 0.126213
# {'epoch': 39, 'average_loss': 0.03438665789845227, 'KLD_loss': 2.4632171348289206e-05, 'x_loss': 0.0546390204043645, 'y_loss': 0.12621346447202894}
# Train Epoch 40: Average Loss: 0.034607, KDL: 0.000031, x_loss: 0.054684, y_loss: 0.127037
# {'epoch': 40, 'average_loss': 0.03460719548510732, 'KLD_loss': 3.108437414522524e-05, 'x_loss': 0.05468377783135683, 'y_loss': 0.12703698452700068}
# Train Epoch 41: Average Loss: 0.034324, KDL: 0.000042, x_loss: 0.054256, y_loss: 0.124981
# {'epoch': 41, 'average_loss': 0.034323828001679095, 'KLD_loss': 4.180603557162815e-05, 'x_loss': 0.054256290542306726, 'y_loss': 0.12498058223476012}
# Train Epoch 42: Average Loss: 0.051178, KDL: 0.000034, x_loss: 0.078308, y_loss: 0.193792
# {'epoch': 42, 'average_loss': 0.0511784824947999, 'KLD_loss': 3.3530924055311414e-05, 'x_loss': 0.0783077020853482, 'y_loss': 0.19379227196245832}
# Train Epoch 43: Average Loss: 0.034784, KDL: 0.000029, x_loss: 0.055294, y_loss: 0.127261
# {'epoch': 43, 'average_loss': 0.03478385046710847, 'KLD_loss': 2.901476842385751e-05, 'x_loss': 0.05529429384127811, 'y_loss': 0.12726072539333944}
# Train Epoch 44: Average Loss: 0.034655, KDL: 0.000028, x_loss: 0.054856, y_loss: 0.127270
# {'epoch': 44, 'average_loss': 0.034655220366807446, 'KLD_loss': 2.8456250826517742e-05, 'x_loss': 0.05485612259211915, 'y_loss': 0.12726988048396176}
# Train Epoch 45: Average Loss: 0.034335, KDL: 0.000030, x_loss: 0.054367, y_loss: 0.125921
# {'epoch': 45, 'average_loss': 0.03433461273433985, 'KLD_loss': 2.9724505212571887e-05, 'x_loss': 0.05436736536298499, 'y_loss': 0.12592074804490916}
# Train Epoch 46: Average Loss: 0.034437, KDL: 0.000035, x_loss: 0.054597, y_loss: 0.125732
# {'epoch': 46, 'average_loss': 0.03443712288841467, 'KLD_loss': 3.473460674285889e-05, 'x_loss': 0.054596831961707386, 'y_loss': 0.12573186439220552}
# Train Epoch 47: Average Loss: 0.034398, KDL: 0.000029, x_loss: 0.054290, y_loss: 0.126584
# {'epoch': 47, 'average_loss': 0.03439827666928371, 'KLD_loss': 2.871343383082637e-05, 'x_loss': 0.05429009465431726, 'y_loss': 0.1265841918066144}
# Train Epoch 48: Average Loss: 0.034561, KDL: 0.000032, x_loss: 0.054453, y_loss: 0.127077
# {'epoch': 48, 'average_loss': 0.034561325761455076, 'KLD_loss': 3.2046326884516964e-05, 'x_loss': 0.05445294686662102, 'y_loss': 0.12707705697458652}
# Train Epoch 49: Average Loss: 0.033987, KDL: 0.000040, x_loss: 0.053922, y_loss: 0.123495
# {'epoch': 49, 'average_loss': 0.03398733905137137, 'KLD_loss': 4.01404168870714e-05, 'x_loss': 0.05392224663282158, 'y_loss': 0.12349511838207643}
# Train Epoch 50: Average Loss: 0.033990, KDL: 0.000024, x_loss: 0.053856, y_loss: 0.125046
# {'epoch': 50, 'average_loss': 0.03399031503660673, 'KLD_loss': 2.4361190972504794e-05, 'x_loss': 0.05385570991266933, 'y_loss': 0.12504635656390478}
# Test Loss: 0.039511
# 0.03951109647750854

# %%
x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points
                                    , number_of_functions))

CVAE_fn.plot_samples_stacked(given_x, x_output.cpu(), y_output.cpu(),fun_list = functions)

# %% [markdown]
# ### 2.4. Hyperparameter's tuning process

# %%
import optuna


number_of_functions = len(functions)

# Customize your Model’s Architecture Based on next dictionary 
model_parameters = {
    "number_of_points": 50,
    "number_of_inputs": 2,
    "number_of_functions": number_of_functions, 
    "bias": True,
    "in_channels1": 1,
    "out_channels1": 16,
    "kernel_size1": [6, 2],
    "out_channels2": 64,
    "kernel_size2": [4, 1]
}

with open('config_model.yaml', 'w') as f:
    yaml.dump(model_parameters, f)
    
    
# Define the input dimensions
number_of_points = 50
number_of_inputs = model_parameters['number_of_inputs']
number_of_functions = model_parameters['number_of_functions']
input_shape = (1, number_of_points, number_of_inputs)
cond_shape = (number_of_points, number_of_functions)


cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

model
# Out:
# c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# CVAE(
#   (encoder): Encoder(
#     (conv1): Conv2d(1, 16, kernel_size=(6, 2), stride=(1, 1))
#     (conv2): Conv2d(16, 64, kernel_size=(4, 1), stride=(1, 1))
#     (fc1_mean): Linear(in_features=2688, out_features=21, bias=True)
#     (fc1_logvar): Linear(in_features=2688, out_features=21, bias=True)
#   )
#   (sampling): Sampling()
#   (decoder): Decoder(
#     (fc1): LazyLinear(in_features=0, out_features=2688, bias=True)
#     (conv_transpose2): ConvTranspose2d(64, 16, kernel_size=(4, 1), stride=(1, 1))
#     (conv_transpose3): ConvTranspose2d(16, 1, kernel_size=(6, 2), stride=(1, 1))
#     (relu): ReLU()
#   )
# )

# %%
import optuna

def training_with_optuna( lr, batch_size, beta, wx, wy,num_epochs, latent_dim):

    print("lr =" , lr , ", batch = " , batch_size ,  ", beta= " , beta, ", wx= ", wx , ", wy = ", wy , ", latent_dim = " , latent_dim)
    
    cvae = CVAE.CVAE(latent_dim).to(device)

    model = cvae
    optimizer = optim.Adam(model.parameters(), lr = lr)
    dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)

    for epoch in range(1, num_epochs + 1):
        epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
        print(epoch_result)
    
    return(epoch_result["average_loss"])


def objective(trial):
    params = {
    "latent_dim": trial.suggest_int("latent_dim", 3,25),
    "lr" : trial.suggest_float("lr", 1e-4, 0.01),
    "batch_size" : trial.suggest_int("batch_size", 64,256),
    # "batch_size": 128,
    "beta" : trial.suggest_float("beta", 1,15),
    "wx": trial.suggest_float("wx", 0.1, 11),
    "wy": trial.suggest_float("wy",0.1,11),
    "epoch":21
    }

    return training_with_optuna(params["lr"],params["batch_size"] , params["beta"], params["wx"], params["wy"], params["epoch"],params["latent_dim"])

# %%
study=optuna.create_study(directions=["minimize"])
study.optimize(objective, n_trials=30)

print("best trial:")
trial_ = study.best_trial

print(trial_.values)
print(trial_.params)
# Out:
# [I 2024-02-16 17:14:09,355] A new study created in memory with name: no-name-124ff9d9-3732-4635-a1df-f91d24275277
# lr = 0.005627950203801477 , batch =  186 , beta=  2.252102397929369 , wx=  0.9834878542037578 , wy =  9.932180706284054 , latent_dim =  21
# Train Epoch 1: Average Loss: 12.984134, KDL: 4.254289, x_loss: 0.123202, y_loss: 0.330428
# {'epoch': 1, 'average_loss': 12.98413381257465, 'KLD_loss': 4.254289137774241, 'x_loss': 0.12320158504586681, 'y_loss': 0.33042815083907884}
# Train Epoch 2: Average Loss: 2.196823, KDL: -0.000017, x_loss: 0.081057, y_loss: 0.213160
# {'epoch': 2, 'average_loss': 2.1968225683864606, 'KLD_loss': -1.7212281439827278e-05, 'x_loss': 0.08105691255080656, 'y_loss': 0.21315992598639988}
# Train Epoch 3: Average Loss: 2.001473, KDL: -0.000016, x_loss: 0.075172, y_loss: 0.194074
# {'epoch': 3, 'average_loss': 2.001472500841857, 'KLD_loss': -1.5552269924972137e-05, 'x_loss': 0.07517217078893601, 'y_loss': 0.1940738625519781}
# Train Epoch 4: Average Loss: 1.869210, KDL: -0.000018, x_loss: 0.071679, y_loss: 0.181104
# {'epoch': 4, 'average_loss': 1.8692100209817568, 'KLD_loss': -1.836809083874784e-05, 'x_loss': 0.07167919966838839, 'y_loss': 0.18110381576429957}
# Train Epoch 5: Average Loss: 1.765109, KDL: -0.000015, x_loss: 0.069189, y_loss: 0.170869
# {'epoch': 5, 'average_loss': 1.7651086859543528, 'KLD_loss': -1.5323600804495546e-05, 'x_loss': 0.0691888722483775, 'y_loss': 0.17086850153801608}
# Train Epoch 6: Average Loss: 1.702655, KDL: -0.000014, x_loss: 0.067378, y_loss: 0.164760
# {'epoch': 6, 'average_loss': 1.7026546462317824, 'KLD_loss': -1.405938407302346e-05, 'x_loss': 0.06737759778601529, 'y_loss': 0.1647595184332376}
# Train Epoch 7: Average Loss: 1.653224, KDL: -0.000015, x_loss: 0.066129, y_loss: 0.159906
# {'epoch': 7, 'average_loss': 1.6532238043817002, 'KLD_loss': -1.4697585850400109e-05, 'x_loss': 0.0661287082490757, 'y_loss': 0.1599064920249925}
# Train Epoch 8: Average Loss: 1.637823, KDL: -0.000013, x_loss: 0.065053, y_loss: 0.158462
# {'epoch': 8, 'average_loss': 1.637823363219052, 'KLD_loss': -1.2809348372278603e-05, 'x_loss': 0.06505250122024224, 'y_loss': 0.15846207030256}
# Train Epoch 9: Average Loss: 1.617988, KDL: -0.000012, x_loss: 0.064431, y_loss: 0.156527
# {'epoch': 9, 'average_loss': 1.6179883661766479, 'KLD_loss': -1.2417818977043974e-05, 'x_loss': 0.064430684100518, 'y_loss': 0.15652651040638246}
# Train Epoch 10: Average Loss: 1.584297, KDL: -0.000011, x_loss: 0.063764, y_loss: 0.153200
# {'epoch': 10, 'average_loss': 1.5842971159179857, 'KLD_loss': -1.0673829170851016e-05, 'x_loss': 0.06376411546312521, 'y_loss': 0.1531999881022703}
# Train Epoch 11: Average Loss: 1.793002, KDL: -0.000007, x_loss: 0.070848, y_loss: 0.173511
# {'epoch': 11, 'average_loss': 1.7930023805359483, 'KLD_loss': -6.793766216717688e-06, 'x_loss': 0.07084799825895896, 'y_loss': 0.1735106960880712}
# Train Epoch 12: Average Loss: 1.523556, KDL: -0.000009, x_loss: 0.062669, y_loss: 0.147192
# {'epoch': 12, 'average_loss': 1.5235561039368015, 'KLD_loss': -8.726097837256675e-06, 'x_loss': 0.06266885611564475, 'y_loss': 0.14719242328383222}
# Train Epoch 13: Average Loss: 1.505482, KDL: -0.000006, x_loss: 0.061544, y_loss: 0.145483
# {'epoch': 13, 'average_loss': 1.5054820321749578, 'KLD_loss': -5.841421371942116e-06, 'x_loss': 0.061543577257197585, 'y_loss': 0.14548344550079573}
# Train Epoch 14: Average Loss: 1.500717, KDL: -0.000006, x_loss: 0.061353, y_loss: 0.145023
# {'epoch': 14, 'average_loss': 1.5007173108788672, 'KLD_loss': -6.39115789122741e-06, 'x_loss': 0.061352843231760434, 'y_loss': 0.14502273150979364}
# Train Epoch 15: Average Loss: 1.506460, KDL: -0.000003, x_loss: 0.061046, y_loss: 0.145631
# {'epoch': 15, 'average_loss': 1.5064598866998042, 'KLD_loss': -3.463550571172211e-06, 'x_loss': 0.06104635348245779, 'y_loss': 0.1456305949384395}
# Train Epoch 16: Average Loss: 1.478887, KDL: -0.000002, x_loss: 0.060367, y_loss: 0.142922
# {'epoch': 16, 'average_loss': 1.4788869883048046, 'KLD_loss': -2.388894336374276e-06, 'x_loss': 0.06036656181636131, 'y_loss': 0.14292154684108874}
# Train Epoch 17: Average Loss: 1.562117, KDL: 0.000000, x_loss: 0.061748, y_loss: 0.151164
# {'epoch': 17, 'average_loss': 1.562117250656993, 'KLD_loss': 1.9111154690994206e-08, 'x_loss': 0.061748485776793115, 'y_loss': 0.15116402022125108}
# Train Epoch 18: Average Loss: 1.442270, KDL: 0.000001, x_loss: 0.059085, y_loss: 0.139361
# {'epoch': 18, 'average_loss': 1.4422696924120963, 'KLD_loss': 1.2402862421198849e-06, 'x_loss': 0.05908525602192684, 'y_loss': 0.13936086654053745}
# Train Epoch 19: Average Loss: 1.603196, KDL: 0.000017, x_loss: 0.062680, y_loss: 0.155204
# {'epoch': 19, 'average_loss': 1.6031964922039925, 'KLD_loss': 1.7299029463729008e-05, 'x_loss': 0.06267959704158696, 'y_loss': 0.15520387755007548}
# Train Epoch 20: Average Loss: 1.442852, KDL: 0.000048, x_loss: 0.058953, y_loss: 0.139422
# {'epoch': 20, 'average_loss': 1.4428516424721503, 'KLD_loss': 4.805081617433342e-05, 'x_loss': 0.058953050295493414, 'y_loss': 0.13942193548752474}
# [I 2024-02-16 17:15:47,894] Trial 0 finished with value: 1.4432670680120532 and parameters: {'latent_dim': 21, 'lr': 0.005627950203801477, 'batch_size': 186, 'beta': 2.252102397929369, 'wx': 0.9834878542037578, 'wy': 9.932180706284054}. Best is trial 0 with value: 1.4432670680120532.
# Train Epoch 21: Average Loss: 1.443267, KDL: 0.000071, x_loss: 0.058943, y_loss: 0.139460
# {'epoch': 21, 'average_loss': 1.4432670680120532, 'KLD_loss': 7.071847366134473e-05, 'x_loss': 0.05894268619859085, 'y_loss': 0.13945964855387752}
# lr = 0.009503127404530716 , batch =  158 , beta=  5.234316765714454 , wx=  9.721525062477914 , wy =  6.37032216544795 , latent_dim =  21
# Train Epoch 1: Average Loss: 38.407405, KDL: 6.578046, x_loss: 0.176465, y_loss: 0.354820
# {'epoch': 1, 'average_loss': 38.407404522948546, 'KLD_loss': 6.578046313629708, 'x_loss': 0.17646488569688645, 'y_loss': 0.3548203296194333}
# Train Epoch 2: Average Loss: 2.073604, KDL: 0.000847, x_loss: 0.080014, y_loss: 0.202708
# {'epoch': 2, 'average_loss': 2.0736036340207287, 'KLD_loss': 0.000847404602014623, 'x_loss': 0.08001354802252746, 'y_loss': 0.20270785124381008}
# Train Epoch 3: Average Loss: 1.931208, KDL: 0.000108, x_loss: 0.075265, y_loss: 0.188208
# {'epoch': 3, 'average_loss': 1.9312077879340728, 'KLD_loss': 0.00010795785352517078, 'x_loss': 0.0752654954567434, 'y_loss': 0.1882082645738671}
# Train Epoch 4: Average Loss: 1.837861, KDL: 0.000100, x_loss: 0.072432, y_loss: 0.177885
# {'epoch': 4, 'average_loss': 1.8378612803056906, 'KLD_loss': 0.0001003709261262963, 'x_loss': 0.07243228222333237, 'y_loss': 0.1778848247976288}
# Train Epoch 5: Average Loss: 1.755412, KDL: 0.000579, x_loss: 0.069692, y_loss: 0.168730
# {'epoch': 5, 'average_loss': 1.7554123900701273, 'KLD_loss': 0.0005786394432634351, 'x_loss': 0.06969243216241518, 'y_loss': 0.1687303777036697}
# Train Epoch 6: Average Loss: 1.730642, KDL: 0.000433, x_loss: 0.068571, y_loss: 0.166674
# {'epoch': 6, 'average_loss': 1.7306419255044223, 'KLD_loss': 0.0004326749657755968, 'x_loss': 0.06857054545227761, 'y_loss': 0.16667396870646242}
# Train Epoch 7: Average Loss: 1.726713, KDL: 0.001152, x_loss: 0.068046, y_loss: 0.166266
# {'epoch': 7, 'average_loss': 1.7267126206538124, 'KLD_loss': 0.0011524333490579614, 'x_loss': 0.06804599316340487, 'y_loss': 0.16626624892484898}
# Train Epoch 8: Average Loss: 1.727247, KDL: 0.000060, x_loss: 0.068235, y_loss: 0.166959
# {'epoch': 8, 'average_loss': 1.7272466692314328, 'KLD_loss': 5.962357136875532e-05, 'x_loss': 0.068235194772529, 'y_loss': 0.16695928009812488}
# Train Epoch 9: Average Loss: 1.890516, KDL: 0.000095, x_loss: 0.073970, y_loss: 0.183809
# {'epoch': 9, 'average_loss': 1.890515685081482, 'KLD_loss': 9.483155481058274e-05, 'x_loss': 0.07396974098555284, 'y_loss': 0.1838086929766676}
# Train Epoch 10: Average Loss: 1.688977, KDL: 0.000096, x_loss: 0.067932, y_loss: 0.161385
# {'epoch': 10, 'average_loss': 1.6889773944354547, 'KLD_loss': 9.601253657167745e-05, 'x_loss': 0.06793159981498033, 'y_loss': 0.16138525524928482}
# Train Epoch 11: Average Loss: 1.634637, KDL: 0.000067, x_loss: 0.065449, y_loss: 0.156667
# {'epoch': 11, 'average_loss': 1.6346366104168162, 'KLD_loss': 6.7219632496766e-05, 'x_loss': 0.06544887032036156, 'y_loss': 0.15666741545872664}
# Train Epoch 12: Average Loss: 1.636739, KDL: 0.000044, x_loss: 0.065009, y_loss: 0.157688
# {'epoch': 12, 'average_loss': 1.636738769062699, 'KLD_loss': 4.4391524358571614e-05, 'x_loss': 0.06500850188270753, 'y_loss': 0.15768819620117758}
# Train Epoch 13: Average Loss: 1.832655, KDL: 0.000030, x_loss: 0.070165, y_loss: 0.180585
# {'epoch': 13, 'average_loss': 1.8326551143968652, 'KLD_loss': 2.98007687121206e-05, 'x_loss': 0.07016509320545723, 'y_loss': 0.1805854345808662}
# Train Epoch 14: Average Loss: 1.588358, KDL: 0.000021, x_loss: 0.063792, y_loss: 0.151968
# {'epoch': 14, 'average_loss': 1.5883575045102016, 'KLD_loss': 2.1391099474818034e-05, 'x_loss': 0.06379236672868095, 'y_loss': 0.15196820538002545}
# Train Epoch 15: Average Loss: 1.635324, KDL: 0.000024, x_loss: 0.064595, y_loss: 0.158114
# {'epoch': 15, 'average_loss': 1.635323603759633, 'KLD_loss': 2.392815752616991e-05, 'x_loss': 0.06459483713806147, 'y_loss': 0.1581141400323095}
# Train Epoch 16: Average Loss: 1.700039, KDL: 0.000055, x_loss: 0.066309, y_loss: 0.165632
# {'epoch': 16, 'average_loss': 1.700038906710596, 'KLD_loss': 5.483792103109013e-05, 'x_loss': 0.06630880385637283, 'y_loss': 0.1656319918979024}
# Train Epoch 17: Average Loss: 17.229994, KDL: 2.952055, x_loss: 0.068275, y_loss: 0.174916
# {'epoch': 17, 'average_loss': 17.229994108703277, 'KLD_loss': 2.9520550679068243, 'x_loss': 0.06827469241303667, 'y_loss': 0.17491559827873868}
# Train Epoch 18: Average Loss: 1.568635, KDL: -0.000015, x_loss: 0.062735, y_loss: 0.150516
# {'epoch': 18, 'average_loss': 1.5686353113602312, 'KLD_loss': -1.5240144955603432e-05, 'x_loss': 0.0627351100740463, 'y_loss': 0.1505157992031902}
# Train Epoch 19: Average Loss: 1.569179, KDL: -0.000014, x_loss: 0.062485, y_loss: 0.150981
# {'epoch': 19, 'average_loss': 1.569179470693519, 'KLD_loss': -1.366377630128303e-05, 'x_loss': 0.062485169024923216, 'y_loss': 0.15098135048555913}
# Train Epoch 20: Average Loss: 1.841573, KDL: -0.000010, x_loss: 0.071645, y_loss: 0.179759
# {'epoch': 20, 'average_loss': 1.8415729602177937, 'KLD_loss': -1.000190421491626e-05, 'x_loss': 0.0716454366466257, 'y_loss': 0.1797589451592492}
# [I 2024-02-16 17:17:26,069] Trial 1 finished with value: 1.5831172338217543 and parameters: {'latent_dim': 21, 'lr': 0.009503127404530716, 'batch_size': 158, 'beta': 5.234316765714454, 'wx': 9.721525062477914, 'wy': 6.37032216544795}. Best is trial 0 with value: 1.4432670680120532.
# Train Epoch 21: Average Loss: 1.583117, KDL: -0.000008, x_loss: 0.062869, y_loss: 0.152580
# {'epoch': 21, 'average_loss': 1.5831172338217543, 'KLD_loss': -8.13344455254963e-06, 'x_loss': 0.0628686040451553, 'y_loss': 0.15257958062640486}
# lr = 0.0006035738958378587 , batch =  244 , beta=  11.793442295245482 , wx=  2.681686622097929 , wy =  0.9124462261330094 , latent_dim =  25
# Train Epoch 1: Average Loss: 9.694283, KDL: 0.761466, x_loss: 0.134683, y_loss: 0.386654
# {'epoch': 1, 'average_loss': 9.694283042448323, 'KLD_loss': 0.7614659864728044, 'x_loss': 0.13468274219733914, 'y_loss': 0.38665373368961053}
# Train Epoch 2: Average Loss: 0.468811, KDL: 0.000734, x_loss: 0.089697, y_loss: 0.240684
# {'epoch': 2, 'average_loss': 0.46881059640791356, 'KLD_loss': 0.0007342138668385948, 'x_loss': 0.08969731936004104, 'y_loss': 0.24068441957962222}
# Train Epoch 3: Average Loss: 0.410779, KDL: 0.000383, x_loss: 0.080962, y_loss: 0.207304
# {'epoch': 3, 'average_loss': 0.410778970398554, 'KLD_loss': 0.0003825398480019918, 'x_loss': 0.08096179762264577, 'y_loss': 0.20730355073039125}
# Train Epoch 4: Average Loss: 0.382215, KDL: 0.000275, x_loss: 0.076123, y_loss: 0.191607
# {'epoch': 4, 'average_loss': 0.3822148523679594, 'KLD_loss': 0.00027514797885243487, 'x_loss': 0.07612335420236355, 'y_loss': 0.19160683416738744}
# Train Epoch 5: Average Loss: 0.360388, KDL: 0.000235, x_loss: 0.072456, y_loss: 0.178980
# {'epoch': 5, 'average_loss': 0.36038786485427765, 'KLD_loss': 0.0002351703440270773, 'x_loss': 0.07245618406592345, 'y_loss': 0.1789799955196497}
# Train Epoch 6: Average Loss: 0.348574, KDL: 0.000246, x_loss: 0.069971, y_loss: 0.173203
# {'epoch': 6, 'average_loss': 0.3485741559325195, 'KLD_loss': 0.0002456517481222385, 'x_loss': 0.0699705214489524, 'y_loss': 0.1732026102339349}
# Train Epoch 7: Average Loss: 0.335200, KDL: 0.000428, x_loss: 0.067625, y_loss: 0.163087
# {'epoch': 7, 'average_loss': 0.33520017404381824, 'KLD_loss': 0.0004276170963194312, 'x_loss': 0.067624905587333, 'y_loss': 0.16308719421305307}
# Train Epoch 8: Average Loss: 0.335020, KDL: 0.001155, x_loss: 0.065960, y_loss: 0.158378
# {'epoch': 8, 'average_loss': 0.3350196815118557, 'KLD_loss': 0.0011551699260386025, 'x_loss': 0.06596023523044295, 'y_loss': 0.15837818046168584}
# Train Epoch 9: Average Loss: 0.334016, KDL: 0.001675, x_loss: 0.064650, y_loss: 0.154408
# {'epoch': 9, 'average_loss': 0.33401626711938437, 'KLD_loss': 0.0016752886336024214, 'x_loss': 0.06464953751462262, 'y_loss': 0.15440805783359016}
# Train Epoch 10: Average Loss: 0.327679, KDL: 0.001489, x_loss: 0.063757, y_loss: 0.152492
# {'epoch': 10, 'average_loss': 0.3276789466782314, 'KLD_loss': 0.0014891702954362078, 'x_loss': 0.06375674305529129, 'y_loss': 0.1524921642207518}
# Train Epoch 11: Average Loss: 0.317701, KDL: 0.001215, x_loss: 0.062581, y_loss: 0.148553
# {'epoch': 11, 'average_loss': 0.31770145478771955, 'KLD_loss': 0.001215267762905214, 'x_loss': 0.06258098786560501, 'y_loss': 0.14855304974608305}
# Train Epoch 12: Average Loss: 0.312417, KDL: 0.000984, x_loss: 0.061929, y_loss: 0.147662
# {'epoch': 12, 'average_loss': 0.31241667059863487, 'KLD_loss': 0.0009844461592232309, 'x_loss': 0.06192866545624849, 'y_loss': 0.1476617321372032}
# Train Epoch 13: Average Loss: 0.307871, KDL: 0.000918, x_loss: 0.061381, y_loss: 0.145142
# {'epoch': 13, 'average_loss': 0.3078708363015477, 'KLD_loss': 0.0009183376300625685, 'x_loss': 0.06138146349751368, 'y_loss': 0.14514239039726373}
# Train Epoch 14: Average Loss: 0.300202, KDL: 0.000604, x_loss: 0.060684, y_loss: 0.142854
# {'epoch': 14, 'average_loss': 0.30020161950733604, 'KLD_loss': 0.0006036595600407298, 'x_loss': 0.06068411516707118, 'y_loss': 0.1428540265414773}
# Train Epoch 15: Average Loss: 0.297962, KDL: 0.000517, x_loss: 0.060268, y_loss: 0.142745
# {'epoch': 15, 'average_loss': 0.2979616971641052, 'KLD_loss': 0.0005168421239387698, 'x_loss': 0.06026769289519729, 'y_loss': 0.1427451636187914}
# Train Epoch 16: Average Loss: 0.291878, KDL: 0.000414, x_loss: 0.059643, y_loss: 0.139240
# {'epoch': 16, 'average_loss': 0.2918775557017908, 'KLD_loss': 0.00041429414981749, 'x_loss': 0.05964264159158963, 'y_loss': 0.1392396910161507}
# Train Epoch 17: Average Loss: 0.288322, KDL: 0.000359, x_loss: 0.058958, y_loss: 0.138072
# {'epoch': 17, 'average_loss': 0.28832151533626926, 'KLD_loss': 0.00035866004664723464, 'x_loss': 0.05895842344659131, 'y_loss': 0.1380724267625227}
# Train Epoch 18: Average Loss: 0.284269, KDL: 0.000258, x_loss: 0.058578, y_loss: 0.136052
# {'epoch': 18, 'average_loss': 0.2842693883471373, 'KLD_loss': 0.00025791678486800773, 'x_loss': 0.05857792424901229, 'y_loss': 0.13605188373021962}
# Train Epoch 19: Average Loss: 0.285756, KDL: 0.000278, x_loss: 0.058605, y_loss: 0.137342
# {'epoch': 19, 'average_loss': 0.2857555969095812, 'KLD_loss': 0.00027789684330544823, 'x_loss': 0.05860518881278794, 'y_loss': 0.13734232734252766}
# Train Epoch 20: Average Loss: 0.282518, KDL: 0.000246, x_loss: 0.058206, y_loss: 0.135373
# {'epoch': 20, 'average_loss': 0.28251768190686294, 'KLD_loss': 0.0002463443250190921, 'x_loss': 0.058206445151349394, 'y_loss': 0.13537344823523265}
# [I 2024-02-16 17:18:35,230] Trial 2 finished with value: 0.28168911196109725 and parameters: {'latent_dim': 25, 'lr': 0.0006035738958378587, 'batch_size': 244, 'beta': 11.793442295245482, 'wx': 2.681686622097929, 'wy': 0.9124462261330094}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 0.281689, KDL: 0.000219, x_loss: 0.057973, y_loss: 0.135506
# {'epoch': 21, 'average_loss': 0.28168911196109725, 'KLD_loss': 0.00021888570087711987, 'x_loss': 0.05797301329127172, 'y_loss': 0.13550633461010164}
# lr = 0.006976710972689424 , batch =  79 , beta=  9.294472119323528 , wx=  0.9627962108979231 , wy =  2.974915409762516 , latent_dim =  7
# Train Epoch 1: Average Loss: 3.544280, KDL: 0.286738, x_loss: 0.100754, y_loss: 0.262931
# {'epoch': 1, 'average_loss': 3.544279573982549, 'KLD_loss': 0.28673796212127045, 'x_loss': 0.10075368053952194, 'y_loss': 0.262930695302961}
# Train Epoch 2: Average Loss: 0.647574, KDL: -0.000002, x_loss: 0.077541, y_loss: 0.192588
# {'epoch': 2, 'average_loss': 0.6475740038623554, 'KLD_loss': -1.6278988942150821e-06, 'x_loss': 0.07754097011169833, 'y_loss': 0.1925879845404512}
# Train Epoch 3: Average Loss: 0.604217, KDL: -0.000001, x_loss: 0.073236, y_loss: 0.179406
# {'epoch': 3, 'average_loss': 0.6042169829445051, 'KLD_loss': -1.214385785951057e-06, 'x_loss': 0.0732355229232878, 'y_loss': 0.1794058973731776}
# Train Epoch 4: Average Loss: 0.579740, KDL: -0.000001, x_loss: 0.070313, y_loss: 0.172123
# {'epoch': 4, 'average_loss': 0.5797403956429465, 'KLD_loss': -7.618189234680851e-07, 'x_loss': 0.07031319695296823, 'y_loss': 0.17212260190815346}
# Train Epoch 5: Average Loss: 0.588899, KDL: -0.000000, x_loss: 0.070737, y_loss: 0.175063
# {'epoch': 5, 'average_loss': 0.5888987496660031, 'KLD_loss': -4.4107907944569277e-07, 'x_loss': 0.07073748912691694, 'y_loss': 0.17506280817432804}
# Train Epoch 6: Average Loss: 0.554120, KDL: -0.000000, x_loss: 0.067439, y_loss: 0.164439
# {'epoch': 6, 'average_loss': 0.5541197343083543, 'KLD_loss': -1.1596069516728839e-07, 'x_loss': 0.06743879869027067, 'y_loss': 0.164438617243586}
# Train Epoch 7: Average Loss: 0.555897, KDL: 0.000000, x_loss: 0.067184, y_loss: 0.165117
# {'epoch': 7, 'average_loss': 0.5558971042081267, 'KLD_loss': 2.770956846963361e-07, 'x_loss': 0.0671838106643438, 'y_loss': 0.16511736540079683}
# Train Epoch 8: Average Loss: 0.556435, KDL: 0.000005, x_loss: 0.067041, y_loss: 0.165330
# {'epoch': 8, 'average_loss': 0.5564351702376753, 'KLD_loss': 4.849986630781756e-06, 'x_loss': 0.06704130697860067, 'y_loss': 0.1653300661175831}
# Train Epoch 9: Average Loss: 0.531566, KDL: 0.000017, x_loss: 0.064942, y_loss: 0.157613
# {'epoch': 9, 'average_loss': 0.5315657483081305, 'KLD_loss': 1.6638853162009192e-05, 'x_loss': 0.06494210704301864, 'y_loss': 0.15761290841969833}
# Train Epoch 10: Average Loss: 0.539263, KDL: 0.000016, x_loss: 0.065273, y_loss: 0.160094
# {'epoch': 10, 'average_loss': 0.5392626053631588, 'KLD_loss': 1.6324892993221915e-05, 'x_loss': 0.06527301773287673, 'y_loss': 0.1600940459324003}
# Train Epoch 11: Average Loss: 0.530183, KDL: 0.000016, x_loss: 0.064121, y_loss: 0.157414
# {'epoch': 11, 'average_loss': 0.5301825523753113, 'KLD_loss': 1.6447421498773222e-05, 'x_loss': 0.06412061190270887, 'y_loss': 0.1574144205858263}
# Train Epoch 12: Average Loss: 0.556917, KDL: 0.000017, x_loss: 0.067570, y_loss: 0.165284
# {'epoch': 12, 'average_loss': 0.5569167155036806, 'KLD_loss': 1.660363651564901e-05, 'x_loss': 0.06756959909405472, 'y_loss': 0.16528423734915576}
# Train Epoch 13: Average Loss: 0.519367, KDL: 0.000017, x_loss: 0.063378, y_loss: 0.154018
# {'epoch': 13, 'average_loss': 0.5193673902872427, 'KLD_loss': 1.6740383506762848e-05, 'x_loss': 0.06337779145952649, 'y_loss': 0.1540184583085314}
# Train Epoch 14: Average Loss: 0.528771, KDL: 0.000017, x_loss: 0.063439, y_loss: 0.157159
# {'epoch': 14, 'average_loss': 0.5287710290290356, 'KLD_loss': 1.6809733934688717e-05, 'x_loss': 0.06343937197061605, 'y_loss': 0.15715928893612835}
# Train Epoch 15: Average Loss: 0.553356, KDL: 0.000017, x_loss: 0.066727, y_loss: 0.164360
# {'epoch': 15, 'average_loss': 0.5533560442416023, 'KLD_loss': 1.663875899985315e-05, 'x_loss': 0.06672747324310585, 'y_loss': 0.1643597733812027}
# Train Epoch 16: Average Loss: 0.511672, KDL: 0.000017, x_loss: 0.062391, y_loss: 0.151752
# {'epoch': 16, 'average_loss': 0.5116720475009268, 'KLD_loss': 1.6535039384971487e-05, 'x_loss': 0.06239101954840277, 'y_loss': 0.15175171357124903}
# Train Epoch 17: Average Loss: 0.514061, KDL: 0.000017, x_loss: 0.062129, y_loss: 0.152640
# {'epoch': 17, 'average_loss': 0.5140613334674218, 'KLD_loss': 1.6510204116315073e-05, 'x_loss': 0.06212869858278012, 'y_loss': 0.1526398326948544}
# Train Epoch 18: Average Loss: 0.525890, KDL: 0.000016, x_loss: 0.062814, y_loss: 0.156395
# {'epoch': 18, 'average_loss': 0.5258903402664462, 'KLD_loss': 1.6450905498546824e-05, 'x_loss': 0.06281367103505944, 'y_loss': 0.15639458453697616}
# Train Epoch 19: Average Loss: 0.524255, KDL: 0.000017, x_loss: 0.062950, y_loss: 0.155800
# {'epoch': 19, 'average_loss': 0.5242545570572029, 'KLD_loss': 1.6720468210759696e-05, 'x_loss': 0.06295003384163406, 'y_loss': 0.1557997510037245}
# Train Epoch 20: Average Loss: 0.512492, KDL: 0.000017, x_loss: 0.061660, y_loss: 0.152262
# {'epoch': 20, 'average_loss': 0.5124915005377307, 'KLD_loss': 1.6982027139708894e-05, 'x_loss': 0.061660288566779374, 'y_loss': 0.15226226362383571}
# [I 2024-02-16 17:21:04,363] Trial 3 finished with value: 0.5150117196648795 and parameters: {'latent_dim': 7, 'lr': 0.006976710972689424, 'batch_size': 79, 'beta': 9.294472119323528, 'wx': 0.9627962108979231, 'wy': 2.974915409762516}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 0.515012, KDL: 0.000017, x_loss: 0.061744, y_loss: 0.153082
# {'epoch': 21, 'average_loss': 0.5150117196648795, 'KLD_loss': 1.6996575192817578e-05, 'x_loss': 0.061743723246229204, 'y_loss': 0.15308237234704303}
# lr = 0.001794821019443689 , batch =  75 , beta=  7.245434713459931 , wx=  10.900182022691734 , wy =  9.778877850437484 , latent_dim =  9
# Train Epoch 1: Average Loss: 4.347868, KDL: 0.084854, x_loss: 0.099470, y_loss: 0.270873
# {'epoch': 1, 'average_loss': 4.347868220023308, 'KLD_loss': 0.08485357688999605, 'x_loss': 0.0994695148568997, 'y_loss': 0.27087272443379956}
# Train Epoch 2: Average Loss: 2.775525, KDL: 0.000010, x_loss: 0.075669, y_loss: 0.199476
# {'epoch': 2, 'average_loss': 2.7755248894219635, 'KLD_loss': 9.736534895031884e-06, 'x_loss': 0.0756689422279373, 'y_loss': 0.199475755554804}
# Train Epoch 3: Average Loss: 2.503506, KDL: 0.000006, x_loss: 0.070099, y_loss: 0.177870
# {'epoch': 3, 'average_loss': 2.50350600936781, 'KLD_loss': 6.49317540507624e-06, 'x_loss': 0.07009893124909147, 'y_loss': 0.17786987760345796}
# Train Epoch 4: Average Loss: 2.419984, KDL: 0.000005, x_loss: 0.067671, y_loss: 0.172037
# {'epoch': 4, 'average_loss': 2.419983910030868, 'KLD_loss': 4.616388674082606e-06, 'x_loss': 0.06767067108498788, 'y_loss': 0.17203689570995284}
# Train Epoch 5: Average Loss: 2.316728, KDL: 0.000004, x_loss: 0.065598, y_loss: 0.163788
# {'epoch': 5, 'average_loss': 2.31672825904443, 'KLD_loss': 4.162249536528581e-06, 'x_loss': 0.06559805350302757, 'y_loss': 0.16378845915622797}
# Train Epoch 6: Average Loss: 2.242488, KDL: 0.000004, x_loss: 0.064131, y_loss: 0.157832
# {'epoch': 6, 'average_loss': 2.2424881553006495, 'KLD_loss': 3.960156726694179e-06, 'x_loss': 0.06413115449584852, 'y_loss': 0.15783182757793515}
# Train Epoch 7: Average Loss: 2.212551, KDL: 0.000004, x_loss: 0.063178, y_loss: 0.155832
# {'epoch': 7, 'average_loss': 2.212551416664467, 'KLD_loss': 4.1218131021044954e-06, 'x_loss': 0.0631784641028925, 'y_loss': 0.15583227192801513}
# Train Epoch 8: Average Loss: 2.156876, KDL: 0.000005, x_loss: 0.061964, y_loss: 0.151492
# {'epoch': 8, 'average_loss': 2.156875826697657, 'KLD_loss': 4.997250737100169e-06, 'x_loss': 0.061964022193936215, 'y_loss': 0.1514918669175798}
# Train Epoch 9: Average Loss: 2.135595, KDL: 0.000004, x_loss: 0.061286, y_loss: 0.150071
# {'epoch': 9, 'average_loss': 2.135594625344341, 'KLD_loss': 4.375110501828401e-06, 'x_loss': 0.06128632764554006, 'y_loss': 0.1500714891932268}
# Train Epoch 10: Average Loss: 2.082172, KDL: 0.000004, x_loss: 0.060522, y_loss: 0.145460
# {'epoch': 10, 'average_loss': 2.0821722705682357, 'KLD_loss': 4.141361102171387e-06, 'x_loss': 0.06052223236943739, 'y_loss': 0.14546033814884554}
# Train Epoch 11: Average Loss: 2.059035, KDL: 0.000004, x_loss: 0.059683, y_loss: 0.144029
# {'epoch': 11, 'average_loss': 2.059034978968093, 'KLD_loss': 4.080728791106766e-06, 'x_loss': 0.0596833271539953, 'y_loss': 0.1440294343011937}
# Train Epoch 12: Average Loss: 2.051356, KDL: 0.000004, x_loss: 0.059615, y_loss: 0.143320
# {'epoch': 12, 'average_loss': 2.0513561595862417, 'KLD_loss': 4.4941634073786475e-06, 'x_loss': 0.05961530495887396, 'y_loss': 0.1433197045601022}
# Train Epoch 13: Average Loss: 2.029250, KDL: 0.000004, x_loss: 0.059009, y_loss: 0.141735
# {'epoch': 13, 'average_loss': 2.0292499713275745, 'KLD_loss': 4.325469751944249e-06, 'x_loss': 0.05900875843972012, 'y_loss': 0.14173532071253886}
# Train Epoch 14: Average Loss: 1.996283, KDL: 0.000004, x_loss: 0.058491, y_loss: 0.138941
# {'epoch': 14, 'average_loss': 1.9962826681280064, 'KLD_loss': 4.261307630581835e-06, 'x_loss': 0.058491151397307775, 'y_loss': 0.13894105043033253}
# Train Epoch 15: Average Loss: 1.976563, KDL: 0.000004, x_loss: 0.057947, y_loss: 0.137531
# {'epoch': 15, 'average_loss': 1.9765626347583274, 'KLD_loss': 4.068865947637601e-06, 'x_loss': 0.05794742258581175, 'y_loss': 0.1375306742894149}
# Train Epoch 16: Average Loss: 1.957659, KDL: 0.000004, x_loss: 0.057456, y_loss: 0.136145
# {'epoch': 16, 'average_loss': 1.9576587489341153, 'KLD_loss': 4.2642789265920015e-06, 'x_loss': 0.05745614246315863, 'y_loss': 0.1361450083788367}
# Train Epoch 17: Average Loss: 1.945238, KDL: 0.000004, x_loss: 0.057024, y_loss: 0.135357
# {'epoch': 17, 'average_loss': 1.945238018947384, 'KLD_loss': 4.406119215077367e-06, 'x_loss': 0.057023908317401846, 'y_loss': 0.13535654098577407}
# Train Epoch 18: Average Loss: 1.932409, KDL: 0.000004, x_loss: 0.056843, y_loss: 0.134246
# {'epoch': 18, 'average_loss': 1.9324085164642049, 'KLD_loss': 4.363113614930206e-06, 'x_loss': 0.05684324398614477, 'y_loss': 0.13424599257813044}
# Train Epoch 19: Average Loss: 1.914223, KDL: 0.000004, x_loss: 0.056503, y_loss: 0.132765
# {'epoch': 19, 'average_loss': 1.9142227791238582, 'KLD_loss': 4.318432471920168e-06, 'x_loss': 0.05650312632512206, 'y_loss': 0.13276544789681727}
# Train Epoch 20: Average Loss: 1.902252, KDL: 0.000004, x_loss: 0.056113, y_loss: 0.131976
# {'epoch': 20, 'average_loss': 1.9022516047936686, 'KLD_loss': 4.210639214408451e-06, 'x_loss': 0.05611331724440274, 'y_loss': 0.13197584713305133}
# [I 2024-02-16 17:23:39,575] Trial 4 finished with value: 1.8997351704151377 and parameters: {'latent_dim': 9, 'lr': 0.001794821019443689, 'batch_size': 75, 'beta': 7.245434713459931, 'wx': 10.900182022691734, 'wy': 9.778877850437484}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 1.899735, KDL: 0.000004, x_loss: 0.055994, y_loss: 0.131851
# {'epoch': 21, 'average_loss': 1.8997351704151377, 'KLD_loss': 4.179362414301425e-06, 'x_loss': 0.05599425304708988, 'y_loss': 0.13185125359821356}
# lr = 0.0057153561823925295 , batch =  195 , beta=  11.143278689761024 , wx=  8.465879583330482 , wy =  7.755994245004194 , latent_dim =  24
# Train Epoch 1: Average Loss: 53.240068, KDL: 4.502075, x_loss: 0.108107, y_loss: 0.278104
# {'epoch': 1, 'average_loss': 53.2400683580551, 'KLD_loss': 4.502075020507065, 'x_loss': 0.10810688364575481, 'y_loss': 0.27810364804769816}
# Train Epoch 2: Average Loss: 2.247982, KDL: 0.000297, x_loss: 0.080186, y_loss: 0.201886
# {'epoch': 2, 'average_loss': 2.247981885488038, 'KLD_loss': 0.0002970637401409781, 'x_loss': 0.0801856120282214, 'y_loss': 0.2018864154234732}
# Train Epoch 3: Average Loss: 2.061517, KDL: 0.000196, x_loss: 0.074525, y_loss: 0.184168
# {'epoch': 3, 'average_loss': 2.061517151940403, 'KLD_loss': 0.00019619287106028774, 'x_loss': 0.07452524042385131, 'y_loss': 0.18416842112415716}
# Train Epoch 4: Average Loss: 1.959327, KDL: 0.000114, x_loss: 0.071585, y_loss: 0.174320
# {'epoch': 4, 'average_loss': 1.959326652987891, 'KLD_loss': 0.00011403983564172339, 'x_loss': 0.0715848798582196, 'y_loss': 0.1743202551066527}
# Train Epoch 5: Average Loss: 1.905877, KDL: 0.000071, x_loss: 0.069421, y_loss: 0.169852
# {'epoch': 5, 'average_loss': 1.9058772829773365, 'KLD_loss': 7.127937052914507e-05, 'x_loss': 0.06942102026201596, 'y_loss': 0.1698522398694914}
# Train Epoch 6: Average Loss: 1.849966, KDL: 0.000043, x_loss: 0.067616, y_loss: 0.164654
# {'epoch': 6, 'average_loss': 1.8499659845935903, 'KLD_loss': 4.297407747012133e-05, 'x_loss': 0.06761631943997119, 'y_loss': 0.16465400211643755}
# Train Epoch 7: Average Loss: 1.799143, KDL: 0.000034, x_loss: 0.066087, y_loss: 0.159784
# {'epoch': 7, 'average_loss': 1.7991434747015524, 'KLD_loss': 3.366308835050051e-05, 'x_loss': 0.06608743810949967, 'y_loss': 0.15978351999328383}
# Train Epoch 8: Average Loss: 1.787750, KDL: 0.000029, x_loss: 0.065448, y_loss: 0.159019
# {'epoch': 8, 'average_loss': 1.7877496790002894, 'KLD_loss': 2.9250543717055292e-05, 'x_loss': 0.06544785180490384, 'y_loss': 0.159018954919328}
# Train Epoch 9: Average Loss: 1.806696, KDL: 0.000026, x_loss: 0.065590, y_loss: 0.161312
# {'epoch': 9, 'average_loss': 1.806695515184607, 'KLD_loss': 2.598413947032906e-05, 'x_loss': 0.06558972663930518, 'y_loss': 0.16131152192286813}
# Train Epoch 10: Average Loss: 1.713570, KDL: 0.000024, x_loss: 0.063421, y_loss: 0.151675
# {'epoch': 10, 'average_loss': 1.7135704514111227, 'KLD_loss': 2.3831168578149747e-05, 'x_loss': 0.06342107035786088, 'y_loss': 0.1516749120478974}
# Train Epoch 11: Average Loss: 1.704868, KDL: 0.000021, x_loss: 0.062904, y_loss: 0.151121
# {'epoch': 11, 'average_loss': 1.7048678300534075, 'KLD_loss': 2.1320279346339652e-05, 'x_loss': 0.06290389586523262, 'y_loss': 0.15112097856187448}
# Train Epoch 12: Average Loss: 1.848024, KDL: 0.000017, x_loss: 0.067172, y_loss: 0.164927
# {'epoch': 12, 'average_loss': 1.848024287883766, 'KLD_loss': 1.6501075343081827e-05, 'x_loss': 0.06717164123877448, 'y_loss': 0.16492706753647582}
# Train Epoch 13: Average Loss: 1.647683, KDL: 0.000013, x_loss: 0.061462, y_loss: 0.145334
# {'epoch': 13, 'average_loss': 1.6476828203796179, 'KLD_loss': 1.285833689669187e-05, 'x_loss': 0.0614624427482631, 'y_loss': 0.14533351411131623}
# Train Epoch 14: Average Loss: 1.643161, KDL: 0.000010, x_loss: 0.061132, y_loss: 0.145116
# {'epoch': 14, 'average_loss': 1.643161361445228, 'KLD_loss': 1.0013638416461312e-05, 'x_loss': 0.06113179936482195, 'y_loss': 0.1451155435998305}
# Train Epoch 15: Average Loss: 1.615508, KDL: 0.000003, x_loss: 0.060233, y_loss: 0.142541
# {'epoch': 15, 'average_loss': 1.6155083746473227, 'KLD_loss': 3.312240567123681e-06, 'x_loss': 0.06023301534921105, 'y_loss': 0.14254084923694937}
# Train Epoch 16: Average Loss: 2.755205, KDL: 0.000002, x_loss: 0.114511, y_loss: 0.230242
# {'epoch': 16, 'average_loss': 2.7552048685955026, 'KLD_loss': 1.7389335595143934e-06, 'x_loss': 0.11451062838933622, 'y_loss': 0.2302415701642371}
# Train Epoch 17: Average Loss: 4.936600, KDL: 0.000015, x_loss: 0.232601, y_loss: 0.382576
# {'epoch': 17, 'average_loss': 4.936599915952478, 'KLD_loss': 1.5096183408770644e-05, 'x_loss': 0.23260108824478024, 'y_loss': 0.38257621121220653}
# Train Epoch 18: Average Loss: 3.123832, KDL: 0.000017, x_loss: 0.130368, y_loss: 0.260440
# {'epoch': 18, 'average_loss': 3.12383189071224, 'KLD_loss': 1.65044448064317e-05, 'x_loss': 0.13036808300378494, 'y_loss': 0.2604395280688362}
# Train Epoch 19: Average Loss: 2.163805, KDL: 0.000023, x_loss: 0.077672, y_loss: 0.194171
# {'epoch': 19, 'average_loss': 2.16380526726706, 'KLD_loss': 2.3146412293581005e-05, 'x_loss': 0.07767155807879236, 'y_loss': 0.19417101606639506}
# Train Epoch 20: Average Loss: 2.016972, KDL: 0.000041, x_loss: 0.072936, y_loss: 0.180382
# {'epoch': 20, 'average_loss': 2.01697190997661, 'KLD_loss': 4.1250887437638254e-05, 'x_loss': 0.07293631111727356, 'y_loss': 0.1803820585182071}
# [I 2024-02-16 17:24:58,922] Trial 5 finished with value: 1.9285078155599376 and parameters: {'latent_dim': 24, 'lr': 0.0057153561823925295, 'batch_size': 195, 'beta': 11.143278689761024, 'wx': 8.465879583330482, 'wy': 7.755994245004194}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 1.928508, KDL: 0.000083, x_loss: 0.070295, y_loss: 0.171800
# {'epoch': 21, 'average_loss': 1.9285078155599376, 'KLD_loss': 8.26442218431023e-05, 'x_loss': 0.07029484860874989, 'y_loss': 0.17179991604059527}
# lr = 0.008737232124792578 , batch =  220 , beta=  12.727223490015403 , wx=  5.7297497637160815 , wy =  3.026909334346587 , latent_dim =  11
# Train Epoch 1: Average Loss: 167.222525, KDL: 12.989298, x_loss: 0.155381, y_loss: 0.335169
# {'epoch': 1, 'average_loss': 167.22252539998883, 'KLD_loss': 12.989297673531942, 'x_loss': 0.1553813357110862, 'y_loss': 0.3351689930473055}
# Train Epoch 2: Average Loss: 1.105796, KDL: 0.006170, x_loss: 0.077934, y_loss: 0.191856
# {'epoch': 2, 'average_loss': 1.1057961293629237, 'KLD_loss': 0.00616983908873338, 'x_loss': 0.07793369118001435, 'y_loss': 0.1918559811599962}
# Train Epoch 3: Average Loss: 1.420789, KDL: 0.034707, x_loss: 0.074025, y_loss: 0.183330
# {'epoch': 3, 'average_loss': 1.420789128607446, 'KLD_loss': 0.03470670908362001, 'x_loss': 0.07402535743274531, 'y_loss': 0.18332967872803027}
# Train Epoch 4: Average Loss: 0.928910, KDL: -0.000006, x_loss: 0.070870, y_loss: 0.172758
# {'epoch': 4, 'average_loss': 0.9289103566945254, 'KLD_loss': -6.080459762405564e-06, 'x_loss': 0.07086953876928968, 'y_loss': 0.17275807290941805}
# Train Epoch 5: Average Loss: 0.901286, KDL: -0.000008, x_loss: 0.068984, y_loss: 0.167209
# {'epoch': 5, 'average_loss': 0.9012863894085308, 'KLD_loss': -8.132235034481509e-06, 'x_loss': 0.06898421491240407, 'y_loss': 0.16720937071265754}
# Train Epoch 6: Average Loss: 0.889686, KDL: -0.000009, x_loss: 0.067788, y_loss: 0.165645
# {'epoch': 6, 'average_loss': 0.889686204967918, 'KLD_loss': -9.115187676398309e-06, 'x_loss': 0.06778825926747951, 'y_loss': 0.16564502064343337}
# Train Epoch 7: Average Loss: 0.863710, KDL: -0.000009, x_loss: 0.066599, y_loss: 0.159311
# {'epoch': 7, 'average_loss': 0.8637097371803535, 'KLD_loss': -8.554380018632491e-06, 'x_loss': 0.06659933504658741, 'y_loss': 0.1593113755459314}
# Train Epoch 8: Average Loss: 0.848796, KDL: -0.000008, x_loss: 0.065411, y_loss: 0.156633
# {'epoch': 8, 'average_loss': 0.8487962515799554, 'KLD_loss': -8.368295627635914e-06, 'x_loss': 0.06541103010812958, 'y_loss': 0.15663301209499547}
# Train Epoch 9: Average Loss: 0.840349, KDL: -0.000009, x_loss: 0.064703, y_loss: 0.155185
# {'epoch': 9, 'average_loss': 0.8403491599219186, 'KLD_loss': -8.69605567429092e-06, 'x_loss': 0.06470255311373826, 'y_loss': 0.15518482661509253}
# Train Epoch 10: Average Loss: 0.840071, KDL: -0.000008, x_loss: 0.064799, y_loss: 0.154907
# {'epoch': 10, 'average_loss': 0.8400713678244706, 'KLD_loss': -7.923160280500139e-06, 'x_loss': 0.0647993622327244, 'y_loss': 0.15490654965678413}
# Train Epoch 11: Average Loss: 0.812682, KDL: -0.000008, x_loss: 0.062987, y_loss: 0.149289
# {'epoch': 11, 'average_loss': 0.8126815163172209, 'KLD_loss': -8.173630787776067e-06, 'x_loss': 0.06298713458927123, 'y_loss': 0.14928925132358467}
# Train Epoch 12: Average Loss: 0.803221, KDL: -0.000008, x_loss: 0.062394, y_loss: 0.147286
# {'epoch': 12, 'average_loss': 0.8032213715406564, 'KLD_loss': -8.09797873863807e-06, 'x_loss': 0.06239411741658882, 'y_loss': 0.14728612935805058}
# Train Epoch 13: Average Loss: 1.051747, KDL: -0.000006, x_loss: 0.080554, y_loss: 0.195008
# {'epoch': 13, 'average_loss': 1.0517470721360092, 'KLD_loss': -6.038867510282076e-06, 'x_loss': 0.08055385686047785, 'y_loss': 0.19500765522102734}
# Train Epoch 14: Average Loss: 0.848149, KDL: -0.000007, x_loss: 0.065973, y_loss: 0.155349
# {'epoch': 14, 'average_loss': 0.8481494528906686, 'KLD_loss': -6.9246842310978815e-06, 'x_loss': 0.06597331625583408, 'y_loss': 0.15534888620559986}
# Train Epoch 15: Average Loss: 0.815071, KDL: -0.000007, x_loss: 0.063316, y_loss: 0.149450
# {'epoch': 15, 'average_loss': 0.8150708763153999, 'KLD_loss': -6.824666327172583e-06, 'x_loss': 0.06331617152625388, 'y_loss': 0.14945010531407135}
# Train Epoch 16: Average Loss: 0.800185, KDL: -0.000005, x_loss: 0.062086, y_loss: 0.146854
# {'epoch': 16, 'average_loss': 0.8001845705640185, 'KLD_loss': -5.2238558674906635e-06, 'x_loss': 0.062085995552959024, 'y_loss': 0.14685403215033668}
# Train Epoch 17: Average Loss: 0.793680, KDL: -0.000005, x_loss: 0.061754, y_loss: 0.145332
# {'epoch': 17, 'average_loss': 0.7936795766537006, 'KLD_loss': -4.8742189512148004e-06, 'x_loss': 0.06175372866647584, 'y_loss': 0.1453324679489974}
# Train Epoch 18: Average Loss: 0.800653, KDL: -0.000005, x_loss: 0.061719, y_loss: 0.147701
# {'epoch': 18, 'average_loss': 0.800652634704506, 'KLD_loss': -4.590212643801511e-06, 'x_loss': 0.061718687079437486, 'y_loss': 0.14770129399967719}
# Train Epoch 19: Average Loss: 0.786427, KDL: -0.000004, x_loss: 0.060944, y_loss: 0.144467
# {'epoch': 19, 'average_loss': 0.7864268255757761, 'KLD_loss': -4.308695321554666e-06, 'x_loss': 0.06094408725480457, 'y_loss': 0.14446659919979807}
# Train Epoch 20: Average Loss: 1.023450, KDL: -0.000002, x_loss: 0.077856, y_loss: 0.190748
# {'epoch': 20, 'average_loss': 1.023449739781055, 'KLD_loss': -1.8678523681975983e-06, 'x_loss': 0.07785624543225372, 'y_loss': 0.19074793716708383}
# [I 2024-02-16 17:26:11,590] Trial 6 finished with value: 0.8010488574321454 and parameters: {'latent_dim': 11, 'lr': 0.008737232124792578, 'batch_size': 220, 'beta': 12.727223490015403, 'wx': 5.7297497637160815, 'wy': 3.026909334346587}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 0.801049, KDL: 0.000000, x_loss: 0.062128, y_loss: 0.147037
# {'epoch': 21, 'average_loss': 0.8010488574321454, 'KLD_loss': 9.287844647418012e-08, 'x_loss': 0.06212849429511762, 'y_loss': 0.14703676366544033}
# lr = 0.008405832889475481 , batch =  159 , beta=  4.9793029695420765 , wx=  9.709499507372238 , wy =  10.920982419612203 , latent_dim =  5
# Train Epoch 1: Average Loss: 17.560784, KDL: 2.440536, x_loss: 0.154519, y_loss: 0.357873
# {'epoch': 1, 'average_loss': 17.560784422915386, 'KLD_loss': 2.4405355178684425, 'x_loss': 0.1545187139880676, 'y_loss': 0.357872505137765}
# Train Epoch 2: Average Loss: 2.902763, KDL: 0.000155, x_loss: 0.077470, y_loss: 0.196850
# {'epoch': 2, 'average_loss': 2.9027625585777392, 'KLD_loss': 0.00015457787081622925, 'x_loss': 0.07747002201827038, 'y_loss': 0.1968502157111615}
# Train Epoch 3: Average Loss: 2.711751, KDL: 0.000086, x_loss: 0.073130, y_loss: 0.183250
# {'epoch': 3, 'average_loss': 2.7117512029001936, 'KLD_loss': 8.629894976775104e-05, 'x_loss': 0.07312971159270913, 'y_loss': 0.1832498714493644}
# Train Epoch 4: Average Loss: 2.589420, KDL: 0.000055, x_loss: 0.070661, y_loss: 0.174258
# {'epoch': 4, 'average_loss': 2.5894196154771816, 'KLD_loss': 5.4621213191264383e-05, 'x_loss': 0.07066073102228024, 'y_loss': 0.17425788837131143}
# Train Epoch 5: Average Loss: 2.509638, KDL: 0.000027, x_loss: 0.068794, y_loss: 0.168625
# {'epoch': 5, 'average_loss': 2.5096384953997664, 'KLD_loss': 2.73247022886534e-05, 'x_loss': 0.06879372048430109, 'y_loss': 0.1686249262814681}
# Train Epoch 6: Average Loss: 2.431393, KDL: 0.000021, x_loss: 0.067150, y_loss: 0.162924
# {'epoch': 6, 'average_loss': 2.4313928163677025, 'KLD_loss': 2.1345427760259146e-05, 'x_loss': 0.06715039214169657, 'y_loss': 0.16292397425597346}
# Train Epoch 7: Average Loss: 2.364364, KDL: 0.000015, x_loss: 0.065786, y_loss: 0.158002
# {'epoch': 7, 'average_loss': 2.364364491737135, 'KLD_loss': 1.5067040256930839e-05, 'x_loss': 0.06578603195580277, 'y_loss': 0.15800227286421437}
# Train Epoch 8: Average Loss: 2.308243, KDL: 0.000014, x_loss: 0.064612, y_loss: 0.153908
# {'epoch': 8, 'average_loss': 2.308243091610543, 'KLD_loss': 1.3796201002427239e-05, 'x_loss': 0.06461231604763358, 'y_loss': 0.15390750559695385}
# Train Epoch 9: Average Loss: 2.313644, KDL: 0.000010, x_loss: 0.064541, y_loss: 0.154467
# {'epoch': 9, 'average_loss': 2.313644369380084, 'KLD_loss': 1.0353535271600622e-05, 'x_loss': 0.06454118453736146, 'y_loss': 0.15446689439454783}
# Train Epoch 10: Average Loss: 2.415873, KDL: 0.000007, x_loss: 0.066123, y_loss: 0.162422
# {'epoch': 10, 'average_loss': 2.4158727080340605, 'KLD_loss': 7.217326490223313e-06, 'x_loss': 0.06612339165707272, 'y_loss': 0.1624223615837969}
# Train Epoch 11: Average Loss: 2.280623, KDL: 0.000006, x_loss: 0.063664, y_loss: 0.152225
# {'epoch': 11, 'average_loss': 2.280622899627079, 'KLD_loss': 5.5226688354686254e-06, 'x_loss': 0.06366444226289213, 'y_loss': 0.1522249082763737}
# Train Epoch 12: Average Loss: 2.271233, KDL: 0.000005, x_loss: 0.062868, y_loss: 0.152073
# {'epoch': 12, 'average_loss': 2.2712330293200544, 'KLD_loss': 4.678396049099241e-06, 'x_loss': 0.06286816867527409, 'y_loss': 0.1520734341350193}
# Train Epoch 13: Average Loss: 2.223780, KDL: 0.000004, x_loss: 0.062148, y_loss: 0.148369
# {'epoch': 13, 'average_loss': 2.223779659582056, 'KLD_loss': 4.0199968886868186e-06, 'x_loss': 0.062148402446498933, 'y_loss': 0.14836850025600773}
# Train Epoch 14: Average Loss: 2.271520, KDL: 0.000004, x_loss: 0.063315, y_loss: 0.151703
# {'epoch': 14, 'average_loss': 2.271519786602742, 'KLD_loss': 3.5175742708821743e-06, 'x_loss': 0.06331539683529606, 'y_loss': 0.15170260428766377}
# Train Epoch 15: Average Loss: 2.200534, KDL: 0.000004, x_loss: 0.061245, y_loss: 0.147044
# {'epoch': 15, 'average_loss': 2.20053402020556, 'KLD_loss': 3.6772464909879504e-06, 'x_loss': 0.061244785684991525, 'y_loss': 0.1470435033707816}
# Train Epoch 16: Average Loss: 2.321138, KDL: 0.000009, x_loss: 0.064234, y_loss: 0.155427
# {'epoch': 16, 'average_loss': 2.321138492070245, 'KLD_loss': 8.667169200976057e-06, 'x_loss': 0.06423378727489132, 'y_loss': 0.15542717353812463}
# Train Epoch 17: Average Loss: 2.180659, KDL: 0.000010, x_loss: 0.060564, y_loss: 0.145826
# {'epoch': 17, 'average_loss': 2.18065899866374, 'KLD_loss': 9.766443734707249e-06, 'x_loss': 0.06056389577438039, 'y_loss': 0.14582619163398713}
# Train Epoch 18: Average Loss: 3.792513, KDL: 0.000023, x_loss: 0.112536, y_loss: 0.247206
# {'epoch': 18, 'average_loss': 3.79251296683222, 'KLD_loss': 2.3027340065693817e-05, 'x_loss': 0.11253562484925615, 'y_loss': 0.24720612379155213}
# Train Epoch 19: Average Loss: 2.584274, KDL: 0.000028, x_loss: 0.072359, y_loss: 0.172289
# {'epoch': 19, 'average_loss': 2.584274409116736, 'KLD_loss': 2.825904536891628e-05, 'x_loss': 0.07235908095498343, 'y_loss': 0.17228882772839127}
# Train Epoch 20: Average Loss: 2.437649, KDL: 0.000029, x_loss: 0.067588, y_loss: 0.163104
# {'epoch': 20, 'average_loss': 2.4376485616868933, 'KLD_loss': 2.90504889192566e-05, 'x_loss': 0.06758772950198957, 'y_loss': 0.1631044566820839}
# [I 2024-02-16 17:27:42,635] Trial 7 finished with value: 2.353407254658746 and parameters: {'latent_dim': 5, 'lr': 0.008405832889475481, 'batch_size': 159, 'beta': 4.9793029695420765, 'wx': 9.709499507372238, 'wy': 10.920982419612203}. Best is trial 2 with value: 0.28168911196109725.
# Train Epoch 21: Average Loss: 2.353407, KDL: 0.000033, x_loss: 0.065338, y_loss: 0.157389
# {'epoch': 21, 'average_loss': 2.353407254658746, 'KLD_loss': 3.3451803916967544e-05, 'x_loss': 0.06533811645899175, 'y_loss': 0.1573887982883969}
# lr = 0.004046866262921888 , batch =  114 , beta=  3.3110216432036994 , wx=  9.89457827920337 , wy =  10.173004018583617 , latent_dim =  20
# Train Epoch 1: Average Loss: 6.126087, KDL: 0.641609, x_loss: 0.104919, y_loss: 0.291318
# {'epoch': 1, 'average_loss': 6.126086814256898, 'KLD_loss': 0.6416089300549926, 'x_loss': 0.10491888625610933, 'y_loss': 0.2913178407453459}
# Train Epoch 2: Average Loss: 2.883209, KDL: 0.000009, x_loss: 0.079044, y_loss: 0.206534
# {'epoch': 2, 'average_loss': 2.8832091609003334, 'KLD_loss': 9.443806081263513e-06, 'x_loss': 0.07904376586844003, 'y_loss': 0.20653419196605682}
# Train Epoch 3: Average Loss: 2.639990, KDL: 0.000008, x_loss: 0.073622, y_loss: 0.187900
# {'epoch': 3, 'average_loss': 2.6399901905744114, 'KLD_loss': 8.306362091273001e-06, 'x_loss': 0.07362160314901271, 'y_loss': 0.1879000505580989}
# Train Epoch 4: Average Loss: 2.522675, KDL: 0.000007, x_loss: 0.070701, y_loss: 0.179209
# {'epoch': 4, 'average_loss': 2.5226753040435375, 'KLD_loss': 7.292709752476025e-06, 'x_loss': 0.07070113279366683, 'y_loss': 0.17920893973804553}
# Train Epoch 5: Average Loss: 2.420755, KDL: 0.000008, x_loss: 0.068471, y_loss: 0.171359
# {'epoch': 5, 'average_loss': 2.420755276104312, 'KLD_loss': 7.940452028244122e-06, 'x_loss': 0.06847115654014645, 'y_loss': 0.1713589971252889}
# Train Epoch 6: Average Loss: 2.341163, KDL: 0.000009, x_loss: 0.067074, y_loss: 0.164894
# {'epoch': 6, 'average_loss': 2.341163249520886, 'KLD_loss': 9.132680697430239e-06, 'x_loss': 0.06707390969309421, 'y_loss': 0.164893768048911}
# Train Epoch 7: Average Loss: 2.303291, KDL: 0.000009, x_loss: 0.066064, y_loss: 0.162154
# {'epoch': 7, 'average_loss': 2.3032913042363923, 'KLD_loss': 8.797116051502271e-06, 'x_loss': 0.06606377486419569, 'y_loss': 0.1621535772920198}
# Train Epoch 8: Average Loss: 2.237425, KDL: 0.000010, x_loss: 0.064726, y_loss: 0.156980
# {'epoch': 8, 'average_loss': 2.237424910340059, 'KLD_loss': 1.0095417906863272e-05, 'x_loss': 0.06472563191586447, 'y_loss': 0.15698004705759278}
# Train Epoch 9: Average Loss: 2.182305, KDL: 0.000010, x_loss: 0.063470, y_loss: 0.152783
# {'epoch': 9, 'average_loss': 2.1823054015772216, 'KLD_loss': 1.0253628185506834e-05, 'x_loss': 0.06346955764317432, 'y_loss': 0.15278347852323756}
# Train Epoch 10: Average Loss: 2.152317, KDL: 0.000011, x_loss: 0.062821, y_loss: 0.150467
# {'epoch': 10, 'average_loss': 2.1523169452888817, 'KLD_loss': 1.0922958476125243e-05, 'x_loss': 0.06282069698264632, 'y_loss': 0.15046651611329484}
# Train Epoch 11: Average Loss: 2.127605, KDL: 0.000013, x_loss: 0.061876, y_loss: 0.148955
# {'epoch': 11, 'average_loss': 2.1276051479482976, 'KLD_loss': 1.2731565701391268e-05, 'x_loss': 0.06187645514794797, 'y_loss': 0.14895517232240196}
# Train Epoch 12: Average Loss: 2.115846, KDL: 0.000016, x_loss: 0.061792, y_loss: 0.147880
# {'epoch': 12, 'average_loss': 2.115846470982719, 'KLD_loss': 1.6417006425271003e-05, 'x_loss': 0.061792149410025136, 'y_loss': 0.14788010033326973}
# Train Epoch 13: Average Loss: 2.095395, KDL: 0.000027, x_loss: 0.061187, y_loss: 0.146455
# {'epoch': 13, 'average_loss': 2.095395402104545, 'KLD_loss': 2.682657068030981e-05, 'x_loss': 0.061186886093407396, 'y_loss': 0.14645508229562795}
# Train Epoch 14: Average Loss: 2.069034, KDL: 0.000028, x_loss: 0.060754, y_loss: 0.144285
# {'epoch': 14, 'average_loss': 2.069034066993175, 'KLD_loss': 2.7960213007307813e-05, 'x_loss': 0.060753928658664906, 'y_loss': 0.14428451877927453}
# Train Epoch 15: Average Loss: 2.047455, KDL: 0.000028, x_loss: 0.060240, y_loss: 0.142663
# {'epoch': 15, 'average_loss': 2.047455096434895, 'KLD_loss': 2.812762195265646e-05, 'x_loss': 0.0602402148814978, 'y_loss': 0.14266291863214997}
# Train Epoch 16: Average Loss: 2.043776, KDL: 0.000028, x_loss: 0.059915, y_loss: 0.142618
# {'epoch': 16, 'average_loss': 2.0437761422984964, 'KLD_loss': 2.7781602733499098e-05, 'x_loss': 0.05991518637483647, 'y_loss': 0.14261752512976358}
# Train Epoch 17: Average Loss: 2.029951, KDL: 0.000026, x_loss: 0.059507, y_loss: 0.141656
# {'epoch': 17, 'average_loss': 2.029950752616743, 'KLD_loss': 2.6280217398815112e-05, 'x_loss': 0.05950656737326082, 'y_loss': 0.14165642179531768}
# Train Epoch 18: Average Loss: 2.008418, KDL: 0.000027, x_loss: 0.059102, y_loss: 0.139933
# {'epoch': 18, 'average_loss': 2.0084180929666227, 'KLD_loss': 2.6771514453757597e-05, 'x_loss': 0.059101950712417146, 'y_loss': 0.13993315766979186}
# Train Epoch 19: Average Loss: 2.019820, KDL: 0.000029, x_loss: 0.059092, y_loss: 0.141062
# {'epoch': 19, 'average_loss': 2.019820259480922, 'KLD_loss': 2.8953465350939635e-05, 'x_loss': 0.05909248212339666, 'y_loss': 0.14106248269082475}
# Train Epoch 20: Average Loss: 1.989566, KDL: 0.000026, x_loss: 0.058554, y_loss: 0.138613
# ...
# {'epoch': 2, 'average_loss': 0.558578298195427, 'KLD_loss': 0.0002504169521197467, 'x_loss': 0.07911207164886971, 'y_loss': 0.21100681908253774}
# Train Epoch 3: Average Loss: 0.504933, KDL: 0.000376, x_loss: 0.073416, y_loss: 0.190195
# {'epoch': 3, 'average_loss': 0.5049327571347286, 'KLD_loss': 0.00037563266888470716, 'x_loss': 0.07341576077288865, 'y_loss': 0.19019490459435423}
# Train Epoch 4: Average Loss: 0.474153, KDL: 0.000414, x_loss: 0.069664, y_loss: 0.178382
# {'epoch': 4, 'average_loss': 0.47415321505685365, 'KLD_loss': 0.0004136625310065041, 'x_loss': 0.06966373175732407, 'y_loss': 0.17838244419982177}
# Train Epoch 5: Average Loss: 0.462103, KDL: 0.000312, x_loss: 0.068151, y_loss: 0.174059
# {'epoch': 5, 'average_loss': 0.4621030248946427, 'KLD_loss': 0.00031184709407913855, 'x_loss': 0.06815084839510806, 'y_loss': 0.17405918950625987}
# Train Epoch 6: Average Loss: 0.443158, KDL: 0.000182, x_loss: 0.066961, y_loss: 0.167082
# {'epoch': 6, 'average_loss': 0.4431578388236498, 'KLD_loss': 0.00018165851702712512, 'x_loss': 0.06696145612519112, 'y_loss': 0.16708193551486647}
# Train Epoch 7: Average Loss: 0.429604, KDL: 0.000141, x_loss: 0.065364, y_loss: 0.162023
# {'epoch': 7, 'average_loss': 0.4296039332386474, 'KLD_loss': 0.00014058021312588257, 'x_loss': 0.06536377140893623, 'y_loss': 0.1620228864217588}
# Train Epoch 8: Average Loss: 0.410791, KDL: 0.000089, x_loss: 0.063541, y_loss: 0.154952
# {'epoch': 8, 'average_loss': 0.41079054206189974, 'KLD_loss': 8.913748700853804e-05, 'x_loss': 0.063541460852248, 'y_loss': 0.15495189100923673}
# Train Epoch 9: Average Loss: 0.413907, KDL: 0.000061, x_loss: 0.063526, y_loss: 0.156243
# {'epoch': 9, 'average_loss': 0.4139068305772235, 'KLD_loss': 6.144049581787396e-05, 'x_loss': 0.06352586590383254, 'y_loss': 0.15624325334186284}
# Train Epoch 10: Average Loss: 0.399205, KDL: 0.000041, x_loss: 0.062371, y_loss: 0.150645
# {'epoch': 10, 'average_loss': 0.39920543987706236, 'KLD_loss': 4.060769304982933e-05, 'x_loss': 0.06237051713809441, 'y_loss': 0.15064486647855507}
# Train Epoch 11: Average Loss: 0.397046, KDL: 0.000022, x_loss: 0.061784, y_loss: 0.149898
# {'epoch': 11, 'average_loss': 0.39704569397677836, 'KLD_loss': 2.206162387776263e-05, 'x_loss': 0.06178418748045751, 'y_loss': 0.14989836346095717}
# Train Epoch 12: Average Loss: 0.389090, KDL: 0.000013, x_loss: 0.061111, y_loss: 0.146866
# {'epoch': 12, 'average_loss': 0.3890899870317307, 'KLD_loss': 1.342643594517954e-05, 'x_loss': 0.061111011485538574, 'y_loss': 0.14686624997868225}
# Train Epoch 13: Average Loss: 0.385011, KDL: 0.000013, x_loss: 0.060625, y_loss: 0.145313
# {'epoch': 13, 'average_loss': 0.38501130436227915, 'KLD_loss': 1.338977768947261e-05, 'x_loss': 0.06062519795178248, 'y_loss': 0.1453128906902573}
# Train Epoch 14: Average Loss: 0.378720, KDL: 0.000008, x_loss: 0.060231, y_loss: 0.142899
# {'epoch': 14, 'average_loss': 0.37871997778964156, 'KLD_loss': 8.142959903663313e-06, 'x_loss': 0.060231296214419354, 'y_loss': 0.14289896218149875}
# Train Epoch 15: Average Loss: 0.373957, KDL: 0.000007, x_loss: 0.059649, y_loss: 0.141089
# {'epoch': 15, 'average_loss': 0.37395662181254286, 'KLD_loss': 6.98136891557577e-06, 'x_loss': 0.05964913982635652, 'y_loss': 0.14108899251466067}
# Train Epoch 16: Average Loss: 0.380069, KDL: 0.000007, x_loss: 0.059844, y_loss: 0.143465
# {'epoch': 16, 'average_loss': 0.38006907386679045, 'KLD_loss': 6.6613787216759624e-06, 'x_loss': 0.05984434297422008, 'y_loss': 0.14346451272077404}
# Train Epoch 17: Average Loss: 0.363591, KDL: 0.000006, x_loss: 0.058718, y_loss: 0.137117
# {'epoch': 17, 'average_loss': 0.36359143529979276, 'KLD_loss': 5.9634027346758776e-06, 'x_loss': 0.05871845716217034, 'y_loss': 0.13711718090333289}
# Train Epoch 18: Average Loss: 0.369266, KDL: 0.000006, x_loss: 0.058646, y_loss: 0.139344
# {'epoch': 18, 'average_loss': 0.3692657250753591, 'KLD_loss': 5.818798508442623e-06, 'x_loss': 0.05864616934682282, 'y_loss': 0.13934421854119905}
# Train Epoch 19: Average Loss: 0.364829, KDL: 0.000005, x_loss: 0.058424, y_loss: 0.137629
# {'epoch': 19, 'average_loss': 0.3648291987852311, 'KLD_loss': 5.367286328418714e-06, 'x_loss': 0.05842418361787505, 'y_loss': 0.13762879656723967}
# Train Epoch 20: Average Loss: 0.361859, KDL: 0.000005, x_loss: 0.058165, y_loss: 0.136490
# {'epoch': 20, 'average_loss': 0.36185858248265135, 'KLD_loss': 4.895905933469674e-06, 'x_loss': 0.05816526008778614, 'y_loss': 0.13649026771456424}
# [I 2024-02-16 17:53:00,878] Trial 27 finished with value: 0.3635785245979336 and parameters: {'latent_dim': 5, 'lr': 0.005015916793804493, 'batch_size': 235, 'beta': 6.514097752864448, 'wx': 0.22372380088661736, 'wy': 2.5555941335995342}. Best is trial 26 with value: 0.03583365828402479.
# Train Epoch 21: Average Loss: 0.363579, KDL: 0.000005, x_loss: 0.058218, y_loss: 0.137159
# {'epoch': 21, 'average_loss': 0.3635785245979336, 'KLD_loss': 4.768021789514962e-06, 'x_loss': 0.05821825956549723, 'y_loss': 0.13715896451137435}
# lr = 0.006269732618356588 , batch =  132 , beta=  8.243667009974889 , wx=  1.534533128950251 , wy =  8.354602380520397 , latent_dim =  8
# Train Epoch 1: Average Loss: 15.580751, KDL: 1.557255, x_loss: 0.115879, y_loss: 0.307069
# {'epoch': 1, 'average_loss': 15.580751267460846, 'KLD_loss': 1.5572553712255408, 'x_loss': 0.11587943513152782, 'y_loss': 0.30706857526207976}
# Train Epoch 2: Average Loss: 1.816198, KDL: -0.000005, x_loss: 0.077659, y_loss: 0.203130
# {'epoch': 2, 'average_loss': 1.816198212647501, 'KLD_loss': -5.220989438663372e-06, 'x_loss': 0.07765938759852682, 'y_loss': 0.2031299860307598}
# Train Epoch 3: Average Loss: 1.695712, KDL: -0.000005, x_loss: 0.073598, y_loss: 0.189454
# {'epoch': 3, 'average_loss': 1.6957119475253968, 'KLD_loss': -4.7531165674053586e-06, 'x_loss': 0.07359792819949441, 'y_loss': 0.18945396962848376}
# Train Epoch 4: Average Loss: 1.558980, KDL: -0.000004, x_loss: 0.070139, y_loss: 0.173723
# {'epoch': 4, 'average_loss': 1.5589797852221767, 'KLD_loss': -4.27722301835435e-06, 'x_loss': 0.07013883352240347, 'y_loss': 0.1737227628503909}
# Train Epoch 5: Average Loss: 1.514529, KDL: -0.000004, x_loss: 0.068006, y_loss: 0.168793
# {'epoch': 5, 'average_loss': 1.514528644902725, 'KLD_loss': -3.513528677907657e-06, 'x_loss': 0.06800609167006683, 'y_loss': 0.16879318337052038}
# Train Epoch 6: Average Loss: 1.454910, KDL: -0.000003, x_loss: 0.066409, y_loss: 0.161950
# {'epoch': 6, 'average_loss': 1.4549097447093369, 'KLD_loss': -3.000519835540047e-06, 'x_loss': 0.0664093421924476, 'y_loss': 0.16194990592809655}
# Train Epoch 7: Average Loss: 1.458793, KDL: -0.000003, x_loss: 0.065819, y_loss: 0.162523
# {'epoch': 7, 'average_loss': 1.4587934534593747, 'KLD_loss': -3.052418338906482e-06, 'x_loss': 0.06581856169809137, 'y_loss': 0.16252332784255136}
# Train Epoch 8: Average Loss: 1.438961, KDL: -0.000002, x_loss: 0.065084, y_loss: 0.160283
# {'epoch': 8, 'average_loss': 1.4389613954876217, 'KLD_loss': -1.993688870231206e-06, 'x_loss': 0.06508356349980139, 'y_loss': 0.16028349580228485}
# Train Epoch 9: Average Loss: 1.391710, KDL: -0.000002, x_loss: 0.063824, y_loss: 0.154859
# {'epoch': 9, 'average_loss': 1.3917097038832693, 'KLD_loss': -1.8164476178252288e-06, 'x_loss': 0.06382376739465309, 'y_loss': 0.15485894659381744}
# Train Epoch 10: Average Loss: 1.380915, KDL: -0.000001, x_loss: 0.063421, y_loss: 0.153640
# {'epoch': 10, 'average_loss': 1.3809149818873343, 'KLD_loss': -8.778710478528508e-07, 'x_loss': 0.06342141176414207, 'y_loss': 0.15363985451434722}
# Train Epoch 11: Average Loss: 1.369394, KDL: -0.000001, x_loss: 0.062774, y_loss: 0.152380
# {'epoch': 11, 'average_loss': 1.3693942277444069, 'KLD_loss': -5.976191296741013e-07, 'x_loss': 0.06277385212009218, 'y_loss': 0.15237954759228198}
# Train Epoch 12: Average Loss: 1.340193, KDL: -0.000000, x_loss: 0.061916, y_loss: 0.149041
# {'epoch': 12, 'average_loss': 1.34019295961687, 'KLD_loss': -1.3273435406445827e-07, 'x_loss': 0.06191634529302177, 'y_loss': 0.14904136026872808}
# Train Epoch 13: Average Loss: 1.485080, KDL: 0.000000, x_loss: 0.066072, y_loss: 0.165620
# {'epoch': 13, 'average_loss': 1.4850803479198416, 'KLD_loss': 2.920470325802121e-07, 'x_loss': 0.06607198324005334, 'y_loss': 0.16561987738574716}
# Train Epoch 14: Average Loss: 1.303181, KDL: 0.000004, x_loss: 0.060760, y_loss: 0.144819
# {'epoch': 14, 'average_loss': 1.3031812515453802, 'KLD_loss': 4.040691657557022e-06, 'x_loss': 0.060760434481037635, 'y_loss': 0.144819456464697}
# Train Epoch 15: Average Loss: 1.358063, KDL: 0.000015, x_loss: 0.062021, y_loss: 0.151146
# {'epoch': 15, 'average_loss': 1.3580630179445472, 'KLD_loss': 1.530345322903354e-05, 'x_loss': 0.062020830800240775, 'y_loss': 0.1511458856370644}
# Train Epoch 16: Average Loss: 1.305158, KDL: 0.000022, x_loss: 0.060359, y_loss: 0.145112
# {'epoch': 16, 'average_loss': 1.3051578695824404, 'KLD_loss': 2.2231903428452624e-05, 'x_loss': 0.060359253560372264, 'y_loss': 0.14511178455519488}
# Train Epoch 17: Average Loss: 1.301388, KDL: 0.000027, x_loss: 0.060075, y_loss: 0.144708
# {'epoch': 17, 'average_loss': 1.3013875339779817, 'KLD_loss': 2.6757610190197786e-05, 'x_loss': 0.060075454163244654, 'y_loss': 0.14470815736220505}
# Train Epoch 18: Average Loss: 1.289182, KDL: 0.000028, x_loss: 0.059812, y_loss: 0.143294
# {'epoch': 18, 'average_loss': 1.2891821751179355, 'KLD_loss': 2.7902208091715708e-05, 'x_loss': 0.05981217762627356, 'y_loss': 0.14329447121528963}
# Train Epoch 19: Average Loss: 1.481391, KDL: 0.000026, x_loss: 0.067447, y_loss: 0.164901
# {'epoch': 19, 'average_loss': 1.4813912014690742, 'KLD_loss': 2.5622291112009014e-05, 'x_loss': 0.0674473508789467, 'y_loss': 0.1649006918505188}
# Train Epoch 20: Average Loss: 1.267052, KDL: 0.000028, x_loss: 0.059164, y_loss: 0.140765
# {'epoch': 20, 'average_loss': 1.2670521722777224, 'KLD_loss': 2.7532942376853923e-05, 'x_loss': 0.05916421495790847, 'y_loss': 0.14076500994431}
# [I 2024-02-16 17:54:43,811] Trial 28 finished with value: 1.2911370732381664 and parameters: {'latent_dim': 8, 'lr': 0.006269732618356588, 'batch_size': 132, 'beta': 8.243667009974889, 'wx': 1.534533128950251, 'wy': 8.354602380520397}. Best is trial 26 with value: 0.03583365828402479.
# Train Epoch 21: Average Loss: 1.291137, KDL: 0.000026, x_loss: 0.059564, y_loss: 0.143576
# {'epoch': 21, 'average_loss': 1.2911370732381664, 'KLD_loss': 2.634446664976256e-05, 'x_loss': 0.059563812561392156, 'y_loss': 0.14357561716382297}
# lr = 0.0045958792731820965 , batch =  233 , beta=  1.0061799916156202 , wx=  0.7591734231492562 , wy =  3.830242784253054 , latent_dim =  5
# Train Epoch 1: Average Loss: 3.393661, KDL: 2.239060, x_loss: 0.104369, y_loss: 0.277144
# {'epoch': 1, 'average_loss': 3.393660862639893, 'KLD_loss': 2.239059641194898, 'x_loss': 0.10436910356200019, 'y_loss': 0.27714418294124826}
# Train Epoch 2: Average Loss: 0.835734, KDL: -0.000008, x_loss: 0.077859, y_loss: 0.202764
# {'epoch': 2, 'average_loss': 0.8357342947361082, 'KLD_loss': -8.430869080299555e-06, 'x_loss': 0.07785888965739761, 'y_loss': 0.2027637415847113}
# Train Epoch 3: Average Loss: 0.779617, KDL: -0.000007, x_loss: 0.073082, y_loss: 0.189059
# {'epoch': 3, 'average_loss': 0.7796166403349056, 'KLD_loss': -6.585273631783419e-06, 'x_loss': 0.07308183936185615, 'y_loss': 0.1890588921169902}
# Train Epoch 4: Average Loss: 0.709250, KDL: -0.000007, x_loss: 0.068988, y_loss: 0.171499
# {'epoch': 4, 'average_loss': 0.7092499066230863, 'KLD_loss': -7.320282071135765e-06, 'x_loss': 0.06898842620295148, 'y_loss': 0.1714990708024003}
# Train Epoch 5: Average Loss: 0.692541, KDL: -0.000007, x_loss: 0.067298, y_loss: 0.167472
# {'epoch': 5, 'average_loss': 0.692540673253148, 'KLD_loss': -7.153527681217637e-06, 'x_loss': 0.06729767303480659, 'y_loss': 0.16747169433984646}
# Train Epoch 6: Average Loss: 0.666856, KDL: -0.000007, x_loss: 0.065469, y_loss: 0.161128
# {'epoch': 6, 'average_loss': 0.6668563426927079, 'KLD_loss': -6.88163347022478e-06, 'x_loss': 0.0654690015454625, 'y_loss': 0.16112840950142507}
# Train Epoch 7: Average Loss: 0.648266, KDL: -0.000007, x_loss: 0.064418, y_loss: 0.156483
# {'epoch': 7, 'average_loss': 0.6482657169186792, 'KLD_loss': -6.991902063059252e-06, 'x_loss': 0.06441813856363296, 'y_loss': 0.1564830824386242}
# Train Epoch 8: Average Loss: 0.642671, KDL: -0.000007, x_loss: 0.063682, y_loss: 0.155168
# {'epoch': 8, 'average_loss': 0.6426709026791328, 'KLD_loss': -6.7016413045483965e-06, 'x_loss': 0.06368170954980129, 'y_loss': 0.15516827631481858}
# Train Epoch 9: Average Loss: 0.626076, KDL: -0.000006, x_loss: 0.062697, y_loss: 0.151031
# {'epoch': 9, 'average_loss': 0.6260757264009742, 'KLD_loss': -6.122991096141727e-06, 'x_loss': 0.062696524484213, 'y_loss': 0.15103072347336038}
# Train Epoch 10: Average Loss: 0.611772, KDL: -0.000006, x_loss: 0.061826, y_loss: 0.147469
# {'epoch': 10, 'average_loss': 0.6117723512095075, 'KLD_loss': -6.443192792493244e-06, 'x_loss': 0.06182564943162508, 'y_loss': 0.14746909306146377}
# Train Epoch 11: Average Loss: 0.603426, KDL: -0.000006, x_loss: 0.060897, y_loss: 0.145474
# {'epoch': 11, 'average_loss': 0.603426401490389, 'KLD_loss': -5.571162977883982e-06, 'x_loss': 0.060896832036764124, 'y_loss': 0.145473998767692}
# Train Epoch 12: Average Loss: 0.601623, KDL: -0.000005, x_loss: 0.060817, y_loss: 0.145019
# {'epoch': 12, 'average_loss': 0.6016227646622547, 'KLD_loss': -4.766846812048624e-06, 'x_loss': 0.060817362610683885, 'y_loss': 0.14501864586112112}
# Train Epoch 13: Average Loss: 0.594387, KDL: -0.000004, x_loss: 0.060274, y_loss: 0.143237
# {'epoch': 13, 'average_loss': 0.5943870506314344, 'KLD_loss': -3.8785296817158544e-06, 'x_loss': 0.060273672042544496, 'y_loss': 0.1432370738234631}
# Train Epoch 14: Average Loss: 0.585509, KDL: -0.000003, x_loss: 0.059639, y_loss: 0.141045
# {'epoch': 14, 'average_loss': 0.5855090216148732, 'KLD_loss': -3.493941107461619e-06, 'x_loss': 0.05963898792343084, 'y_loss': 0.14104489424200944}
# Train Epoch 15: Average Loss: 0.581242, KDL: -0.000003, x_loss: 0.059028, y_loss: 0.140052
# {'epoch': 15, 'average_loss': 0.5812416170225587, 'KLD_loss': -2.871349800464719e-06, 'x_loss': 0.059028167858026746, 'y_loss': 0.1400516642214254}
# Train Epoch 16: Average Loss: 0.563948, KDL: -0.000003, x_loss: 0.058211, y_loss: 0.135699
# {'epoch': 16, 'average_loss': 0.5639476372752079, 'KLD_loss': -3.3106221709140513e-06, 'x_loss': 0.05821090316356615, 'y_loss': 0.1356986528392448}
# Train Epoch 17: Average Loss: 0.575212, KDL: -0.000003, x_loss: 0.058518, y_loss: 0.138579
# {'epoch': 17, 'average_loss': 0.575211829016375, 'KLD_loss': -3.1033227610033613e-06, 'x_loss': 0.05851795977458011, 'y_loss': 0.13857859331508016}
# Train Epoch 18: Average Loss: 0.554958, KDL: -0.000002, x_loss: 0.057539, y_loss: 0.133484
# {'epoch': 18, 'average_loss': 0.5549578855204028, 'KLD_loss': -1.9508738850438317e-06, 'x_loss': 0.05753927893590095, 'y_loss': 0.1334843694124111}
# Train Epoch 19: Average Loss: 0.562766, KDL: -0.000003, x_loss: 0.058089, y_loss: 0.135414
# {'epoch': 19, 'average_loss': 0.5627664689407792, 'KLD_loss': -2.6996745619662974e-06, 'x_loss': 0.05808861169011094, 'y_loss': 0.13541435121103776}
# Train Epoch 20: Average Loss: 0.564462, KDL: -0.000001, x_loss: 0.057752, y_loss: 0.135923
# {'epoch': 20, 'average_loss': 0.5644616846428361, 'KLD_loss': -8.399403372476267e-07, 'x_loss': 0.05775249341372834, 'y_loss': 0.13592307032194248}
# [I 2024-02-16 17:55:55,142] Trial 29 finished with value: 0.5689073343609654 and parameters: {'latent_dim': 5, 'lr': 0.0045958792731820965, 'batch_size': 233, 'beta': 1.0061799916156202, 'wx': 0.7591734231492562, 'wy': 3.830242784253054}. Best is trial 26 with value: 0.03583365828402479.
# Train Epoch 21: Average Loss: 0.568907, KDL: -0.000001, x_loss: 0.058700, y_loss: 0.136896
# {'epoch': 21, 'average_loss': 0.5689073343609654, 'KLD_loss': -5.26946644450343e-07, 'x_loss': 0.05870039578267308, 'y_loss': 0.13689577898313832}
# best trial:
# [0.03583365828402479]
# {'latent_dim': 8, 'lr': 0.004699203904034449, 'batch_size': 232, 'beta': 13.254604785840401, 'wx': 0.2797739476512935, 'wy': 0.1487447727368247}

# %%
study.best_params
# Out:
# {'latent_dim': 8,
#  'lr': 0.004699203904034449,
#  'batch_size': 232,
#  'beta': 13.254604785840401,
#  'wx': 0.2797739476512935,
#  'wy': 0.1487447727368247}

# %% [markdown]
# TRAINING ON BEST PARAMS

# %%
hyperparameters = study.best_params

latent_dim, lr,batch_size, beta,  wx, wy, num_epochs = hyperparameters.values()
num_epochs=50
cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

# update PyTorch DataLoader with current value of batch_size
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
num_samples = 30

x_batch, y_batch = next(iter(dataloader))
y_idx = np.random.randint(batch_size)
given_x = x_batch[y_idx].unsqueeze(0).to(device) 
given_y = y_batch[y_idx].unsqueeze(0).to(device) 

given_y = torch.reshape(given_y, (len(given_y), number_of_points* number_of_functions))


# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

for epoch in range(1, num_epochs + 1):
    epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
    print(epoch_result)
    
    
CVAE_fn.test_cvae(model, validation_loader,beta, wx, wy, functions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 hyperparameters = study.best_params
#
# NameError: name 'study' is not defined

# %% [markdown]
# ## 3. Sample generation of reconstructed X0/X1 pairs and saving results
#
# Download dataset **scoring_dataset.pt** and put them into the **'/data'** folder. Otherwise, change the path to it to your own.
#
# For submission **, we require num_samples to equals 30** for each element of the **scoring_dataset.pt**. Please be sure that all 50 elements from each sample, and only them, were used for sample generation.

# %%
filename_scoring_dataset = f'{data_root}scoring{filename}.pt'
scoring_dataset = CVAE_fn.SignalDataset(torch.load(filename_scoring_dataset))

print(f"Scoring dataset is loaded successfully and has length: {len(scoring_dataset)}")

# create a PyTorch DataLoader from the scoring_dataset
scoring_loader = DataLoader(scoring_dataset, batch_size=len(scoring_dataset), shuffle=True)

num_samples = 30
x_batch, y_batch = next(iter(scoring_loader))
x_out= []
y_out = []
for idx in range(len(y_batch)):
    given_y = y_batch[idx].unsqueeze(0).to(device)
    given_y = torch.reshape(given_y, (len(given_y), number_of_points * number_of_functions))
    x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
    y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points, number_of_functions))
    x_out.append(x_output)
    y_out.append(y_output)
    '''
    Combine all generated samples together.
    Be carefull -  y_output here are GIVEN Y1/Y1. y_hat (aka reconstructed Y1/Y2) always could  be calculated 
    by x_output, so it should not be stored in result file. 
    '''

x_outputs = torch.cat(x_out, dim=0)   
y_outputs = torch.cat(y_out, dim=0) 
x_outputs = x_outputs.cpu()
y_outputs = y_outputs.cpu()


# Save result as TensorDataset before submitting, for example like next: 
# Pay attention the code below doesn't work unless you have comleted generation x_ouputs/y_outputs above.  

ds = data_utils.TensorDataset(x_outputs,y_outputs)
torch.save(ds, 'D:/aiml projects/BH 24-2y/bh2y_final resources/bh2y_final resources/result/result_dataset.pt')
# Out:
# Scoring dataset is loaded successfully and has length: 50

# %% [markdown]
# ## Submission and evaluation
#
# The evaluation of the results will combine in a total score for the Predictive Leader Board the following assessments:
#
#  - Reconstruction error: This measures how close the vector Y1_hat/Y2_hat obtained from the generated X0_hat and X1_hat is to the given Y1/Y2. A low reconstruction error indicates that the CVAE has learned to generate combinations of X0 and X1 that can produce similar signals Y1/Y2.
#
#  - Preservation of the structure: This measures how well the vectors X0_hat and X1_hat have retained the given structure, straight lines with a preserved slope sign. A high level of preservation indicates that the CVAE has learned to generate combinations of X0 and X1 that adhere to the given structure.
#
#  - Diversity of generated combinations: This measures how well the CVAE has covered the solution space by generating diverse combinations of X0_hat and X1_hat that can produce similar signals Y1/Y2. A high level of diversity indicates that the CVAE has generated a wide range of possible combinations of X0 and X1.
#
# Please note that a **higher total score indicates a better solution**.
