# %% [markdown]
# # Two Birds, One Neural Network Challenge - Starter Notebook
#
#
# ## Background
# The original concept for this challenge comes from the difficulties of understanding the Earth using only a limited number of data sources that could be interpreted in a multitude of ways.    McAliley and Li (2021) took an interesting approach to this problem by using generative algorithms to create diverse output models consistent with a series of measurements.   The algorithm produced many potential output solutions that scientists could use to make better predictions or plan future data gathering.
#
# This challenge expands upon the work of McAliley and Li (2021) by asking you to develop a generative neural network that maximizes the diversity of generated outputs consistent with **two** complex conditions.   How many sets of inputs simultaneously satisfy both conditions? How diverse will these sets of solutions be? These are the core questions of the Two Birds, One Neural Network challenge.
#
# ## The Statement of the Problem
#
# In this challenge, we have two given conditions, or models, Y0, Y1 captured by these equations:
#
# $$
# y_1 = \cos(49 \cdot x_0 + 42 \cdot x_1)
# $$
#
# $$
# y_2 = \cos(56 \cdot x_0 + 63 \cdot x_1)
# $$
#
# As you can see, the equations are a function of the vectors X0 (decreasing straight line) and X1 (increasing straight line). Can we generate a complete solution space of combination (X0, X1) simultaneously satisfying functions Y0 and Y1? Can we develop a neural network that can generate the most diverse set of solutions satisfying both conditions?
#
# This Challenge asks you to develop a neural network of arbitrary nature at the participant's choice. This could be any variation of an autoencoder (e.g., CVAE), a generative adversarial network (GAN), or any other network that allows you to generate the desired variety of solutions.
#
# Our example is built on a network type, such as a conditional variational autoencoder (CVAE), in which given functions are used as conditionals.
#
# If you prefer to use the proposed CVAE, then **any changes, including hyperparameters, configuration of layers, loss function, optimizer, etc., are welcomed**.
#
# Again, the Challenge aims **to develop a neural network and find the optimal values for hyperparameters and other constraints** to achieve **a complete space of reconstructed X0/X1**. Remember that X0/X1 should preserve the nature of the provided data, including the sign of the slope, closeness to a straight line, and producing the Y0/Y1 almost match to the given Y1/Y2.
#
# ## Description of provided data
#
# For training and evaluation of NN we are providing:
#  - **train_dataset.pt** (100,000 elements) - to build your solution.
#  - **validation_dataset.pt** (3,000 elements) - to validate your soltuion.
#
# Both dataset have the same structure:
# Each element is tensor structured as a pair of X0/X1 straight lines from 50 points (X0 is descending, X1 is ascending) along as associated tensor of conditional values Y1/Y2 for each pair X0/X1.
#
# For evaluation the **scoring_dataset.pt**  has the same structure but only 50 elements.  This dataset must be used to generate scores on the Predictive Leaderboard as described below.
#
# ## Evaluation process
#
# ### Predictive Scoring Evaluation
#
# Participants must use the provided scoring dataset and all other materials to generate results. Specifically, all 50 elements from the scoring dataset must be utilized to generate 30 samples for each element. The shape of the resulting dataset will be a threshold scoring criteria, ensuring the presence of all 50 elements.
#
# During the Predictive Scoring calculation, the '"nature of data" will be investigated, which includes the following criteria:
#  - X0 should exhibit a descending pattern, and X1 should show an ascending pattern.
#  - X0 and X1 should closely resemble straight lines (i.e., Pearson Coefficient) with a goodness of fit greater than 0.8.
#  - Reconstructed Y1/Y2, computed as functions on reconstructed X0/X1, should closely match the provided Y1/Y2 values.  The RMSE should be less than 0.1.
#
# All the abovementioned requirements are mandatory and will be assessed for the entire result. The score will be set to 0 if these criteria are not met. In all other cases, the score will be calculated as a coverage score within the [0,1] interval.
#
#
# ### Final Scoring Evaluation
#
# The best submissions on the Predictive Leaderboard will be invited to the Final Evaluation process.   Please ensure that your code is runnable, easy to follow, and reproducible. We offer the following recommendations:
#
#  -  Create a notebook with a clear and easily followable pipeline.
#  -  Include a reasonable amount of comments and descriptions to help us fully understand the brilliance of your solution.
#  - Explicitly set seeds for the training process (code example for this can be found below) to ensure the Judges can reproduce your results; otherwise, your solution may be disqualified.
#
# For the Final Evaluation, 100 X0/X1 samples will be generated on a larger scoring dataset containing 1000 elements. **Please note that the final_scoring_dataset is fixed and will be the same for all provided submissions**.
#
# The Final Assessment will be calculated using the following formula:
#
#
# $$
# \text{FinalAssessment} = 0.3 \cdot \text{LiveScoring} + 0.65 \cdot \text{FinalScoring} + 0.05 \cdot \text{Interpretability}
# $$
#
#
# The interpretability criterion will focus on the extent of documentation, including docstrings and markdown, clear variable naming, and adherence to standard Python style guidelines.
#
# ## Provided functionality
#
# Below, a quick start for this challenge is provided using CVAE. The architecture of the CVAE is provided in a separate file, **CVAE_example.py**, along with a configuration file, **config_model.yaml**. Functions for training, testing, plotting, and sample generation are also provided separately in the **CVAE_function.py** module.
# ## 0. Environment & settings

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, TensorDataset  

import torch.utils.data as data_utils


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import yaml


# Module with CVAE antares architecture
import CVAE_example as CVAE 

#Module w/ith all related CVAE functions: train, test, etc.
import CVAE_functions as CVAE_fn


# setup device cuda vs. cpu
cuda = torch.cuda.is_available()

# device = torch.device("mps")
device = torch.device("cuda")

def f_y_0(x0, x1):
    return np.cos(49 * x0 + 63 * x1)


def f_y_1(x0, x1):
    return np.cos(4 * x0 + 8 * x1)

functions = [f_y_0, f_y_1]

# %%
device
# Out:
# device(type='cuda')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Nov__3_17:51:05_Pacific_Daylight_Time_2023
# Cuda compilation tools, release 12.3, V12.3.103
# Build cuda_12.3.r12.3/compiler.33492891_0

# %% [markdown]
# ## 1. Prepare Dataset
# ### 1.1. Load Dataset
#
# Download datasets: **test_dataset.pt** and **validation_dataset.pt** and put them into the **'/data'** folder. Otherwise, edit the following hardcoded path to your own.

# %%
data_root = 'D:/aiml projects/BH 24-2y/bh2y_final resources/bh2y_final resources/data_2/'  #edit it for you own path to datasets
filename = "_dataset" 

filename_dataset = f'{data_root}train{filename}.pt'
filename_validation_dataset = f'{data_root}validation{filename}.pt'

dataset = CVAE_fn.SignalDataset(torch.load(filename_dataset))
dataset_validation = CVAE_fn.SignalDataset(torch.load(filename_validation_dataset))

print(f"Train dataset is loaded successfully and has length: {len(dataset)}")
print(f"Validation dataset is loaded successfully and has length: {len(dataset_validation)}")

# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = 100, shuffle=True)

# create a PyTorch DataLoader from the dataset_test
validation_loader = DataLoader(dataset_validation, batch_size=100, shuffle=True)
# Out:
# Train dataset is loaded successfully and has length: 100000
# Validation dataset is loaded successfully and has length: 3000

# %% [markdown]
# ### 1.2. Plot Random Samples

# %%
x,y = next(iter(dataloader))        
num_samples = 30

CVAE_fn.plot_samples(x, y, num_samples = num_samples)

# %% [markdown]
# ## 2. Model setup and train
# ### 2.1. Define the model and optimizer
#
# Here, we invite you to create your own neural network instead of the provided example or upgrade the suggested CVAE with any other possible changes, including (but not limited to) the loss function, optimizer, and hyperparameters.

# %%
number_of_functions = len(functions)

# Customize your Model’s Architecture Based on next dictionary 
model_parameters = {
    "number_of_points": 50,
    "number_of_inputs": 2,
    "number_of_functions": number_of_functions, 
    "bias": True,
    "in_channels1": 1,
    "out_channels1": 16 ,
    "kernel_size1": [6, 2],
    "out_channels2": 64,
    "kernel_size2": [4, 1],
    "out_channels3": 64,
    "kernel_size3": [4, 1]
}

with open('config_model.yaml', 'w') as f:
    yaml.dump(model_parameters, f)
    
    
# Define the input dimensions
number_of_points = 50
number_of_inputs = model_parameters['number_of_inputs']
number_of_functions = model_parameters['number_of_functions']
input_shape = (1, number_of_points, number_of_inputs)
cond_shape = (number_of_points, number_of_functions)


# Define initial state of hyperparameters
hyperparameters = {
    'latent_dim': 8,
    'lr': 0.004699203904034449,
    'beta': 13.254604785840401,
    'wx': 0.2797739476512935,
    'wy': 0.1487447727368247,
    'batch_size': 232,
    "epoch":50
    }



latent_dim, lr, beta,  wx, wy,batch_size, num_epochs = hyperparameters.values()

cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

print("Current CVAE configuration: ")
model
# Out:
# c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Current CVAE configuration:
# CVAE(
#   (encoder): Encoder(
#     (conv1): Conv2d(1, 16, kernel_size=(6, 2), stride=(1, 1))
#     (conv2): Conv2d(16, 64, kernel_size=(4, 1), stride=(1, 1))
#     (fc1_mean): Linear(in_features=2688, out_features=8, bias=True)
#     (fc1_logvar): Linear(in_features=2688, out_features=8, bias=True)
#   )
#   (sampling): Sampling()
#   (decoder): Decoder(
#     (fc1): LazyLinear(in_features=0, out_features=2688, bias=True)
#     (conv_transpose2): ConvTranspose2d(64, 16, kernel_size=(4, 1), stride=(1, 1))
#     (conv_transpose3): ConvTranspose2d(16, 1, kernel_size=(6, 2), stride=(1, 1))
#     (relu): ReLU()
#   )
# )

# %% [markdown]
# ### 2.2. Generate samples from the untrained model

# %%
# update PyTorch DataLoader with current value of batch_size
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
num_samples = 30

x_batch, y_batch = next(iter(dataloader))
y_idx = np.random.randint(batch_size)
given_x = x_batch[y_idx].unsqueeze(0).to(device) 
given_y = y_batch[y_idx].unsqueeze(0).to(device) 

given_y = torch.reshape(given_y, (len(given_y), number_of_points* number_of_functions))

x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points, number_of_functions))

CVAE_fn.plot_samples_stacked(given_x, x_output.cpu(), y_output.cpu(),fun_list = functions)

# %% [markdown]
# ### 2.3. Train & validate model

# %%
# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

for epoch in range(1, num_epochs + 1):
    epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
    print(epoch_result)
    
    
CVAE_fn.test_cvae(model, validation_loader,beta, wx, wy, functions)
# Out:
# Train Epoch 1: Average Loss: 44.420743, KDL: 3.341201, x_loss: 0.165447, y_loss: 0.592687
# {'epoch': 1, 'average_loss': 44.42074346871771, 'KLD_loss': 3.3412009584544986, 'x_loss': 0.1654467993174438, 'y_loss': 0.5926872497355496}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       9 np.random.seed(random_seed)
#      11 for epoch in range(1, num_epochs + 1):
# ---> 12     epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
#      13     print(epoch_result)
#      16 CVAE_fn.test_cvae(model, validation_loader,beta, wx, wy, functions)
#
# File d:\aiml projects\BH 24-2y\CVAE_functions.py:72, in train_cvae(cvae, train_loader, optimizer, beta, wx, wy, epoch, fun_list, step_to_print)
#      69 recon_loss = 0.0
#      70 cond_loss = 0.0
# ---> 72 for batch_idx, (data, cond_data) in enumerate(train_loader):
#      73     Nw = data.size(-2)
#      74     cond_data = torch.reshape(cond_data, (len(cond_data), Nw * len(fun_list)))
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\collate.py:265, in default_collate(batch)
#     204 def default_collate(batch):
#     205     r"""
#     206         Function that takes in a batch of data and puts the elements within the batch
#     207         into a tensor with an additional outer dimension - batch size. The exact output type can be
#    (...)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\collate.py:142, in collate(batch, collate_fn_map)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\collate.py:142, in <listcomp>(.0)
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
# --> 142     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     143 else:
#     144     try:
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\collate.py:119, in collate(batch, collate_fn_map)
#     117 if collate_fn_map is not None:
#     118     if elem_type in collate_fn_map:
# --> 119         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     121     for collate_type in collate_fn_map:
#     122         if isinstance(elem, collate_type):
#
# File c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\utils\data\_utils\collate.py:162, in collate_tensor_fn(batch, collate_fn_map)
#     160     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     161     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 162 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points
                                    , number_of_functions))

CVAE_fn.plot_samples_stacked(given_x, x_output.cpu(), y_output.cpu(),fun_list = functions)

# %% [markdown]
# ### 2.4. Hyperparameter's tuning process

# %%
import optuna


number_of_functions = len(functions)

# Customize your Model’s Architecture Based on next dictionary 
model_parameters = {
    "number_of_points": 50,
    "number_of_inputs": 2,
    "number_of_functions": number_of_functions, 
    "bias": True,
    "in_channels1": 1,
    "out_channels1": 16,
    "kernel_size1": [6, 2],
    "out_channels2": 64,
    "kernel_size2": [4, 1]
}

with open('config_model.yaml', 'w') as f:
    yaml.dump(model_parameters, f)
    
    
# Define the input dimensions
number_of_points = 50
number_of_inputs = model_parameters['number_of_inputs']
number_of_functions = model_parameters['number_of_functions']
input_shape = (1, number_of_points, number_of_inputs)
cond_shape = (number_of_points, number_of_functions)


cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

model
# Out:
# c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# CVAE(
#   (encoder): Encoder(
#     (conv1): Conv2d(1, 16, kernel_size=(6, 2), stride=(1, 1))
#     (conv2): Conv2d(16, 64, kernel_size=(4, 1), stride=(1, 1))
#     (fc1_mean): Linear(in_features=2688, out_features=8, bias=True)
#     (fc1_logvar): Linear(in_features=2688, out_features=8, bias=True)
#   )
#   (sampling): Sampling()
#   (decoder): Decoder(
#     (fc1): LazyLinear(in_features=0, out_features=2688, bias=True)
#     (conv_transpose2): ConvTranspose2d(64, 16, kernel_size=(4, 1), stride=(1, 1))
#     (conv_transpose3): ConvTranspose2d(16, 1, kernel_size=(6, 2), stride=(1, 1))
#     (relu): ReLU()
#   )
# )

# %%
import optuna

def training_with_optuna( lr, batch_size, beta, wx, wy,num_epochs, latent_dim):

    print("lr =" , lr , ", batch = " , batch_size ,  ", beta= " , beta, ", wx= ", wx , ", wy = ", wy , ", latent_dim = " , latent_dim)
    
    cvae = CVAE.CVAE(latent_dim).to(device)

    model = cvae
    optimizer = optim.Adam(model.parameters(), lr = lr)
    dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)

    for epoch in range(1, num_epochs + 1):
        epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
        print(epoch_result)
    
    return(epoch_result["average_loss"])


def objective(trial):
    params = {
    "latent_dim": trial.suggest_int("latent_dim", 3,25),
    "lr" : trial.suggest_float("lr", 1e-4, 0.01),
    "batch_size" : trial.suggest_int("batch_size", 64,256),
    # "batch_size": 128,
    "beta" : trial.suggest_float("beta", 1,15),
    "wx": trial.suggest_float("wx", 0.1, 11),
    "wy": trial.suggest_float("wy",0.1,11),
    "epoch":21
    }

    return training_with_optuna(params["lr"],params["batch_size"] , params["beta"], params["wx"], params["wy"], params["epoch"],params["latent_dim"])

# %%
study=optuna.create_study(directions=["minimize"])
study.optimize(objective, n_trials=10)

print("best trial:")
trial_ = study.best_trial

print(trial_.values)
print(trial_.params)
# Out:
# [I 2024-02-16 19:59:08,469] A new study created in memory with name: no-name-ffb9cc70-848c-49e9-9ca1-2cc842446996
# lr = 0.00615003001845609 , batch =  133 , beta=  5.266269669996161 , wx=  8.10794713357333 , wy =  10.329797571831925 , latent_dim =  18
# Train Epoch 1: Average Loss: 14.114779, KDL: 1.279967, x_loss: 0.166744, y_loss: 0.582991
# {'epoch': 1, 'average_loss': 14.11477916735284, 'KLD_loss': 1.2799668795964185, 'x_loss': 0.1667438137662062, 'y_loss': 0.5829909451781435}
# Train Epoch 2: Average Loss: 6.947096, KDL: 0.000037, x_loss: 0.144967, y_loss: 0.558725
# {'epoch': 2, 'average_loss': 6.947096069442465, 'KLD_loss': 3.7161157803332554e-05, 'x_loss': 0.14496742230542797, 'y_loss': 0.5587246024862249}
# Train Epoch 3: Average Loss: 6.927739, KDL: 0.000043, x_loss: 0.142776, y_loss: 0.558567
# {'epoch': 3, 'average_loss': 6.927739334867356, 'KLD_loss': 4.318439738547548e-05, 'x_loss': 0.14277641490062185, 'y_loss': 0.5585673983268281}
# Train Epoch 4: Average Loss: 6.920716, KDL: 0.000028, x_loss: 0.141363, y_loss: 0.559004
# {'epoch': 4, 'average_loss': 6.920715838670731, 'KLD_loss': 2.8155189245305164e-05, 'x_loss': 0.14136331177693098, 'y_loss': 0.5590042926846667}
# Train Epoch 5: Average Loss: 6.933227, KDL: 0.000019, x_loss: 0.140738, y_loss: 0.560711
# {'epoch': 5, 'average_loss': 6.933227182068723, 'KLD_loss': 1.9156274960396137e-05, 'x_loss': 0.14073800891043342, 'y_loss': 0.5607108748022546}
# Train Epoch 6: Average Loss: 6.908238, KDL: 0.000015, x_loss: 0.139826, y_loss: 0.559010
# {'epoch': 6, 'average_loss': 6.908238300617705, 'KLD_loss': 1.5303056607855128e-05, 'x_loss': 0.13982555271185776, 'y_loss': 0.5590099276221813}
# Train Epoch 7: Average Loss: 6.908870, KDL: 0.000014, x_loss: 0.139239, y_loss: 0.559532
# {'epoch': 7, 'average_loss': 6.90887000522715, 'KLD_loss': 1.351067677457282e-05, 'x_loss': 0.13923943462841054, 'y_loss': 0.5595320444157783}
# Train Epoch 8: Average Loss: 6.900735, KDL: 0.000012, x_loss: 0.138810, y_loss: 0.559082
# {'epoch': 8, 'average_loss': 6.900735116385399, 'KLD_loss': 1.185625157457717e-05, 'x_loss': 0.138810279689967, 'y_loss': 0.5590822179108224}
# Train Epoch 9: Average Loss: 6.897578, KDL: 0.000009, x_loss: 0.138349, y_loss: 0.559140
# {'epoch': 9, 'average_loss': 6.897578229929539, 'KLD_loss': 9.22548327040165e-06, 'x_loss': 0.13834897106751165, 'y_loss': 0.5591400348918235}
# Train Epoch 10: Average Loss: 6.908319, KDL: 0.000008, x_loss: 0.138335, y_loss: 0.560191
# {'epoch': 10, 'average_loss': 6.908319422539244, 'KLD_loss': 8.38935375213623e-06, 'x_loss': 0.138334863214813, 'y_loss': 0.5601913598465159}
# Train Epoch 11: Average Loss: 6.886961, KDL: 0.000009, x_loss: 0.137601, y_loss: 0.558699
# {'epoch': 11, 'average_loss': 6.886960964253608, 'KLD_loss': 9.320636696003853e-06, 'x_loss': 0.13760105586868335, 'y_loss': 0.5586992045666309}
# Train Epoch 12: Average Loss: 6.889642, KDL: 0.000011, x_loss: 0.137558, y_loss: 0.558992
# {'epoch': 12, 'average_loss': 6.889641837236729, 'KLD_loss': 1.1304591564421958e-05, 'x_loss': 0.1375577312279889, 'y_loss': 0.5589917251404296}
# Train Epoch 13: Average Loss: 6.901318, KDL: 0.000018, x_loss: 0.137371, y_loss: 0.560266
# {'epoch': 13, 'average_loss': 6.901317639553801, 'KLD_loss': 1.754255053844858e-05, 'x_loss': 0.137370826072119, 'y_loss': 0.5602655500332092}
# Train Epoch 14: Average Loss: 6.881684, KDL: 0.000040, x_loss: 0.136874, y_loss: 0.558743
# {'epoch': 14, 'average_loss': 6.881684052817365, 'KLD_loss': 4.045110433659655e-05, 'x_loss': 0.1368736632643862, 'y_loss': 0.5587434238417351}
# Train Epoch 15: Average Loss: 6.897744, KDL: 0.000055, x_loss: 0.137302, y_loss: 0.559954
# {'epoch': 15, 'average_loss': 6.897744239010709, 'KLD_loss': 5.471226858331802e-05, 'x_loss': 0.13730244358327795, 'y_loss': 0.5599543444336729}
# Train Epoch 16: Average Loss: 6.901452, KDL: 0.000054, x_loss: 0.136954, y_loss: 0.560587
# {'epoch': 16, 'average_loss': 6.901451826729673, 'KLD_loss': 5.41906883107855e-05, 'x_loss': 0.13695367132412625, 'y_loss': 0.5605872866321118}
# Train Epoch 17: Average Loss: 6.888594, KDL: 0.000055, x_loss: 0.136658, y_loss: 0.559574
# {'epoch': 17, 'average_loss': 6.888594427641402, 'KLD_loss': 5.4808769454347326e-05, 'x_loss': 0.1366582317376866, 'y_loss': 0.5595741734859792}
# Train Epoch 18: Average Loss: 6.884286, KDL: 0.000055, x_loss: 0.136494, y_loss: 0.559286
# {'epoch': 18, 'average_loss': 6.884285966132549, 'KLD_loss': 5.528473473609762e-05, 'x_loss': 0.13649389354829142, 'y_loss': 0.5592858309441424}
# Train Epoch 19: Average Loss: 6.897751, KDL: 0.000055, x_loss: 0.136693, y_loss: 0.560433
# {'epoch': 19, 'average_loss': 6.897750560273516, 'KLD_loss': 5.466827845319788e-05, 'x_loss': 0.1366933736890713, 'y_loss': 0.5604330439992408}
# Train Epoch 20: Average Loss: 6.882518, KDL: 0.000055, x_loss: 0.136450, y_loss: 0.559149
# {'epoch': 20, 'average_loss': 6.88251816909364, 'KLD_loss': 5.498631520474211e-05, 'x_loss': 0.1364498151704035, 'y_loss': 0.5591494461640398}
# [I 2024-02-16 20:00:55,536] Trial 0 finished with value: 6.877091762233288 and parameters: {'latent_dim': 18, 'lr': 0.00615003001845609, 'batch_size': 133, 'beta': 5.266269669996161, 'wx': 8.10794713357333, 'wy': 10.329797571831925}. Best is trial 0 with value: 6.877091762233288.
# Train Epoch 21: Average Loss: 6.877092, KDL: 0.000054, x_loss: 0.135983, y_loss: 0.558991
# {'epoch': 21, 'average_loss': 6.877091762233288, 'KLD_loss': 5.4040923714637756e-05, 'x_loss': 0.13598272694829613, 'y_loss': 0.5589912325302338}
# lr = 0.0036066471382456876 , batch =  154 , beta=  3.781515951459095 , wx=  5.846547247598992 , wy =  0.7958775399235891 , latent_dim =  5
# Train Epoch 1: Average Loss: 7.152952, KDL: 1.524933, x_loss: 0.158101, y_loss: 0.580547
# {'epoch': 1, 'average_loss': 7.152952035757211, 'KLD_loss': 1.5249333574680182, 'x_loss': 0.15810144694951864, 'y_loss': 0.5805472650894752}
# Train Epoch 2: Average Loss: 1.285675, KDL: 0.000052, x_loss: 0.143614, y_loss: 0.560178
# {'epoch': 2, 'average_loss': 1.2856746246264532, 'KLD_loss': 5.203875211568979e-05, 'x_loss': 0.14361376920571695, 'y_loss': 0.5601781207781572}
# Train Epoch 3: Average Loss: 1.270378, KDL: 0.000247, x_loss: 0.141016, y_loss: 0.559112
# {'epoch': 3, 'average_loss': 1.2703778252234825, 'KLD_loss': 0.00024716441447918233, 'x_loss': 0.14101636778849821, 'y_loss': 0.5591115699364588}
# Train Epoch 4: Average Loss: 1.263537, KDL: -0.000003, x_loss: 0.139973, y_loss: 0.559369
# {'epoch': 4, 'average_loss': 1.2635374159079331, 'KLD_loss': -2.7782183427077072e-06, 'x_loss': 0.13997303594763463, 'y_loss': 0.5593686965795663}
# Train Epoch 5: Average Loss: 1.252127, KDL: -0.000003, x_loss: 0.138412, y_loss: 0.556500
# {'epoch': 5, 'average_loss': 1.252127247773684, 'KLD_loss': -3.168903864347018e-06, 'x_loss': 0.13841213975961392, 'y_loss': 0.5565003694937779}
# Train Epoch 6: Average Loss: 1.247508, KDL: -0.000002, x_loss: 0.137563, y_loss: 0.556931
# {'epoch': 6, 'average_loss': 1.2475077630923344, 'KLD_loss': -2.453052080594576e-06, 'x_loss': 0.13756294847680972, 'y_loss': 0.5569308932010945}
# Train Epoch 7: Average Loss: 1.242569, KDL: -0.000001, x_loss: 0.136775, y_loss: 0.556507
# {'epoch': 7, 'average_loss': 1.2425687120510982, 'KLD_loss': -1.422441922701322e-06, 'x_loss': 0.13677514942792746, 'y_loss': 0.5565074116450089}
# Train Epoch 8: Average Loss: 1.238106, KDL: -0.000001, x_loss: 0.136118, y_loss: 0.555727
# {'epoch': 8, 'average_loss': 1.2381056945140545, 'KLD_loss': -1.4273936931903545e-06, 'x_loss': 0.13611805362197069, 'y_loss': 0.5557268140866206}
# Train Epoch 9: Average Loss: 1.236184, KDL: -0.000001, x_loss: 0.135762, y_loss: 0.555923
# {'epoch': 9, 'average_loss': 1.236184495779184, 'KLD_loss': -7.393268438485952e-07, 'x_loss': 0.13576234000233503, 'y_loss': 0.5559226905382596}
# Train Epoch 10: Average Loss: 1.231398, KDL: -0.000001, x_loss: 0.135047, y_loss: 0.555166
# {'epoch': 10, 'average_loss': 1.2313984377567584, 'KLD_loss': -5.717002428494966e-07, 'x_loss': 0.13504659740970684, 'y_loss': 0.5551662062681638}
# Train Epoch 11: Average Loss: 1.230509, KDL: -0.000000, x_loss: 0.134922, y_loss: 0.554960
# {'epoch': 11, 'average_loss': 1.2305088184430049, 'KLD_loss': -8.725203000582181e-08, 'x_loss': 0.13492217163626966, 'y_loss': 0.5549601601637327}
# Train Epoch 12: Average Loss: 1.228448, KDL: 0.000000, x_loss: 0.134626, y_loss: 0.554546
# {'epoch': 12, 'average_loss': 1.228447967859415, 'KLD_loss': 1.2700374309833233e-07, 'x_loss': 0.13462588738936646, 'y_loss': 0.5545462479041173}
# Train Epoch 13: Average Loss: 1.224174, KDL: 0.000001, x_loss: 0.134072, y_loss: 0.553240
# {'epoch': 13, 'average_loss': 1.2241739643537082, 'KLD_loss': 7.909994858961839e-07, 'x_loss': 0.13407218534212845, 'y_loss': 0.5532404328309573}
# Train Epoch 14: Average Loss: 1.224987, KDL: 0.000001, x_loss: 0.134061, y_loss: 0.554338
# {'epoch': 14, 'average_loss': 1.224986680654379, 'KLD_loss': 1.21460511134221e-06, 'x_loss': 0.1340614488377021, 'y_loss': 0.5543384481393374}
# Train Epoch 15: Average Loss: 1.223322, KDL: 0.000002, x_loss: 0.133761, y_loss: 0.554452
# {'epoch': 15, 'average_loss': 1.2233216381072998, 'KLD_loss': 1.7889187886164739e-06, 'x_loss': 0.13376077559131844, 'y_loss': 0.554452398098432}
# Train Epoch 16: Average Loss: 1.220999, KDL: 0.000002, x_loss: 0.133443, y_loss: 0.553871
# {'epoch': 16, 'average_loss': 1.2209991456912115, 'KLD_loss': 2.0666305835430437e-06, 'x_loss': 0.13344254090235783, 'y_loss': 0.553870687026244}
# Train Epoch 17: Average Loss: 1.217545, KDL: 0.000003, x_loss: 0.133023, y_loss: 0.552609
# {'epoch': 17, 'average_loss': 1.217544615818904, 'KLD_loss': 2.7658389164851262e-06, 'x_loss': 0.13302301158125585, 'y_loss': 0.5526087119029118}
# Train Epoch 18: Average Loss: 1.218105, KDL: 0.000004, x_loss: 0.133027, y_loss: 0.553280
# {'epoch': 18, 'average_loss': 1.2181048092475304, 'KLD_loss': 3.5304748094998874e-06, 'x_loss': 0.13302699090196538, 'y_loss': 0.5532797188942249}
# Train Epoch 19: Average Loss: 1.216297, KDL: 0.000005, x_loss: 0.132812, y_loss: 0.552579
# {'epoch': 19, 'average_loss': 1.216296777175023, 'KLD_loss': 4.973228161151593e-06, 'x_loss': 0.13281222196725698, 'y_loss': 0.5525788172391745}
# Train Epoch 20: Average Loss: 1.218431, KDL: 0.000007, x_loss: 0.133021, y_loss: 0.553718
# {'epoch': 20, 'average_loss': 1.218430830515348, 'KLD_loss': 7.2448987227219805e-06, 'x_loss': 0.13302072513561983, 'y_loss': 0.553717732337805}
# [I 2024-02-16 20:02:33,862] Trial 1 finished with value: 1.2156213927268982 and parameters: {'latent_dim': 5, 'lr': 0.0036066471382456876, 'batch_size': 154, 'beta': 3.781515951459095, 'wx': 5.846547247598992, 'wy': 0.7958775399235891}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 1.215621, KDL: 0.000008, x_loss: 0.132576, y_loss: 0.553452
# {'epoch': 21, 'average_loss': 1.2156213927268982, 'KLD_loss': 7.595236484821026e-06, 'x_loss': 0.13257609899227435, 'y_loss': 0.5534523232166584}
# lr = 0.0076997026256870075 , batch =  140 , beta=  7.24850493619921 , wx=  3.130902906025629 , wy =  5.044847172243226 , latent_dim =  22
# Train Epoch 1: Average Loss: 19.459007, KDL: 2.208243, x_loss: 0.164256, y_loss: 0.582431
# {'epoch': 1, 'average_loss': 19.45900669531389, 'KLD_loss': 2.208243065989101, 'x_loss': 0.1642557897351005, 'y_loss': 0.582431186495961}
# Train Epoch 2: Average Loss: 3.299049, KDL: 0.003513, x_loss: 0.145720, y_loss: 0.558460
# {'epoch': 2, 'average_loss': 3.299048876262211, 'KLD_loss': 0.0035132220575025863, 'x_loss': 0.14572024350608145, 'y_loss': 0.5584604066568655}
# Train Epoch 3: Average Loss: 3.281619, KDL: -0.000005, x_loss: 0.144003, y_loss: 0.561126
# {'epoch': 3, 'average_loss': 3.2816188142016216, 'KLD_loss': -5.099323246028873e-06, 'x_loss': 0.1440029233068853, 'y_loss': 0.5611263496892436}
# Train Epoch 4: Average Loss: 3.279454, KDL: -0.000004, x_loss: 0.142863, y_loss: 0.561402
# {'epoch': 4, 'average_loss': 3.2794536337152227, 'KLD_loss': -3.601287628387238e-06, 'x_loss': 0.14286323421068126, 'y_loss': 0.5614023193612799}
# Train Epoch 5: Average Loss: 3.275656, KDL: -0.000004, x_loss: 0.141872, y_loss: 0.561265
# {'epoch': 5, 'average_loss': 3.2756557077794644, 'KLD_loss': -4.150650717995384e-06, 'x_loss': 0.14187233576199393, 'y_loss': 0.561265239682231}
# Train Epoch 6: Average Loss: 3.273925, KDL: -0.000002, x_loss: 0.141244, y_loss: 0.561308
# {'epoch': 6, 'average_loss': 3.2739253687691856, 'KLD_loss': -1.7447905106977983e-06, 'x_loss': 0.14124443974945095, 'y_loss': 0.5613084741405674}
# Train Epoch 7: Average Loss: 3.276020, KDL: -0.000002, x_loss: 0.140817, y_loss: 0.561989
# {'epoch': 7, 'average_loss': 3.276020483870606, 'KLD_loss': -1.719781568833998e-06, 'x_loss': 0.14081672523821984, 'y_loss': 0.5619891813584975}
# Train Epoch 8: Average Loss: 3.264573, KDL: -0.000001, x_loss: 0.139903, y_loss: 0.560285
# {'epoch': 8, 'average_loss': 3.264572722761781, 'KLD_loss': -7.919498256870083e-07, 'x_loss': 0.13990349109981443, 'y_loss': 0.5602854137654071}
# Train Epoch 9: Average Loss: 3.276085, KDL: -0.000001, x_loss: 0.140068, y_loss: 0.562465
# {'epoch': 9, 'average_loss': 3.2760846944955677, 'KLD_loss': -5.618675605400459e-07, 'x_loss': 0.1400681068013598, 'y_loss': 0.5624648486817634}
# Train Epoch 10: Average Loss: 3.274785, KDL: -0.000000, x_loss: 0.139492, y_loss: 0.562564
# {'epoch': 10, 'average_loss': 3.274785084157557, 'KLD_loss': -3.901394930752841e-07, 'x_loss': 0.13949235280702163, 'y_loss': 0.5625643117444499}
# Train Epoch 11: Average Loss: 3.279864, KDL: 0.000001, x_loss: 0.139669, y_loss: 0.563459
# {'epoch': 11, 'average_loss': 3.279864318554218, 'KLD_loss': 1.243778042026333e-06, 'x_loss': 0.13966947192703927, 'y_loss': 0.5634588579197863}
# Train Epoch 12: Average Loss: 3.266252, KDL: 0.000003, x_loss: 0.138778, y_loss: 0.561311
# {'epoch': 12, 'average_loss': 3.2662522095900317, 'KLD_loss': 3.020246545751612e-06, 'x_loss': 0.1387782619758086, 'y_loss': 0.5613111819420661}
# Train Epoch 13: Average Loss: 3.266991, KDL: 0.000013, x_loss: 0.138586, y_loss: 0.561563
# {'epoch': 13, 'average_loss': 3.266990702969211, 'KLD_loss': 1.2647021900523793e-05, 'x_loss': 0.13858615830019638, 'y_loss': 0.5615629589641011}
# Train Epoch 14: Average Loss: 3.262105, KDL: 0.000058, x_loss: 0.138200, y_loss: 0.560769
# {'epoch': 14, 'average_loss': 3.262105182500986, 'KLD_loss': 5.782734264026988e-05, 'x_loss': 0.13820011602206664, 'y_loss': 0.5607692080777842}
# Train Epoch 15: Average Loss: 3.263688, KDL: 0.000097, x_loss: 0.138354, y_loss: 0.560930
# {'epoch': 15, 'average_loss': 3.2636877163306814, 'KLD_loss': 9.730062284669676e-05, 'x_loss': 0.13835439942516647, 'y_loss': 0.560930434056929}
# Train Epoch 16: Average Loss: 3.258312, KDL: 0.000120, x_loss: 0.137891, y_loss: 0.560120
# {'epoch': 16, 'average_loss': 3.2583122550190744, 'KLD_loss': 0.00011962693887990672, 'x_loss': 0.137891406602376, 'y_loss': 0.5601201615967117}
# Train Epoch 17: Average Loss: 3.256379, KDL: 0.000112, x_loss: 0.137833, y_loss: 0.559784
# {'epoch': 17, 'average_loss': 3.256378825727876, 'KLD_loss': 0.00011206006670331622, 'x_loss': 0.13783345333971345, 'y_loss': 0.5597837513143366}
# Train Epoch 18: Average Loss: 3.258039, KDL: 0.000110, x_loss: 0.137482, y_loss: 0.560334
# {'epoch': 18, 'average_loss': 3.258039395792501, 'KLD_loss': 0.00011038613486123252, 'x_loss': 0.13748166059905834, 'y_loss': 0.5603336457605962}
# Train Epoch 19: Average Loss: 3.268273, KDL: 0.000118, x_loss: 0.137866, y_loss: 0.562113
# {'epoch': 19, 'average_loss': 3.2682733835873905, 'KLD_loss': 0.00011799635587038694, 'x_loss': 0.13786628803798368, 'y_loss': 0.5621126071556465}
# Train Epoch 20: Average Loss: 3.259342, KDL: 0.000116, x_loss: 0.137350, y_loss: 0.560666
# {'epoch': 20, 'average_loss': 3.259341953851126, 'KLD_loss': 0.00011563050997007144, 'x_loss': 0.1373498973729727, 'y_loss': 0.5606660794544887}
# [I 2024-02-16 20:04:15,578] Trial 2 finished with value: 3.2576955748604726 and parameters: {'latent_dim': 22, 'lr': 0.0076997026256870075, 'batch_size': 140, 'beta': 7.24850493619921, 'wx': 3.130902906025629, 'wy': 5.044847172243226}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 3.257696, KDL: 0.000113, x_loss: 0.137249, y_loss: 0.560406
# {'epoch': 21, 'average_loss': 3.2576955748604726, 'KLD_loss': 0.0001131087749988049, 'x_loss': 0.13724890288773117, 'y_loss': 0.5604060350598156}
# lr = 0.004039488804765774 , batch =  73 , beta=  3.7783187402078475 , wx=  1.582387518174921 , wy =  1.8569441940746076 , latent_dim =  8
# Train Epoch 1: Average Loss: 1.997507, KDL: 0.187943, x_loss: 0.151582, y_loss: 0.564119
# {'epoch': 1, 'average_loss': 1.9975074916860482, 'KLD_loss': 0.18794279485723397, 'x_loss': 0.15158199125724117, 'y_loss': 0.5641194125161554}
# Train Epoch 2: Average Loss: 1.264967, KDL: -0.000001, x_loss: 0.143864, y_loss: 0.558618
# {'epoch': 2, 'average_loss': 1.2649666438137528, 'KLD_loss': -1.107993787222535e-06, 'x_loss': 0.14386409772356062, 'y_loss': 0.5586177912071674}
# Train Epoch 3: Average Loss: 1.263250, KDL: -0.000001, x_loss: 0.141911, y_loss: 0.559357
# {'epoch': 3, 'average_loss': 1.2632502464482385, 'KLD_loss': -5.657655479264085e-07, 'x_loss': 0.14191082905243782, 'y_loss': 0.5593568452953422}
# Train Epoch 4: Average Loss: 1.259830, KDL: 0.000000, x_loss: 0.140350, y_loss: 0.558844
# {'epoch': 4, 'average_loss': 1.2598303993252942, 'KLD_loss': 6.763169365207645e-08, 'x_loss': 0.14035003131432255, 'y_loss': 0.5588439306638536}
# Train Epoch 5: Average Loss: 1.256672, KDL: 0.000001, x_loss: 0.139184, y_loss: 0.558135
# {'epoch': 5, 'average_loss': 1.2566721499401288, 'KLD_loss': 8.368796675744718e-07, 'x_loss': 0.13918402484298623, 'y_loss': 0.5581351960662507}
# Train Epoch 6: Average Loss: 1.256670, KDL: 0.000001, x_loss: 0.138556, y_loss: 0.558669
# {'epoch': 6, 'average_loss': 1.256670371981433, 'KLD_loss': 1.2781280670722906e-06, 'x_loss': 0.13855568769313123, 'y_loss': 0.5586687741923506}
# Train Epoch 7: Average Loss: 1.254238, KDL: 0.000002, x_loss: 0.138163, y_loss: 0.557693
# {'epoch': 7, 'average_loss': 1.2542376432975713, 'KLD_loss': 1.753159683116161e-06, 'x_loss': 0.1381627141015373, 'y_loss': 0.5576926096947524}
# Train Epoch 8: Average Loss: 1.254405, KDL: 0.000004, x_loss: 0.137527, y_loss: 0.558320
# {'epoch': 8, 'average_loss': 1.254404584769785, 'KLD_loss': 3.7475441494127258e-06, 'x_loss': 0.1375273737920462, 'y_loss': 0.5583198542577507}
# Train Epoch 9: Average Loss: 1.253276, KDL: 0.000007, x_loss: 0.137283, y_loss: 0.557915
# {'epoch': 9, 'average_loss': 1.253276311481086, 'KLD_loss': 6.759275485129252e-06, 'x_loss': 0.13728272400959565, 'y_loss': 0.5579146072594788}
# Train Epoch 10: Average Loss: 1.253340, KDL: 0.000007, x_loss: 0.136882, y_loss: 0.558290
# {'epoch': 10, 'average_loss': 1.2533396358037516, 'KLD_loss': 6.823013298702936e-06, 'x_loss': 0.13688242480593876, 'y_loss': 0.558289691827593}
# Train Epoch 11: Average Loss: 1.251342, KDL: 0.000007, x_loss: 0.136338, y_loss: 0.557679
# {'epoch': 11, 'average_loss': 1.2513422891171309, 'KLD_loss': 6.525403391705813e-06, 'x_loss': 0.13633807895936234, 'y_loss': 0.5576785510908948}
# Train Epoch 12: Average Loss: 1.253515, KDL: 0.000007, x_loss: 0.136613, y_loss: 0.558614
# {'epoch': 12, 'average_loss': 1.2535150073740604, 'KLD_loss': 6.762233963848031e-06, 'x_loss': 0.13661320521122347, 'y_loss': 0.5586136725262134}
# Train Epoch 13: Average Loss: 1.250477, KDL: 0.000007, x_loss: 0.136197, y_loss: 0.557332
# {'epoch': 13, 'average_loss': 1.250476516946389, 'KLD_loss': 6.846398332693281e-06, 'x_loss': 0.136196966485603, 'y_loss': 0.5573319111427252}
# Train Epoch 14: Average Loss: 1.251618, KDL: 0.000007, x_loss: 0.136227, y_loss: 0.557921
# {'epoch': 14, 'average_loss': 1.251618293515087, 'KLD_loss': 6.653814420212794e-06, 'x_loss': 0.13622712687092975, 'y_loss': 0.5579214712999163}
# Train Epoch 15: Average Loss: 1.249466, KDL: 0.000007, x_loss: 0.135829, y_loss: 0.557101
# {'epoch': 15, 'average_loss': 1.2494656706378409, 'KLD_loss': 6.961887770325598e-06, 'x_loss': 0.13582853004880194, 'y_loss': 0.5571012769302313}
# Train Epoch 16: Average Loss: 1.250599, KDL: 0.000007, x_loss: 0.135734, y_loss: 0.557792
# {'epoch': 16, 'average_loss': 1.2505986183229154, 'KLD_loss': 6.876788000120734e-06, 'x_loss': 0.1357341984327692, 'y_loss': 0.5577919489493335}
# Train Epoch 17: Average Loss: 1.249115, KDL: 0.000007, x_loss: 0.135613, y_loss: 0.557097
# {'epoch': 17, 'average_loss': 1.249114775831682, 'KLD_loss': 6.766997984726063e-06, 'x_loss': 0.1356125676610174, 'y_loss': 0.5570967421044398}
# Train Epoch 18: Average Loss: 1.249256, KDL: 0.000007, x_loss: 0.135488, y_loss: 0.557280
# {'epoch': 18, 'average_loss': 1.2492564267485682, 'KLD_loss': 6.59477536695717e-06, 'x_loss': 0.13548766165210382, 'y_loss': 0.5572798132243818}
# Train Epoch 19: Average Loss: 1.247480, KDL: 0.000007, x_loss: 0.135239, y_loss: 0.556534
# {'epoch': 19, 'average_loss': 1.247479835652957, 'KLD_loss': 6.837305361337035e-06, 'x_loss': 0.13523921629373176, 'y_loss': 0.5565343014515229}
# Train Epoch 20: Average Loss: 1.247965, KDL: 0.000007, x_loss: 0.135014, y_loss: 0.556988
# {'epoch': 20, 'average_loss': 1.2479647179589655, 'KLD_loss': 6.6837037566804535e-06, 'x_loss': 0.13501408203457393, 'y_loss': 0.5569875804612237}
# [I 2024-02-16 20:06:55,848] Trial 3 finished with value: 1.2480368981396195 and parameters: {'latent_dim': 8, 'lr': 0.004039488804765774, 'batch_size': 73, 'beta': 3.7783187402078475, 'wx': 1.582387518174921, 'wy': 1.8569441940746076}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 1.248037, KDL: 0.000007, x_loss: 0.135056, y_loss: 0.556991
# {'epoch': 21, 'average_loss': 1.2480368981396195, 'KLD_loss': 6.794211638234827e-06, 'x_loss': 0.1350559043079397, 'y_loss': 0.5569905882334187}
# lr = 0.0016749255785944086 , batch =  179 , beta=  14.99380297571815 , wx=  4.067721959587702 , wy =  10.902305600757675 , latent_dim =  10
# Train Epoch 1: Average Loss: 9.454032, KDL: 0.148692, x_loss: 0.171931, y_loss: 0.598516
# {'epoch': 1, 'average_loss': 9.454031872621377, 'KLD_loss': 0.14869187620330154, 'x_loss': 0.17193072510480029, 'y_loss': 0.5985164021763264}
# Train Epoch 2: Average Loss: 6.696538, KDL: 0.000084, x_loss: 0.144244, y_loss: 0.560298
# {'epoch': 2, 'average_loss': 6.6965384312733764, 'KLD_loss': 8.391209066660545e-05, 'x_loss': 0.14424366935794383, 'y_loss': 0.5602977368614115}
# Train Epoch 3: Average Loss: 6.683549, KDL: 0.000040, x_loss: 0.141675, y_loss: 0.560125
# {'epoch': 3, 'average_loss': 6.68354938878996, 'KLD_loss': 4.048840091138918e-05, 'x_loss': 0.14167455971667506, 'y_loss': 0.5601246048811297}
# Train Epoch 4: Average Loss: 6.656339, KDL: 0.000029, x_loss: 0.139766, y_loss: 0.558356
# {'epoch': 4, 'average_loss': 6.656338786396443, 'KLD_loss': 2.9071605696021337e-05, 'x_loss': 0.13976645540306096, 'y_loss': 0.5583563740223593}
# Train Epoch 5: Average Loss: 6.684778, KDL: 0.000023, x_loss: 0.138987, y_loss: 0.561263
# {'epoch': 5, 'average_loss': 6.684777692306874, 'KLD_loss': 2.349030779598011e-05, 'x_loss': 0.1389868506005497, 'y_loss': 0.5612634487570078}
# Train Epoch 6: Average Loss: 6.648520, KDL: 0.000021, x_loss: 0.137645, y_loss: 0.558442
# {'epoch': 6, 'average_loss': 6.648520372421456, 'KLD_loss': 2.0881405030252256e-05, 'x_loss': 0.13764521827478102, 'y_loss': 0.5584419523240842}
# Train Epoch 7: Average Loss: 6.616861, KDL: 0.000018, x_loss: 0.136576, y_loss: 0.555941
# {'epoch': 7, 'average_loss': 6.616860759066341, 'KLD_loss': 1.7939931804677453e-05, 'x_loss': 0.13657574103695336, 'y_loss': 0.5559410891080798}
# Train Epoch 8: Average Loss: 6.624431, KDL: 0.000016, x_loss: 0.136095, y_loss: 0.556818
# {'epoch': 8, 'average_loss': 6.624431481301678, 'KLD_loss': 1.577545150661298e-05, 'x_loss': 0.1360952156014434, 'y_loss': 0.5568177672319634}
# Train Epoch 9: Average Loss: 6.615669, KDL: 0.000014, x_loss: 0.135334, y_loss: 0.556301
# {'epoch': 9, 'average_loss': 6.615668725029087, 'KLD_loss': 1.3720157534577125e-05, 'x_loss': 0.13533388956554887, 'y_loss': 0.5563008971845528}
# Train Epoch 10: Average Loss: 6.621404, KDL: 0.000012, x_loss: 0.135212, y_loss: 0.556875
# {'epoch': 10, 'average_loss': 6.621404051567446, 'KLD_loss': 1.2041524399158566e-05, 'x_loss': 0.1352120354798271, 'y_loss': 0.5568747359439598}
# Train Epoch 11: Average Loss: 6.600142, KDL: 0.000011, x_loss: 0.134392, y_loss: 0.555232
# {'epoch': 11, 'average_loss': 6.600142161620111, 'KLD_loss': 1.122523932209595e-05, 'x_loss': 0.13439225850623493, 'y_loss': 0.5552315025295469}
# Train Epoch 12: Average Loss: 6.616621, KDL: 0.000010, x_loss: 0.134510, y_loss: 0.556700
# {'epoch': 12, 'average_loss': 6.616621312600342, 'KLD_loss': 1.0474263448834632e-05, 'x_loss': 0.13451032420497033, 'y_loss': 0.5567000139378051}
# Train Epoch 13: Average Loss: 6.591207, KDL: 0.000010, x_loss: 0.133757, y_loss: 0.554651
# {'epoch': 13, 'average_loss': 6.59120682782905, 'KLD_loss': 9.787477193023736e-06, 'x_loss': 0.13375679007689728, 'y_loss': 0.5546509954072069}
# Train Epoch 14: Average Loss: 6.598650, KDL: 0.000009, x_loss: 0.133690, y_loss: 0.555360
# {'epoch': 14, 'average_loss': 6.598650134740021, 'KLD_loss': 9.247250121906534e-06, 'x_loss': 0.1336896571069156, 'y_loss': 0.5553595146467519}
# Train Epoch 15: Average Loss: 6.578430, KDL: 0.000008, x_loss: 0.133146, y_loss: 0.553709
# {'epoch': 15, 'average_loss': 6.578429688707874, 'KLD_loss': 8.370400754624914e-06, 'x_loss': 0.133146310188476, 'y_loss': 0.5537087527072068}
# Train Epoch 16: Average Loss: 6.577022, KDL: 0.000007, x_loss: 0.132848, y_loss: 0.553692
# {'epoch': 16, 'average_loss': 6.577021908461514, 'KLD_loss': 7.487260378324068e-06, 'x_loss': 0.13284823538365645, 'y_loss': 0.5536920537035879}
# Train Epoch 17: Average Loss: 6.577904, KDL: 0.000007, x_loss: 0.132793, y_loss: 0.553794
# {'epoch': 17, 'average_loss': 6.577903619605868, 'KLD_loss': 7.102282614528813e-06, 'x_loss': 0.13279314159227398, 'y_loss': 0.5537940121933898}
# Train Epoch 18: Average Loss: 6.565767, KDL: 0.000006, x_loss: 0.132513, y_loss: 0.552786
# {'epoch': 18, 'average_loss': 6.565766538405034, 'KLD_loss': 6.254489178734303e-06, 'x_loss': 0.13251345865894942, 'y_loss': 0.5527862718791996}
# Train Epoch 19: Average Loss: 6.570328, KDL: 0.000008, x_loss: 0.132280, y_loss: 0.553289
# {'epoch': 19, 'average_loss': 6.570327908920261, 'KLD_loss': 8.369014600095254e-06, 'x_loss': 0.13227982491201493, 'y_loss': 0.553288920834154}
# Train Epoch 20: Average Loss: 6.563327, KDL: 0.000010, x_loss: 0.132173, y_loss: 0.552684
# {'epoch': 20, 'average_loss': 6.563326781039161, 'KLD_loss': 1.0438223431063467e-05, 'x_loss': 0.13217347783031533, 'y_loss': 0.5526835830992151}
# [I 2024-02-16 20:08:18,304] Trial 4 finished with value: 6.563189920244575 and parameters: {'latent_dim': 10, 'lr': 0.0016749255785944086, 'batch_size': 179, 'beta': 14.99380297571815, 'wx': 4.067721959587702, 'wy': 10.902305600757675}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 6.563190, KDL: 0.000010, x_loss: 0.132017, y_loss: 0.552729
# {'epoch': 21, 'average_loss': 6.563189920244575, 'KLD_loss': 1.0491217185005093e-05, 'x_loss': 0.1320170078406607, 'y_loss': 0.5527293366481665}
# lr = 0.004011900402510797 , batch =  137 , beta=  11.413037883056699 , wx=  1.0408142073746267 , wy =  10.03731068700089 , latent_dim =  14
# Train Epoch 1: Average Loss: 35.165588, KDL: 2.574210, x_loss: 0.152566, y_loss: 0.560632
# {'epoch': 1, 'average_loss': 35.16558805295866, 'KLD_loss': 2.5742097850531747, 'x_loss': 0.15256564642672668, 'y_loss': 0.5606323407937402}
# Train Epoch 2: Average Loss: 5.736562, KDL: 0.000173, x_loss: 0.143514, y_loss: 0.556445
# {'epoch': 2, 'average_loss': 5.736561576634237, 'KLD_loss': 0.00017346433580738225, 'x_loss': 0.14351412825388452, 'y_loss': 0.5564448986151447}
# Train Epoch 3: Average Loss: 5.740812, KDL: 0.000144, x_loss: 0.141390, y_loss: 0.557122
# {'epoch': 3, 'average_loss': 5.740812303595347, 'KLD_loss': 0.00014424879256993124, 'x_loss': 0.14138994297548516, 'y_loss': 0.5571218779642289}
# Train Epoch 4: Average Loss: 5.744878, KDL: 0.000113, x_loss: 0.140074, y_loss: 0.557699
# {'epoch': 4, 'average_loss': 5.7448783854915675, 'KLD_loss': 0.0001132108985561214, 'x_loss': 0.14007362050757016, 'y_loss': 0.557698761355387}
# Train Epoch 5: Average Loss: 5.740646, KDL: 0.000059, x_loss: 0.138922, y_loss: 0.557458
# {'epoch': 5, 'average_loss': 5.740646291105715, 'KLD_loss': 5.9167163012778926e-05, 'x_loss': 0.1389223503025427, 'y_loss': 0.5574579586721446}
# Train Epoch 6: Average Loss: 5.730633, KDL: 0.000038, x_loss: 0.137772, y_loss: 0.556603
# {'epoch': 6, 'average_loss': 5.730633076576337, 'KLD_loss': 3.8251525735201904e-05, 'x_loss': 0.13777247649961955, 'y_loss': 0.5566033758529245}
# Train Epoch 7: Average Loss: 5.737442, KDL: 0.000022, x_loss: 0.137425, y_loss: 0.557337
# {'epoch': 7, 'average_loss': 5.737442112622196, 'KLD_loss': 2.165657200225412e-05, 'x_loss': 0.13742531776836472, 'y_loss': 0.5573366174959157}
# Train Epoch 8: Average Loss: 5.725737, KDL: 0.000015, x_loss: 0.136913, y_loss: 0.556231
# {'epoch': 8, 'average_loss': 5.725737371836623, 'KLD_loss': 1.5248092886519758e-05, 'x_loss': 0.1369132903238682, 'y_loss': 0.5562308736043433}
# Train Epoch 9: Average Loss: 5.721626, KDL: 0.000012, x_loss: 0.136367, y_loss: 0.555882
# {'epoch': 9, 'average_loss': 5.721625599795825, 'KLD_loss': 1.172803036154133e-05, 'x_loss': 0.1363669037716846, 'y_loss': 0.5558818856330767}
# Train Epoch 10: Average Loss: 5.726295, KDL: 0.000010, x_loss: 0.136145, y_loss: 0.556372
# {'epoch': 10, 'average_loss': 5.7262953039718, 'KLD_loss': 1.0283311752423848e-05, 'x_loss': 0.1361449796961595, 'y_loss': 0.5563717744938315}
# Train Epoch 11: Average Loss: 5.710419, KDL: 0.000009, x_loss: 0.135528, y_loss: 0.554855
# {'epoch': 11, 'average_loss': 5.710418791966895, 'KLD_loss': 9.45354161197192e-06, 'x_loss': 0.13552833714917914, 'y_loss': 0.5548549116474308}
# Train Epoch 12: Average Loss: 5.718553, KDL: 0.000009, x_loss: 0.135604, y_loss: 0.555658
# {'epoch': 12, 'average_loss': 5.718553215836826, 'KLD_loss': 8.76045390351178e-06, 'x_loss': 0.13560443106171202, 'y_loss': 0.5556582285933298}
# Train Epoch 13: Average Loss: 5.714791, KDL: 0.000008, x_loss: 0.135211, y_loss: 0.555325
# {'epoch': 13, 'average_loss': 5.714790796906981, 'KLD_loss': 7.83813326326135e-06, 'x_loss': 0.13521114420400906, 'y_loss': 0.555325214258612}
# Train Epoch 14: Average Loss: 5.708499, KDL: 0.000007, x_loss: 0.134911, y_loss: 0.554731
# {'epoch': 14, 'average_loss': 5.708498619027334, 'KLD_loss': 6.883479144475231e-06, 'x_loss': 0.13491095859710484, 'y_loss': 0.5547305478625102}
# Train Epoch 15: Average Loss: 5.709020, KDL: 0.000006, x_loss: 0.134575, y_loss: 0.554818
# {'epoch': 15, 'average_loss': 5.709019877812634, 'KLD_loss': 5.9736918096673e-06, 'x_loss': 0.13457461511843824, 'y_loss': 0.5548183927797291}
# Train Epoch 16: Average Loss: 5.710216, KDL: 0.000008, x_loss: 0.134390, y_loss: 0.554955
# {'epoch': 16, 'average_loss': 5.710216042766833, 'KLD_loss': 7.620984560822788e-06, 'x_loss': 0.13439022493484903, 'y_loss': 0.5549548122164322}
# Train Epoch 17: Average Loss: 5.721226, KDL: 0.000016, x_loss: 0.134510, y_loss: 0.556030
# {'epoch': 17, 'average_loss': 5.7212262297329834, 'KLD_loss': 1.598143414275287e-05, 'x_loss': 0.13450974007583644, 'y_loss': 0.5560298384052433}
# Train Epoch 18: Average Loss: 5.701518, KDL: 0.000024, x_loss: 0.133883, y_loss: 0.554123
# {'epoch': 18, 'average_loss': 5.701517947079384, 'KLD_loss': 2.357286133178293e-05, 'x_loss': 0.1338830666693106, 'y_loss': 0.5541226867127091}
# Train Epoch 19: Average Loss: 5.708584, KDL: 0.000024, x_loss: 0.133916, y_loss: 0.554822
# {'epoch': 19, 'average_loss': 5.70858360969857, 'KLD_loss': 2.446297096879515e-05, 'x_loss': 0.13391556029450402, 'y_loss': 0.554822245036086}
# Train Epoch 20: Average Loss: 5.711296, KDL: 0.000024, x_loss: 0.133956, y_loss: 0.555089
# {'epoch': 20, 'average_loss': 5.711295824181543, 'KLD_loss': 2.408415487367813e-05, 'x_loss': 0.1339559180177238, 'y_loss': 0.5550887024565919}
# [I 2024-02-16 20:09:53,546] Trial 5 finished with value: 5.7170607651749705 and parameters: {'latent_dim': 14, 'lr': 0.004011900402510797, 'batch_size': 137, 'beta': 11.413037883056699, 'wx': 1.0408142073746267, 'wy': 10.03731068700089}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 5.717061, KDL: 0.000024, x_loss: 0.134165, y_loss: 0.555642
# {'epoch': 21, 'average_loss': 5.7170607651749705, 'KLD_loss': 2.386990475328001e-05, 'x_loss': 0.13416501437760378, 'y_loss': 0.555641616778831}
# lr = 0.007945311227114537 , batch =  256 , beta=  9.129956664740469 , wx=  6.278733216543349 , wy =  10.144810491500639 , latent_dim =  10
# Train Epoch 1: Average Loss: 166.472105, KDL: 17.462013, x_loss: 0.168921, y_loss: 0.589866
# {'epoch': 1, 'average_loss': 166.4721045433103, 'KLD_loss': 17.46201273654123, 'x_loss': 0.16892061506390876, 'y_loss': 0.5898658512803294}
# Train Epoch 2: Average Loss: 6.612596, KDL: 0.003729, x_loss: 0.144419, y_loss: 0.559082
# {'epoch': 2, 'average_loss': 6.612595644753302, 'KLD_loss': 0.0037289645970629915, 'x_loss': 0.1444186421916308, 'y_loss': 0.5590823144863939}
# Train Epoch 3: Average Loss: 6.564937, KDL: 0.001163, x_loss: 0.142112, y_loss: 0.558121
# {'epoch': 3, 'average_loss': 6.564936798856691, 'KLD_loss': 0.001163498138832619, 'x_loss': 0.14211224084315094, 'y_loss': 0.5581207398868278}
# Train Epoch 4: Average Loss: 6.557110, KDL: 0.000362, x_loss: 0.140957, y_loss: 0.558785
# {'epoch': 4, 'average_loss': 6.557109632760363, 'KLD_loss': 0.00036208152466113, 'x_loss': 0.14095717506564182, 'y_loss': 0.558785325730853}
# Train Epoch 5: Average Loss: 6.544876, KDL: 0.000193, x_loss: 0.139848, y_loss: 0.558418
# {'epoch': 5, 'average_loss': 6.544875965703784, 'KLD_loss': 0.00019266683122386104, 'x_loss': 0.1398481853172907, 'y_loss': 0.5584182550230294}
# Train Epoch 6: Average Loss: 6.544559, KDL: 0.000203, x_loss: 0.139067, y_loss: 0.558861
# {'epoch': 6, 'average_loss': 6.5445588872865645, 'KLD_loss': 0.00020279779153711656, 'x_loss': 0.13906699927795269, 'y_loss': 0.558861368300055}
# Train Epoch 7: Average Loss: 6.534262, KDL: 0.000051, x_loss: 0.138663, y_loss: 0.558233
# {'epoch': 7, 'average_loss': 6.534261790078009, 'KLD_loss': 5.121060344569214e-05, 'x_loss': 0.1386628621603217, 'y_loss': 0.5582329021085559}
# Train Epoch 8: Average Loss: 6.543998, KDL: 0.000063, x_loss: 0.138448, y_loss: 0.559315
# {'epoch': 8, 'average_loss': 6.54399762434118, 'KLD_loss': 6.272809584732251e-05, 'x_loss': 0.1384476271203107, 'y_loss': 0.5593154366363955}
# Train Epoch 9: Average Loss: 6.512159, KDL: 0.000035, x_loss: 0.137132, y_loss: 0.557016
# {'epoch': 9, 'average_loss': 6.512158963381482, 'KLD_loss': 3.476711490270122e-05, 'x_loss': 0.1371319076365522, 'y_loss': 0.5570164949387846}
# Train Epoch 10: Average Loss: 6.539827, KDL: 0.000030, x_loss: 0.137511, y_loss: 0.559513
# {'epoch': 10, 'average_loss': 6.539827141920319, 'KLD_loss': 3.0494483230668872e-05, 'x_loss': 0.13751112867880355, 'y_loss': 0.5595129585022207}
# Train Epoch 11: Average Loss: 6.522722, KDL: 0.000034, x_loss: 0.137215, y_loss: 0.558006
# {'epoch': 11, 'average_loss': 6.522722151578235, 'KLD_loss': 3.4244240397382576e-05, 'x_loss': 0.1372154727387611, 'y_loss': 0.5580064866244031}
# Train Epoch 12: Average Loss: 6.523073, KDL: 0.000016, x_loss: 0.137016, y_loss: 0.558181
# {'epoch': 12, 'average_loss': 6.523073201289263, 'KLD_loss': 1.5792182034543713e-05, 'x_loss': 0.1370164328028479, 'y_loss': 0.5581808855466526}
# Train Epoch 13: Average Loss: 6.531410, KDL: 0.000020, x_loss: 0.136988, y_loss: 0.559016
# {'epoch': 13, 'average_loss': 6.531410400215012, 'KLD_loss': 2.0382882993849343e-05, 'x_loss': 0.13698846383777727, 'y_loss': 0.5590158822896231}
# Train Epoch 14: Average Loss: 6.503193, KDL: 0.000018, x_loss: 0.136057, y_loss: 0.556813
# {'epoch': 14, 'average_loss': 6.503193089419313, 'KLD_loss': 1.763619120468569e-05, 'x_loss': 0.1360568581220439, 'y_loss': 0.5568134828906535}
# Train Epoch 15: Average Loss: 6.553457, KDL: 0.000016, x_loss: 0.137303, y_loss: 0.560999
# {'epoch': 15, 'average_loss': 6.553456929638562, 'KLD_loss': 1.5806130436070433e-05, 'x_loss': 0.13730275564257752, 'y_loss': 0.5609986654023076}
# Train Epoch 16: Average Loss: 6.496592, KDL: 0.000015, x_loss: 0.135757, y_loss: 0.556350
# {'epoch': 16, 'average_loss': 6.496591727751905, 'KLD_loss': 1.5309552097564462e-05, 'x_loss': 0.1357574729282228, 'y_loss': 0.5563501554072056}
# Train Epoch 17: Average Loss: 6.480777, KDL: 0.000014, x_loss: 0.135035, y_loss: 0.555240
# {'epoch': 17, 'average_loss': 6.4807768282683, 'KLD_loss': 1.4075918880569966e-05, 'x_loss': 0.1350347118838059, 'y_loss': 0.5552396746852514}
# Train Epoch 18: Average Loss: 6.527251, KDL: 0.000014, x_loss: 0.136083, y_loss: 0.559172
# {'epoch': 18, 'average_loss': 6.527250919195697, 'KLD_loss': 1.3872866740312113e-05, 'x_loss': 0.13608292015769596, 'y_loss': 0.5591721801501711}
# Train Epoch 19: Average Loss: 6.489504, KDL: 0.000012, x_loss: 0.134932, y_loss: 0.556165
# {'epoch': 19, 'average_loss': 6.4895035909569785, 'KLD_loss': 1.2379854231539284e-05, 'x_loss': 0.13493180804697755, 'y_loss': 0.5561651085953578}
# Train Epoch 20: Average Loss: 6.524548, KDL: 0.000012, x_loss: 0.135624, y_loss: 0.559191
# {'epoch': 20, 'average_loss': 6.5245482037439375, 'KLD_loss': 1.2391058685224685e-05, 'x_loss': 0.13562380004188287, 'y_loss': 0.5591912551609146}
# [I 2024-02-16 20:10:58,417] Trial 6 finished with value: 6.498898092743076 and parameters: {'latent_dim': 10, 'lr': 0.007945311227114537, 'batch_size': 256, 'beta': 9.129956664740469, 'wx': 6.278733216543349, 'wy': 10.144810491500639}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 6.498898, KDL: 0.000012, x_loss: 0.135028, y_loss: 0.557032
# {'epoch': 21, 'average_loss': 6.498898092743076, 'KLD_loss': 1.1587539292357463e-05, 'x_loss': 0.13502816474803572, 'y_loss': 0.5570322255344342}
# lr = 0.00908112279294006 , batch =  239 , beta=  11.60530574189356 , wx=  7.190777295853795 , wy =  2.066914941246368 , latent_dim =  6
# Train Epoch 1: Average Loss: 61.832001, KDL: 5.119222, x_loss: 0.170392, y_loss: 0.578934
# {'epoch': 1, 'average_loss': 61.83200111195694, 'KLD_loss': 5.1192222473018205, 'x_loss': 0.1703920011588668, 'y_loss': 0.5789340191069537}
# Train Epoch 2: Average Loss: 2.185715, KDL: 0.000441, x_loss: 0.143356, y_loss: 0.556268
# {'epoch': 2, 'average_loss': 2.1857152864301406, 'KLD_loss': 0.00044068679889232846, 'x_loss': 0.14335624197929173, 'y_loss': 0.5562677484423563}
# Train Epoch 3: Average Loss: 2.204072, KDL: 0.002016, x_loss: 0.142209, y_loss: 0.560295
# {'epoch': 3, 'average_loss': 2.2040715354154674, 'KLD_loss': 0.0020158256721951795, 'x_loss': 0.14220920699450737, 'y_loss': 0.5602951752542027}
# Train Epoch 4: Average Loss: 2.197570, KDL: 0.001557, x_loss: 0.141593, y_loss: 0.561868
# {'epoch': 4, 'average_loss': 2.1975700394350475, 'KLD_loss': 0.0015572447480905027, 'x_loss': 0.14159317615137465, 'y_loss': 0.5618676711096114}
# Train Epoch 5: Average Loss: 2.188216, KDL: 0.001047, x_loss: 0.140803, y_loss: 0.562955
# {'epoch': 5, 'average_loss': 2.188216368736686, 'KLD_loss': 0.0010474405311457012, 'x_loss': 0.14080274327344713, 'y_loss': 0.5629546043411928}
# Train Epoch 6: Average Loss: 2.169378, KDL: 0.000753, x_loss: 0.139524, y_loss: 0.559941
# {'epoch': 6, 'average_loss': 2.169377502222903, 'KLD_loss': 0.000753274467509231, 'x_loss': 0.13952395311047752, 'y_loss': 0.5599406964739069}
# Train Epoch 7: Average Loss: 2.166885, KDL: 0.000500, x_loss: 0.139280, y_loss: 0.561002
# {'epoch': 7, 'average_loss': 2.1668849623004123, 'KLD_loss': 0.0005004582370949247, 'x_loss': 0.13928018921101576, 'y_loss': 0.5610023337218528}
# Train Epoch 8: Average Loss: 2.159966, KDL: 0.000283, x_loss: 0.138789, y_loss: 0.560583
# {'epoch': 8, 'average_loss': 2.159966230676965, 'KLD_loss': 0.0002830919758516735, 'x_loss': 0.1387893543856525, 'y_loss': 0.560583043923526}
# Train Epoch 9: Average Loss: 2.162934, KDL: 0.000179, x_loss: 0.139145, y_loss: 0.561364
# {'epoch': 9, 'average_loss': 2.1629336016843883, 'KLD_loss': 0.00017912020831233278, 'x_loss': 0.1391453503104269, 'y_loss': 0.5613639714609752}
# Train Epoch 10: Average Loss: 2.153896, KDL: 0.000124, x_loss: 0.138198, y_loss: 0.560594
# {'epoch': 10, 'average_loss': 2.1538961212504164, 'KLD_loss': 0.00012444809683751946, 'x_loss': 0.13819807129500875, 'y_loss': 0.5605940665151737}
# Train Epoch 11: Average Loss: 2.146872, KDL: 0.000085, x_loss: 0.137520, y_loss: 0.559780
# {'epoch': 11, 'average_loss': 2.1468717181312726, 'KLD_loss': 8.455473654025494e-05, 'x_loss': 0.13751965725621063, 'y_loss': 0.5597797635062498}
# Train Epoch 12: Average Loss: 2.149511, KDL: 0.000059, x_loss: 0.137548, y_loss: 0.561101
# {'epoch': 12, 'average_loss': 2.1495109768073144, 'KLD_loss': 5.924559436151691e-05, 'x_loss': 0.1375477606150586, 'y_loss': 0.5611010037344794}
# Train Epoch 13: Average Loss: 2.142141, KDL: 0.000045, x_loss: 0.136982, y_loss: 0.559584
# {'epoch': 13, 'average_loss': 2.1421413017628015, 'KLD_loss': 4.4777029169487784e-05, 'x_loss': 0.1369822240459037, 'y_loss': 0.5595841915624523}
# Train Epoch 14: Average Loss: 2.145292, KDL: 0.000028, x_loss: 0.137143, y_loss: 0.560644
# {'epoch': 14, 'average_loss': 2.1452917631599955, 'KLD_loss': 2.7954080508830722e-05, 'x_loss': 0.13714284793004786, 'y_loss': 0.5606440776572307}
# Train Epoch 15: Average Loss: 2.143088, KDL: 0.000020, x_loss: 0.136856, y_loss: 0.560618
# {'epoch': 15, 'average_loss': 2.1430884517178046, 'KLD_loss': 2.017937298321781e-05, 'x_loss': 0.13685636892736955, 'y_loss': 0.5606183961638402}
# Train Epoch 16: Average Loss: 2.145815, KDL: 0.000096, x_loss: 0.136783, y_loss: 0.561770
# {'epoch': 16, 'average_loss': 2.145815100760904, 'KLD_loss': 9.558017327848084e-05, 'x_loss': 0.1367827535457998, 'y_loss': 0.5617703313190214}
# Train Epoch 17: Average Loss: 2.144024, KDL: -0.000000, x_loss: 0.136963, y_loss: 0.560814
# {'epoch': 17, 'average_loss': 2.1440237882882713, 'KLD_loss': -4.759836310703032e-07, 'x_loss': 0.13696347038330497, 'y_loss': 0.5608142954352932}
# Train Epoch 18: Average Loss: 2.129470, KDL: 0.000001, x_loss: 0.135869, y_loss: 0.557574
# {'epoch': 18, 'average_loss': 2.129470135545389, 'KLD_loss': 5.200114056716955e-07, 'x_loss': 0.13586924482928256, 'y_loss': 0.5575742592106002}
# Train Epoch 19: Average Loss: 2.133610, KDL: 0.000001, x_loss: 0.135954, y_loss: 0.559281
# {'epoch': 19, 'average_loss': 2.133610219261242, 'KLD_loss': 9.4193831832995e-07, 'x_loss': 0.13595381875240148, 'y_loss': 0.5592806852802741}
# Train Epoch 20: Average Loss: 2.144237, KDL: 0.000001, x_loss: 0.136877, y_loss: 0.561210
# {'epoch': 20, 'average_loss': 2.144237146741735, 'KLD_loss': 1.2300748529183835e-06, 'x_loss': 0.13687673520501303, 'y_loss': 0.561209693017609}
# [I 2024-02-16 20:12:06,498] Trial 7 finished with value: 2.134952084830382 and parameters: {'latent_dim': 6, 'lr': 0.00908112279294006, 'batch_size': 239, 'beta': 11.60530574189356, 'wx': 7.190777295853795, 'wy': 2.066914941246368}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 2.134952, KDL: 0.000002, x_loss: 0.135874, y_loss: 0.560204
# {'epoch': 21, 'average_loss': 2.134952084830382, 'KLD_loss': 1.5469468009784854e-06, 'x_loss': 0.1358739743298164, 'y_loss': 0.5602042773173931}
# lr = 0.003321485354537328 , batch =  152 , beta=  6.9475353488486755 , wx=  6.015586475050493 , wy =  4.088911749600005 , latent_dim =  16
# Train Epoch 1: Average Loss: 25.892844, KDL: 3.257056, x_loss: 0.156873, y_loss: 0.567547
# {'epoch': 1, 'average_loss': 25.892844100128915, 'KLD_loss': 3.2570559891976845, 'x_loss': 0.15687275532984082, 'y_loss': 0.567547149752411}
# Train Epoch 2: Average Loss: 3.126934, KDL: 0.000000, x_loss: 0.143122, y_loss: 0.554175
# {'epoch': 2, 'average_loss': 3.1269338750549363, 'KLD_loss': 2.8887418265763023e-07, 'x_loss': 0.14312176083675995, 'y_loss': 0.5541745119000641}
# Train Epoch 3: Average Loss: 3.119286, KDL: -0.000004, x_loss: 0.141194, y_loss: 0.555148
# {'epoch': 3, 'average_loss': 3.119285869743324, 'KLD_loss': -4.084458104745233e-06, 'x_loss': 0.14119367744196148, 'y_loss': 0.5551481041321276}
# Train Epoch 4: Average Loss: 3.113293, KDL: -0.000006, x_loss: 0.139544, y_loss: 0.556112
# {'epoch': 4, 'average_loss': 3.113292836853074, 'KLD_loss': -5.748134253597549e-06, 'x_loss': 0.13954385071087028, 'y_loss': 0.5561124686049835}
# Train Epoch 5: Average Loss: 3.110780, KDL: -0.000006, x_loss: 0.138737, y_loss: 0.556686
# {'epoch': 5, 'average_loss': 3.1107801985233388, 'KLD_loss': -6.1746063928111345e-06, 'x_loss': 0.13873711043804612, 'y_loss': 0.5566855652716385}
# Train Epoch 6: Average Loss: 3.099086, KDL: -0.000006, x_loss: 0.137707, y_loss: 0.555341
# {'epoch': 6, 'average_loss': 3.099085805263925, 'KLD_loss': -5.788263216569431e-06, 'x_loss': 0.13770679510156073, 'y_loss': 0.5553406762315872}
# Train Epoch 7: Average Loss: 3.099534, KDL: -0.000004, x_loss: 0.137127, y_loss: 0.556300
# {'epoch': 7, 'average_loss': 3.0995338068182345, 'KLD_loss': -4.086858595758224e-06, 'x_loss': 0.13712720260431702, 'y_loss': 0.5563000434256614}
# Train Epoch 8: Average Loss: 3.093127, KDL: -0.000004, x_loss: 0.136405, y_loss: 0.555796
# {'epoch': 8, 'average_loss': 3.0931273202403338, 'KLD_loss': -4.497523728112682e-06, 'x_loss': 0.13640539982217423, 'y_loss': 0.5557958590585772}
# Train Epoch 9: Average Loss: 3.088284, KDL: -0.000002, x_loss: 0.135795, y_loss: 0.555505
# {'epoch': 9, 'average_loss': 3.08828366201337, 'KLD_loss': -2.1459936733303823e-06, 'x_loss': 0.13579525706842316, 'y_loss': 0.5555049198195565}
# Train Epoch 10: Average Loss: 3.078879, KDL: -0.000002, x_loss: 0.135256, y_loss: 0.553998
# {'epoch': 10, 'average_loss': 3.07887859728561, 'KLD_loss': -1.994672154945443e-06, 'x_loss': 0.13525568619144, 'y_loss': 0.5539983372376682}
# Train Epoch 11: Average Loss: 3.082022, KDL: -0.000001, x_loss: 0.135080, y_loss: 0.555024
# {'epoch': 11, 'average_loss': 3.0820223357539773, 'KLD_loss': -1.187518374898151e-06, 'x_loss': 0.1350801641568768, 'y_loss': 0.5550240385133807}
# Train Epoch 12: Average Loss: 3.082472, KDL: 0.000000, x_loss: 0.134810, y_loss: 0.555529
# {'epoch': 12, 'average_loss': 3.082471518531034, 'KLD_loss': 1.6767203264323412e-07, 'x_loss': 0.13481018889276453, 'y_loss': 0.5555287753557362}
# Train Epoch 13: Average Loss: 3.079665, KDL: 0.000001, x_loss: 0.134594, y_loss: 0.555160
# {'epoch': 13, 'average_loss': 3.079664808276214, 'KLD_loss': 5.297385450554474e-07, 'x_loss': 0.1345938670485759, 'y_loss': 0.555159992178885}
# Train Epoch 14: Average Loss: 3.079165, KDL: 0.000002, x_loss: 0.134302, y_loss: 0.555464
# {'epoch': 14, 'average_loss': 3.0791648495885737, 'KLD_loss': 2.2513888164856512e-06, 'x_loss': 0.1343023000811552, 'y_loss': 0.5554637461447788}
# Train Epoch 15: Average Loss: 3.064184, KDL: 0.000003, x_loss: 0.133517, y_loss: 0.552955
# {'epoch': 15, 'average_loss': 3.06418426891953, 'KLD_loss': 2.989698325971702e-06, 'x_loss': 0.13351654597645835, 'y_loss': 0.5529547795698635}
# Train Epoch 16: Average Loss: 3.068574, KDL: 0.000005, x_loss: 0.133925, y_loss: 0.553424
# {'epoch': 16, 'average_loss': 3.068573900993834, 'KLD_loss': 4.78137046732801e-06, 'x_loss': 0.1339251481019255, 'y_loss': 0.5534241491175712}
# Train Epoch 17: Average Loss: 3.065788, KDL: 0.000007, x_loss: 0.133424, y_loss: 0.553475
# {'epoch': 17, 'average_loss': 3.0657876327769733, 'KLD_loss': 7.252743903626787e-06, 'x_loss': 0.13342427414782504, 'y_loss': 0.5534754118296151}
# Train Epoch 18: Average Loss: 3.072255, KDL: 0.000012, x_loss: 0.133494, y_loss: 0.554947
# {'epoch': 18, 'average_loss': 3.0722546947038643, 'KLD_loss': 1.1727440320974426e-05, 'x_loss': 0.13349394529695569, 'y_loss': 0.554946920610851}
# Train Epoch 19: Average Loss: 3.064796, KDL: 0.000019, x_loss: 0.133096, y_loss: 0.553696
# {'epoch': 19, 'average_loss': 3.0647960172960462, 'KLD_loss': 1.8560687097010278e-05, 'x_loss': 0.1330963693287416, 'y_loss': 0.5536961004726793}
# Train Epoch 20: Average Loss: 3.060698, KDL: 0.000023, x_loss: 0.132765, y_loss: 0.553174
# {'epoch': 20, 'average_loss': 3.0606977863514677, 'KLD_loss': 2.2824819689463698e-05, 'x_loss': 0.13276478267730552, 'y_loss': 0.5531744025760871}
# [I 2024-02-16 20:13:36,844] Trial 8 finished with value: 3.0688794257068346 and parameters: {'latent_dim': 16, 'lr': 0.003321485354537328, 'batch_size': 152, 'beta': 6.9475353488486755, 'wx': 6.015586475050493, 'wy': 4.088911749600005}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 3.068879, KDL: 0.000022, x_loss: 0.133027, y_loss: 0.554792
# {'epoch': 21, 'average_loss': 3.0688794257068346, 'KLD_loss': 2.179038923199778e-05, 'x_loss': 0.13302661997116083, 'y_loss': 0.5547918805054256}
# lr = 0.009705409162265215 , batch =  230 , beta=  12.50224425978791 , wx=  4.1011886237020665 , wy =  9.428726447984396 , latent_dim =  16
# Train Epoch 1: Average Loss: 115.090950, KDL: 8.667645, x_loss: 0.218943, y_loss: 0.618111
# {'epoch': 1, 'average_loss': 115.09095015580627, 'KLD_loss': 8.667645192625878, 'x_loss': 0.21894267718682345, 'y_loss': 0.6181112190772747}
# Train Epoch 2: Average Loss: 5.865552, KDL: 0.000240, x_loss: 0.144187, y_loss: 0.559059
# {'epoch': 2, 'average_loss': 5.865552174359903, 'KLD_loss': 0.00023997693226255218, 'x_loss': 0.14418689420168426, 'y_loss': 0.5590590022076135}
# Train Epoch 3: Average Loss: 5.858788, KDL: 0.000042, x_loss: 0.142205, y_loss: 0.559466
# {'epoch': 3, 'average_loss': 5.858788107729506, 'KLD_loss': 4.232909487581801e-05, 'x_loss': 0.14220483899116515, 'y_loss': 0.5594658188436223}
# Train Epoch 4: Average Loss: 5.874745, KDL: 0.000026, x_loss: 0.141322, y_loss: 0.561564
# {'epoch': 4, 'average_loss': 5.874744521612408, 'KLD_loss': 2.5750439742515827e-05, 'x_loss': 0.14132199196637363, 'y_loss': 0.5615641302075879}
# Train Epoch 5: Average Loss: 5.892351, KDL: 0.000022, x_loss: 0.141532, y_loss: 0.563346
# {'epoch': 5, 'average_loss': 5.892350974028138, 'KLD_loss': 2.1699310719281776e-05, 'x_loss': 0.1415316476732835, 'y_loss': 0.5633456286342665}
# Train Epoch 6: Average Loss: 5.865283, KDL: 0.000020, x_loss: 0.140302, y_loss: 0.561012
# {'epoch': 6, 'average_loss': 5.865283100084326, 'KLD_loss': 2.005120803569925e-05, 'x_loss': 0.14030184273062082, 'y_loss': 0.5610119503119896}
# Train Epoch 7: Average Loss: 5.851380, KDL: 0.000019, x_loss: 0.139484, y_loss: 0.559895
# {'epoch': 7, 'average_loss': 5.851380139931865, 'KLD_loss': 1.9034435009134228e-05, 'x_loss': 0.13948399808214998, 'y_loss': 0.5598945043552881}
# Train Epoch 8: Average Loss: 5.908296, KDL: 0.000019, x_loss: 0.140581, y_loss: 0.565453
# {'epoch': 8, 'average_loss': 5.90829627924952, 'KLD_loss': 1.9157686452755983e-05, 'x_loss': 0.1405814669084275, 'y_loss': 0.5654534397454097}
# Train Epoch 9: Average Loss: 5.854607, KDL: 0.000019, x_loss: 0.138749, y_loss: 0.560556
# {'epoch': 9, 'average_loss': 5.854606850941976, 'KLD_loss': 1.9286898360855278e-05, 'x_loss': 0.13874946647676928, 'y_loss': 0.5605558873593122}
# Train Epoch 10: Average Loss: 5.941577, KDL: 0.000020, x_loss: 0.140897, y_loss: 0.568845
# {'epoch': 10, 'average_loss': 5.941577016896215, 'KLD_loss': 1.9698718498493063e-05, 'x_loss': 0.14089709713883783, 'y_loss': 0.568845149292343}
# Train Epoch 11: Average Loss: 5.843908, KDL: 0.000021, x_loss: 0.138354, y_loss: 0.559592
# {'epoch': 11, 'average_loss': 5.843907563439731, 'KLD_loss': 2.055318876244556e-05, 'x_loss': 0.13835381577754843, 'y_loss': 0.559591549977489}
# Train Epoch 12: Average Loss: 5.863474, KDL: 0.000020, x_loss: 0.138112, y_loss: 0.561773
# {'epoch': 12, 'average_loss': 5.8634737365547265, 'KLD_loss': 1.991480246357534e-05, 'x_loss': 0.13811185920032962, 'y_loss': 0.5617728073021461}
# Train Epoch 13: Average Loss: 5.862895, KDL: 0.000019, x_loss: 0.138037, y_loss: 0.561745
# {'epoch': 13, 'average_loss': 5.862894793762558, 'KLD_loss': 1.937863470494062e-05, 'x_loss': 0.13803658877638564, 'y_loss': 0.5617448549161013}
# Train Epoch 14: Average Loss: 5.877021, KDL: 0.000019, x_loss: 0.138001, y_loss: 0.563259
# {'epoch': 14, 'average_loss': 5.877021406984877, 'KLD_loss': 1.8815747622785896e-05, 'x_loss': 0.13800133886350982, 'y_loss': 0.5632591843605042}
# Train Epoch 15: Average Loss: 5.943652, KDL: 0.000018, x_loss: 0.140640, y_loss: 0.569179
# {'epoch': 15, 'average_loss': 5.943651997357949, 'KLD_loss': 1.7828228829920977e-05, 'x_loss': 0.14064033377444607, 'y_loss': 0.569179384735809}
# Train Epoch 16: Average Loss: 5.828303, KDL: 0.000017, x_loss: 0.137151, y_loss: 0.558464
# {'epoch': 16, 'average_loss': 5.82830251386796, 'KLD_loss': 1.688291286600047e-05, 'x_loss': 0.13715129242888813, 'y_loss': 0.558464421211988}
# Train Epoch 17: Average Loss: 5.853011, KDL: 0.000016, x_loss: 0.137622, y_loss: 0.560882
# {'epoch': 17, 'average_loss': 5.853011152113991, 'KLD_loss': 1.566485426891809e-05, 'x_loss': 0.13762248860693527, 'y_loss': 0.5608816511329563}
# Train Epoch 18: Average Loss: 5.831570, KDL: 0.000014, x_loss: 0.136670, y_loss: 0.559024
# {'epoch': 18, 'average_loss': 5.8315703611264285, 'KLD_loss': 1.4442616495592842e-05, 'x_loss': 0.13666997706067974, 'y_loss': 0.5590235960894617}
# Train Epoch 19: Average Loss: 5.877998, KDL: 0.000011, x_loss: 0.138248, y_loss: 0.563266
# {'epoch': 19, 'average_loss': 5.877998382743748, 'KLD_loss': 1.056242263180086e-05, 'x_loss': 0.13824803474648245, 'y_loss': 0.5632664420138831}
# Train Epoch 20: Average Loss: 5.839887, KDL: 0.000020, x_loss: 0.136725, y_loss: 0.559875
# {'epoch': 20, 'average_loss': 5.83988741622574, 'KLD_loss': 1.9752979278564452e-05, 'x_loss': 0.13672486146291096, 'y_loss': 0.5598747805617321}
# [I 2024-02-16 20:14:48,740] Trial 9 finished with value: 5.8351540335293475 and parameters: {'latent_dim': 16, 'lr': 0.009705409162265215, 'batch_size': 230, 'beta': 12.50224425978791, 'wx': 4.1011886237020665, 'wy': 9.428726447984396}. Best is trial 1 with value: 1.2156213927268982.
# Train Epoch 21: Average Loss: 5.835154, KDL: 0.000038, x_loss: 0.136698, y_loss: 0.559360
# {'epoch': 21, 'average_loss': 5.8351540335293475, 'KLD_loss': 3.819602659378929e-05, 'x_loss': 0.13669759999404008, 'y_loss': 0.5593601639243378}
# best trial:
# [1.2156213927268982]
# {'latent_dim': 5, 'lr': 0.0036066471382456876, 'batch_size': 154, 'beta': 3.781515951459095, 'wx': 5.846547247598992, 'wy': 0.7958775399235891}

# %%
study.best_params
# Out:
# {'latent_dim': 5,
#  'lr': 0.0036066471382456876,
#  'batch_size': 154,
#  'beta': 3.781515951459095,
#  'wx': 5.846547247598992,
#  'wy': 0.7958775399235891}

# %% [markdown]
# TRAINING ON BEST PARAMS

# %%
hyperparameters = study.best_params
latent_dim, lr,batch_size, beta,  wx, wy = hyperparameters.values()
num_epochs=50
cvae = CVAE.CVAE(latent_dim).to(device)

# Define the model and optimizer
model = cvae
optimizer = optim.Adam(model.parameters(), lr = lr)

# update PyTorch DataLoader with current value of batch_size
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
num_samples = 30

x_batch, y_batch = next(iter(dataloader))
y_idx = np.random.randint(batch_size)
given_x = x_batch[y_idx].unsqueeze(0).to(device) 
given_y = y_batch[y_idx].unsqueeze(0).to(device) 

given_y = torch.reshape(given_y, (len(given_y), number_of_points* number_of_functions))


# create a PyTorch DataLoader from the dataset
dataloader = DataLoader(dataset, batch_size = batch_size, shuffle=True)
random_seed = 0 # recommend to find optimal value for you solution
torch.manual_seed(random_seed)
if cuda:
    torch.cuda.manual_seed(random_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)

for epoch in range(1, num_epochs + 1):
    epoch_result = CVAE_fn.train_cvae(model, dataloader, optimizer, beta, wx, wy, epoch, functions)
    print(epoch_result)
    
    
CVAE_fn.test_cvae(model, validation_loader,beta, wx, wy, functions)
# Out:
# c:\Users\Aerof\.conda\envs\groundingdino\Lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Train Epoch 1: Average Loss: 3.328905, KDL: 0.518258, x_loss: 0.156270, y_loss: 0.572281
# {'epoch': 1, 'average_loss': 3.3289047853763285, 'KLD_loss': 0.5182580372461906, 'x_loss': 0.1562697053528749, 'y_loss': 0.572281006024434}
# Train Epoch 2: Average Loss: 1.277573, KDL: -0.000004, x_loss: 0.142684, y_loss: 0.557095
# {'epoch': 2, 'average_loss': 1.2775726410058827, 'KLD_loss': -4.020104041466346e-06, 'x_loss': 0.14268394748751934, 'y_loss': 0.5570950368734506}
# Train Epoch 3: Average Loss: 1.264428, KDL: -0.000004, x_loss: 0.140642, y_loss: 0.555579
# {'epoch': 3, 'average_loss': 1.264428209708287, 'KLD_loss': -3.758852298443134e-06, 'x_loss': 0.1406418584057918, 'y_loss': 0.5555794184941512}
# Train Epoch 4: Average Loss: 1.255594, KDL: -0.000003, x_loss: 0.139109, y_loss: 0.555738
# {'epoch': 4, 'average_loss': 1.2555940439150883, 'KLD_loss': -2.93731689453125e-06, 'x_loss': 0.13910876789918314, 'y_loss': 0.5557377509887402}
# Train Epoch 5: Average Loss: 1.249240, KDL: -0.000002, x_loss: 0.138047, y_loss: 0.555543
# {'epoch': 5, 'average_loss': 1.2492396158438464, 'KLD_loss': -1.574571316058819e-06, 'x_loss': 0.1380474917132121, 'y_loss': 0.5555432758881496}
# Train Epoch 6: Average Loss: 1.244142, KDL: -0.000001, x_loss: 0.137159, y_loss: 0.555668
# {'epoch': 6, 'average_loss': 1.2441424692594087, 'KLD_loss': -1.4146474691537711e-06, 'x_loss': 0.13715859807454622, 'y_loss': 0.5556679269900688}
# Train Epoch 7: Average Loss: 1.237620, KDL: -0.000001, x_loss: 0.136116, y_loss: 0.555130
# {'epoch': 7, 'average_loss': 1.2376196833757254, 'KLD_loss': -9.814592508169322e-07, 'x_loss': 0.13611587864848285, 'y_loss': 0.5551300159784464}
# Train Epoch 8: Average Loss: 1.234903, KDL: -0.000000, x_loss: 0.135641, y_loss: 0.555201
# {'epoch': 8, 'average_loss': 1.2349031253961416, 'KLD_loss': -2.8243431678185097e-08, 'x_loss': 0.1356408870449433, 'y_loss': 0.5552014997372261}
# Train Epoch 9: Average Loss: 1.233690, KDL: 0.000000, x_loss: 0.135335, y_loss: 0.555923
# {'epoch': 9, 'average_loss': 1.2336904014073886, 'KLD_loss': 1.6597601083608775e-08, 'x_loss': 0.13533526787391076, 'y_loss': 0.5559226206632761}
# Train Epoch 10: Average Loss: 1.231724, KDL: 0.000000, x_loss: 0.135029, y_loss: 0.555700
# {'epoch': 10, 'average_loss': 1.2317240293209368, 'KLD_loss': 4.826142237736628e-07, 'x_loss': 0.1350289040001539, 'y_loss': 0.5557002752560836}
# Train Epoch 11: Average Loss: 1.228154, KDL: 0.000001, x_loss: 0.134486, y_loss: 0.555201
# {'epoch': 11, 'average_loss': 1.228153971708738, 'KLD_loss': 1.0450069720928486e-06, 'x_loss': 0.13448586702346801, 'y_loss': 0.5552010839719038}
# Train Epoch 12: Average Loss: 1.224472, KDL: 0.000002, x_loss: 0.134100, y_loss: 0.553408
# {'epoch': 12, 'average_loss': 1.2244724323199345, 'KLD_loss': 1.8661755781907302e-06, 'x_loss': 0.13409976052550168, 'y_loss': 0.5534077800237216}
# Train Epoch 13: Average Loss: 1.225583, KDL: 0.000002, x_loss: 0.134111, y_loss: 0.554724
# {'epoch': 13, 'average_loss': 1.225583381652832, 'KLD_loss': 1.906431638277494e-06, 'x_loss': 0.13411058898155506, 'y_loss': 0.5547239210972419}
# Train Epoch 14: Average Loss: 1.223675, KDL: 0.000002, x_loss: 0.133803, y_loss: 0.554581
# {'epoch': 14, 'average_loss': 1.2236746600958017, 'KLD_loss': 2.134854976947491e-06, 'x_loss': 0.1338034692635903, 'y_loss': 0.5545806837081909}
# Train Epoch 15: Average Loss: 1.221363, KDL: 0.000003, x_loss: 0.133492, y_loss: 0.553965
# {'epoch': 15, 'average_loss': 1.2213626749698931, 'KLD_loss': 2.6760651515080376e-06, 'x_loss': 0.13349150774570612, 'y_loss': 0.5539648438416994}
# Train Epoch 16: Average Loss: 1.220427, KDL: 0.000004, x_loss: 0.133313, y_loss: 0.554098
# {'epoch': 16, 'average_loss': 1.220427141556373, 'KLD_loss': 3.6059893094576324e-06, 'x_loss': 0.13331271648406984, 'y_loss': 0.5540983613637778}
# Train Epoch 17: Average Loss: 1.221102, KDL: 0.000004, x_loss: 0.133331, y_loss: 0.554811
# {'epoch': 17, 'average_loss': 1.2211017118967495, 'KLD_loss': 4.3901113363412714e-06, 'x_loss': 0.13333061158657075, 'y_loss': 0.5548107538773464}
# Train Epoch 18: Average Loss: 1.215297, KDL: 0.000007, x_loss: 0.132660, y_loss: 0.552430
# {'epoch': 18, 'average_loss': 1.215296999857976, 'KLD_loss': 7.465802706204928e-06, 'x_loss': 0.13265980584117082, 'y_loss': 0.5524304312926073}
# Train Epoch 19: Average Loss: 1.216832, KDL: 0.000008, x_loss: 0.132824, y_loss: 0.553150
# {'epoch': 19, 'average_loss': 1.2168321200517507, 'KLD_loss': 7.590789061326247e-06, 'x_loss': 0.13282428278372838, 'y_loss': 0.5531504296339476}
# Train Epoch 20: Average Loss: 1.217860, KDL: 0.000009, x_loss: 0.132846, y_loss: 0.554279
# {'epoch': 20, 'average_loss': 1.2178603273171644, 'KLD_loss': 8.595539973332332e-06, 'x_loss': 0.13284588115719648, 'y_loss': 0.5542789113521576}
# Train Epoch 21: Average Loss: 1.212866, KDL: 0.000009, x_loss: 0.132220, y_loss: 0.552599
# {'epoch': 21, 'average_loss': 1.2128664781497076, 'KLD_loss': 8.543638082650991e-06, 'x_loss': 0.13222048074007034, 'y_loss': 0.5525987238150376}
# Train Epoch 22: Average Loss: 1.215190, KDL: 0.000009, x_loss: 0.132494, y_loss: 0.553506
# {'epoch': 22, 'average_loss': 1.215189912685981, 'KLD_loss': 9.035789049588716e-06, 'x_loss': 0.1324940338730812, 'y_loss': 0.5535061864669506}
# Train Epoch 23: Average Loss: 1.211128, KDL: 0.000008, x_loss: 0.132016, y_loss: 0.551923
# {'epoch': 23, 'average_loss': 1.2111276157085713, 'KLD_loss': 7.80472388634315e-06, 'x_loss': 0.13201553690891998, 'y_loss': 0.5519229233264923}
# Train Epoch 24: Average Loss: 1.212342, KDL: 0.000008, x_loss: 0.132150, y_loss: 0.552462
# {'epoch': 24, 'average_loss': 1.2123419838685257, 'KLD_loss': 8.131999235886794e-06, 'x_loss': 0.13214958330759635, 'y_loss': 0.5524624796097095}
# Train Epoch 25: Average Loss: 1.207022, KDL: 0.000008, x_loss: 0.131470, y_loss: 0.550774
# {'epoch': 25, 'average_loss': 1.207022233559535, 'KLD_loss': 7.837919088510366e-06, 'x_loss': 0.1314697080392104, 'y_loss': 0.5507741354979001}
# Train Epoch 26: Average Loss: 1.208128, KDL: 0.000008, x_loss: 0.131522, y_loss: 0.551783
# {'epoch': 26, 'average_loss': 1.208128064595736, 'KLD_loss': 7.597483121431791e-06, 'x_loss': 0.1315216404084976, 'y_loss': 0.5517832294794229}
# Train Epoch 27: Average Loss: 1.210504, KDL: 0.000008, x_loss: 0.131750, y_loss: 0.553090
# {'epoch': 27, 'average_loss': 1.210503947368035, 'KLD_loss': 8.211777760432316e-06, 'x_loss': 0.13174967682132355, 'y_loss': 0.5530903831353554}
# Train Epoch 28: Average Loss: 1.206513, KDL: 0.000007, x_loss: 0.131310, y_loss: 0.551307
# {'epoch': 28, 'average_loss': 1.2065126464917109, 'KLD_loss': 7.345768121572642e-06, 'x_loss': 0.1313102947634, 'y_loss': 0.5513072487941155}
# Train Epoch 29: Average Loss: 1.206862, KDL: 0.000008, x_loss: 0.131317, y_loss: 0.551695
# {'epoch': 29, 'average_loss': 1.2068622950407175, 'KLD_loss': 7.960062760573167e-06, 'x_loss': 0.1313169645346128, 'y_loss': 0.5516946568855873}
# Train Epoch 30: Average Loss: 1.204973, KDL: 0.000009, x_loss: 0.131078, y_loss: 0.551071
# {'epoch': 30, 'average_loss': 1.204973495373359, 'KLD_loss': 8.586370027982271e-06, 'x_loss': 0.1310783702478959, 'y_loss': 0.5510711721273569}
# Train Epoch 31: Average Loss: 1.207554, KDL: 0.000008, x_loss: 0.131369, y_loss: 0.552177
# {'epoch': 31, 'average_loss': 1.2075542886440571, 'KLD_loss': 8.475505388700046e-06, 'x_loss': 0.13136926381633832, 'y_loss': 0.5521774918299455}
# Train Epoch 32: Average Loss: 1.206309, KDL: 0.000008, x_loss: 0.131141, y_loss: 0.552289
# {'epoch': 32, 'average_loss': 1.2063094650782071, 'KLD_loss': 8.150705924400916e-06, 'x_loss': 0.1311413664657336, 'y_loss': 0.5522890841960907}
# Train Epoch 33: Average Loss: 1.203160, KDL: 0.000008, x_loss: 0.130737, y_loss: 0.551305
# {'epoch': 33, 'average_loss': 1.2031602300130404, 'KLD_loss': 8.16941261291504e-06, 'x_loss': 0.13073663391746007, 'y_loss': 0.5513052419515756}
# Train Epoch 34: Average Loss: 1.201178, KDL: 0.000008, x_loss: 0.130499, y_loss: 0.550559
# {'epoch': 34, 'average_loss': 1.2011776836101826, 'KLD_loss': 8.367483432476337e-06, 'x_loss': 0.13049903783660668, 'y_loss': 0.5505586728682885}
# Train Epoch 35: Average Loss: 1.209106, KDL: 0.000008, x_loss: 0.131327, y_loss: 0.554441
# {'epoch': 35, 'average_loss': 1.209106034865746, 'KLD_loss': 7.75318879347581e-06, 'x_loss': 0.131326967386099, 'y_loss': 0.5544413580344274}
# Train Epoch 36: Average Loss: 1.201767, KDL: 0.000009, x_loss: 0.130559, y_loss: 0.550858
# {'epoch': 36, 'average_loss': 1.2017665540255034, 'KLD_loss': 8.520346421461839e-06, 'x_loss': 0.13055894639629584, 'y_loss': 0.5508577566880446}
# Train Epoch 37: Average Loss: 1.202662, KDL: 0.000008, x_loss: 0.130693, y_loss: 0.551002
# {'epoch': 37, 'average_loss': 1.202662038069505, 'KLD_loss': 8.06560883155236e-06, 'x_loss': 0.13069281979249073, 'y_loss': 0.5510016305630023}
# Train Epoch 38: Average Loss: 1.201290, KDL: 0.000008, x_loss: 0.130460, y_loss: 0.550985
# {'epoch': 38, 'average_loss': 1.201290281185737, 'KLD_loss': 8.374544290395884e-06, 'x_loss': 0.13046023894961065, 'y_loss': 0.5509851278708531}
# Train Epoch 39: Average Loss: 1.201688, KDL: 0.000008, x_loss: 0.130566, y_loss: 0.550710
# {'epoch': 39, 'average_loss': 1.201688033250662, 'KLD_loss': 7.851674006535457e-06, 'x_loss': 0.1305660867003294, 'y_loss': 0.5507098213525918}
# Train Epoch 40: Average Loss: 1.198984, KDL: 0.000008, x_loss: 0.130194, y_loss: 0.550043
# {'epoch': 40, 'average_loss': 1.1989840006828307, 'KLD_loss': 8.122829290536733e-06, 'x_loss': 0.13019420345242208, 'y_loss': 0.5500428544558011}
# Train Epoch 41: Average Loss: 1.200694, KDL: 0.000009, x_loss: 0.130342, y_loss: 0.551103
# {'epoch': 41, 'average_loss': 1.20069365299665, 'KLD_loss': 8.870913432194637e-06, 'x_loss': 0.1303418531555396, 'y_loss': 0.5511027900072244}
# Train Epoch 42: Average Loss: 1.197947, KDL: 0.000008, x_loss: 0.130015, y_loss: 0.550056
# {'epoch': 42, 'average_loss': 1.1979474812287552, 'KLD_loss': 8.24744884784405e-06, 'x_loss': 0.13001508954625862, 'y_loss': 0.5500556744978978}
# Train Epoch 43: Average Loss: 1.199827, KDL: 0.000007, x_loss: 0.130303, y_loss: 0.550308
# {'epoch': 43, 'average_loss': 1.1998273943020747, 'KLD_loss': 7.393085039578951e-06, 'x_loss': 0.13030289200636055, 'y_loss': 0.5503075924286476}
# Train Epoch 44: Average Loss: 1.199569, KDL: 0.000008, x_loss: 0.130121, y_loss: 0.551313
# {'epoch': 44, 'average_loss': 1.1995692975704486, 'KLD_loss': 8.242497077355018e-06, 'x_loss': 0.13012133701489523, 'y_loss': 0.5513129707483145}
# Train Epoch 45: Average Loss: 1.203305, KDL: 0.000009, x_loss: 0.130692, y_loss: 0.551811
# {'epoch': 45, 'average_loss': 1.2033053073516258, 'KLD_loss': 8.616722547090971e-06, 'x_loss': 0.13069236484857705, 'y_loss': 0.5518106032334841}
# Train Epoch 46: Average Loss: 1.197905, KDL: 0.000008, x_loss: 0.129965, y_loss: 0.550374
# {'epoch': 46, 'average_loss': 1.1979050093430739, 'KLD_loss': 8.049378028282753e-06, 'x_loss': 0.12996466636657714, 'y_loss': 0.5503736631686871}
# Train Epoch 47: Average Loss: 1.195696, KDL: 0.000008, x_loss: 0.129649, y_loss: 0.549919
# {'epoch': 47, 'average_loss': 1.195696457165938, 'KLD_loss': 7.866529318002554e-06, 'x_loss': 0.12964886023448063, 'y_loss': 0.5499194663304549}
# Train Epoch 48: Average Loss: 1.200270, KDL: 0.000009, x_loss: 0.130140, y_loss: 0.552055
# {'epoch': 48, 'average_loss': 1.200269591808319, 'KLD_loss': 8.654502721933218e-06, 'x_loss': 0.13013980378325168, 'y_loss': 0.5520552609517024}
# Train Epoch 49: Average Loss: 1.196047, KDL: 0.000009, x_loss: 0.129738, y_loss: 0.549698
# {'epoch': 49, 'average_loss': 1.1960465247814471, 'KLD_loss': 8.510809678297777e-06, 'x_loss': 0.12973840558758148, 'y_loss': 0.5496984534997207}
# Train Epoch 50: Average Loss: 1.196129, KDL: 0.000008, x_loss: 0.129703, y_loss: 0.550061
# {'epoch': 50, 'average_loss': 1.1961293323223408, 'KLD_loss': 8.289447197547325e-06, 'x_loss': 0.12970335935170835, 'y_loss': 0.550060997742873}
# Test Loss: 1.197432
# 1.1974317193031312

# %% [markdown]
# ## 3. Sample generation of reconstructed X0/X1 pairs and saving results
#
# Download dataset **scoring_dataset.pt** and put them into the **'/data'** folder. Otherwise, change the path to it to your own.
#
# For submission **, we require num_samples to equals 30** for each element of the **scoring_dataset.pt**. Please be sure that all 50 elements from each sample, and only them, were used for sample generation.

# %%
filename_scoring_dataset = f'{data_root}scoring{filename}.pt'
scoring_dataset = CVAE_fn.SignalDataset(torch.load(filename_scoring_dataset))

print(f"Scoring dataset is loaded successfully and has length: {len(scoring_dataset)}")

# create a PyTorch DataLoader from the scoring_dataset
scoring_loader = DataLoader(scoring_dataset, batch_size=len(scoring_dataset), shuffle=True)

num_samples = 30
x_batch, y_batch = next(iter(scoring_loader))
x_out= []
y_out = []
for idx in range(len(y_batch)):
    given_y = y_batch[idx].unsqueeze(0).to(device)
    given_y = torch.reshape(given_y, (len(given_y), number_of_points * number_of_functions))
    x_output, y_output = CVAE_fn.generate_samples(model, num_samples, given_y, input_shape)
    y_output = torch.reshape(y_output, (len(y_output), 1, number_of_points, number_of_functions))
    x_out.append(x_output)
    y_out.append(y_output)
    '''
    Combine all generated samples together.
    Be carefull -  y_output here are GIVEN Y1/Y1. y_hat (aka reconstructed Y1/Y2) always could  be calculated 
    by x_output, so it should not be stored in result file. 
    '''

x_outputs = torch.cat(x_out, dim=0)   
y_outputs = torch.cat(y_out, dim=0) 
x_outputs = x_outputs.cpu()
y_outputs = y_outputs.cpu()


# Save result as TensorDataset before submitting, for example like next: 
# Pay attention the code below doesn't work unless you have comleted generation x_ouputs/y_outputs above.  

ds = data_utils.TensorDataset(x_outputs,y_outputs)
torch.save(ds, 'D:/aiml projects/BH 24-2y/bh2y_final resources/bh2y_final resources/result/result_dataset.pt')
# Out:
# Scoring dataset is loaded successfully and has length: 50

# %% [markdown]
# ## Submission and evaluation
#
# The evaluation of the results will combine in a total score for the Predictive Leader Board the following assessments:
#
#  - Reconstruction error: This measures how close the vector Y1_hat/Y2_hat obtained from the generated X0_hat and X1_hat is to the given Y1/Y2. A low reconstruction error indicates that the CVAE has learned to generate combinations of X0 and X1 that can produce similar signals Y1/Y2.
#
#  - Preservation of the structure: This measures how well the vectors X0_hat and X1_hat have retained the given structure, straight lines with a preserved slope sign. A high level of preservation indicates that the CVAE has learned to generate combinations of X0 and X1 that adhere to the given structure.
#
#  - Diversity of generated combinations: This measures how well the CVAE has covered the solution space by generating diverse combinations of X0_hat and X1_hat that can produce similar signals Y1/Y2. A high level of diversity indicates that the CVAE has generated a wide range of possible combinations of X0 and X1.
#
# Please note that a **higher total score indicates a better solution**.
